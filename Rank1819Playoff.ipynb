# %% [markdown]
# <a href="https://colab.research.google.com/github/flee2-trinity/Deep-Learning-in-Sports-Result-Prediction-/blob/main/Rank1819Playoff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#add n days no win rate
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

from google.colab import drive

drive.mount('/content/gdrive')
DATA_PATH = '/content/gdrive/My Drive/2021 Fall/Thesis I'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import glob
import os
import datetime

def findFiles(path): 
  return glob.glob(path)

# %%
import csv

filename = '/content/gdrive/My Drive/2021 Fall/Thesis I/NBA Data/nba 18-19/NatStat-NBA2019-Team_Statlines.csv'
with open(filename, newline='') as f:
      reader = csv.reader(f)
      """
      print(list(reader))
      ['GameDay', 'GameID', 'TeamID', 'Team', 'OpponentID', 'Opponent', 'Location',
       'Division', 'Conference', 'Playoffs', 'WinOrLoss', 'PlayerType', 'MIN', 'PTS', 
       'FGM', 'FGA', '3FM', '3FA', 'FTM', 'FTA', 'REB', 'AST', 'STL', 'BLK', 'OREB', 'TO', 'PF']
      """
      next(reader)
      rawDataL = list(reader)
print(rawDataL[0])
# Out:
# ['2018-10-16', '985248', '5', 'Boston', '28', 'Philadelphia', 'H', '', '', '', 'W', '', '234', '103', '41', '96', '11', '37', '10', '14', '54', '21', '7', '6', '12', '14', '20']

# %%
filename18 = '/content/gdrive/My Drive/2021 Fall/Thesis I/NBA Data/nba 17-18/NatStat-NBA2018-Team_Statlines.csv'
with open(filename18, newline='') as f:
      reader = csv.reader(f)
      """
      print(list(reader))
      ['GameDay', 'GameID', 'TeamID', 'Team', 'OpponentID', 'Opponent', 'Location',
       'Division', 'Conference', 'Playoffs', 'WinOrLoss', 'PlayerType', 'MIN', 'PTS', 
       'FGM', 'FGA', '3FM', '3FA', 'FTM', 'FTA', 'REB', 'AST', 'STL', 'BLK', 'OREB', 'TO', 'PF']
      """
      next(reader)
      rawDataL18 = list(reader)
print(rawDataL18[0])
# Out:
# ['2017-10-17', '982028', '1', 'Houston', '25', 'Golden State', 'V', '', 'Western', '', 'W', '', '237', '122', '47', '96', '15', '41', '13', '19', '41', '27', '10', '5', '9', '12', '15']

# %%
import datetime

def readTime(ampm):
  t = 0
  tL = ampm.replace(' ',':').split(':')
  if tL[2] == "PM" and int(tL[0]) < 12:
    t += 12
  t += int(tL[0])
  t += int(tL[1])/60
  return t

seasonBegin = datetime.datetime(2018, 10, 16)
noonTime = readTime("12:00 PM")
#not using
class Stats:
  def __init__(self):
    """
    MIN, PTS,FGM, FGA, 3FM, 3FA, FTM, FTA, REB, AST, STL, BLK, OREB, TO, PF
    """
    self.MIN = 0
    self.PTS = 0
    self.FGM = 0
    self.FGA = 0
    self.FM3 = 0
    self.FA3 = 0
    self.FTM = 0
    self.FTA = 0
    self.REB = 0
    self.AST = 0
    self.STL = 0
    self.BLK = 0
    self.OREB = 0
    self.TO = 0
    self.PF = 0
    self.Win = 0
    self.Loss = 0
    self.WinRate = 0
  def update(self, MIN, PTS,FGM, FGA, FM3, FA3, FTM, FTA, REB, AST, STL, BLK, OREB, TO, PF):
    self.MIN = MIN
    self.PTS = PTS
    self.FGM = FGM
    self.FGA = FGA
    self.FM3 = FM3
    self.FA3 = FA3
    self.FTM = FTM
    self.FTA = FTA
    self.REB = REB
    self.AST = AST
    self.STL = STL
    self.BLK = BLK
    self.OREB = OREB
    self.TO = TO
    self.PF = PF
  def addWinRate(self, Win, Loss):
    self.Win = Win
    self.Loss = Loss
    self.WinRate = Win/(Win+Loss)
  def notEmpty(self):
    return self.MIN>0

class aGame:
  def __init__(self, GameDay, GameID, TeamID, Team, OpponentID, Opponent, Location,
       Division, Conference, Playoffs, WinOrLoss, PlayerType):
    self.GameID = int(GameID)
    self.TeamID = int(TeamID)
    gdL = GameDay.split("-")
    self.GameDay = datetime.datetime(int(gdL[0]), int(gdL[1]), int(gdL[2]))
    #self.GameTime = GameTime
    self.DayCount = (self.GameDay - seasonBegin).days
    self.Team = Team
    self.OpponentID = int(OpponentID)
    self.Opponent = Opponent
    self.Home = Location == 'H'
    self.Division = Division
    self.Conference = Conference
    self.Playoffs = Playoffs == 'Y'
    self.WinOrLoss = WinOrLoss == 'W'
    self.WinID = int(self.WinOrLoss)
    self.LossID = int(not self.WinOrLoss)
    self.PlayerType = PlayerType
    self.TStats = Stats()
    self.OppStats = Stats()
    self.TStatsP = Stats()
    self.OppStatsP = Stats()
    self.previous = False
  def printDay(self):
    print('Day', self.DayCount)
  def updateLastWRate(self, winRate):
    self.lastWinRate = winRate
def aLinetoGame(aline):
  newG = aGame(aline[0], aline[1], aline[2], aline[3], aline[4], aline[5], aline[6],
               aline[7], aline[8], aline[9], aline[10], aline[11])
  for n in range(12, 27):
    aline[n] = int(aline[n])

  newG.TStats.update(aline[12], aline[13], aline[14], aline[15], aline[16], aline[17], 
                     aline[18], aline[19], aline[20], aline[21], aline[22], aline[23], 
                     aline[24], aline[25], aline[26])
  return newG

def readLines(filename):
  with open(filename, newline='') as f:
      reader = csv.reader(f)
      next(reader)
      rawDataL = list(reader)
  #print(rawDataL)
  #'ID', 'GameDay', 'GameTime', 'Home', 'HomeID', 'Visitor', 'VisitorID', 'ScoreVis', 
  #'ScoreHome', 'GameStatus', 'Venue', 'CityState', 'Neutral', 'Division', 'Conference', 'Playoffs'
  #print("RawDataLength ",len(rawDataL))
  data = []
  print(rawDataL[0])
  for oneLine in rawDataL:
    g = aLinetoGame(oneLine)
    data.append(g)
  return data

# %%
from copy import deepcopy
allData18 = readLines(filename18)
print(allData18[1])
print(len(allData18))
winRecord18 = []
lossRecord18 = []
for tg in allData18:
  tg.previous = True
  if tg.WinID and not tg.Playoffs:
    winRecord18.append(tg.TeamID)
  elif not tg.Playoffs:
    lossRecord18.append(tg.TeamID)
print(len(allData18))
# Out:
# ['2017-10-17', '982028', '1', 'Houston', '25', 'Golden State', 'V', '', 'Western', '', 'W', '', '237', '122', '47', '96', '15', '41', '13', '19', '41', '27', '10', '5', '9', '12', '15']
# <__main__.aGame object at 0x7f5829946890>
# 2622
# 2622

# %%
from collections import Counter
wr = Counter(winRecord18).most_common()
lr = Counter(lossRecord18).most_common()

# %%
allData = readLines(filename)
print(allData[1])
print(len(allData))
# Out:
# ['2018-10-16', '985248', '5', 'Boston', '28', 'Philadelphia', 'H', '', '', '', 'W', '', '234', '103', '41', '96', '11', '37', '10', '14', '54', '21', '7', '6', '12', '14', '20']
# <__main__.aGame object at 0x7f5818b78110>
# 2580

# %%
tempD = allData[0:400]
tIDs = list(set(map(lambda x: x.TeamID, tempD)))
print(len(tIDs))
# Out:
# 30

# %%
from collections import defaultdict
dic = defaultdict(lambda: "Not Present")
for t in tIDs:
  w = list(filter(lambda x: x[0] == t, wr))[0][1]
  l = list(filter(lambda x: x[0] == t, lr))[0][1]
  dic[t] = w/(w+l)

# %%
for tg in allData:
  previousGamesList = list(filter(lambda g: (g.DayCount < tg.DayCount) and (g.TeamID == tg.TeamID), allData))
  pMIN = 0
  pPTS = 0
  pFGM = 0
  pFGA = 0
  pFM3 = 0
  pFA3 = 0
  pFTM = 0
  pFTA = 0
  pREB = 0
  pAST = 0
  pSTL = 0
  pBLK = 0
  pOREB = 0
  pTO = 0
  pPF = 0
  pWin = 0
  pLoss = 0
  for p in previousGamesList:
    g = p.TStats
    pMIN += g.MIN
    pPTS += g.PTS
    pFGM += g.FGM
    pFGA += g.FGA
    pFM3 += g.FM3
    pFA3 += g.FA3
    pFTM += g.FTM
    pFTA += g.FTA
    pREB += g.REB
    pAST += g.AST
    pSTL += g.STL
    pBLK += g.BLK
    pOREB += g.OREB
    pTO += g.TO
    pPF += g.PF
    pWin += p.WinID
    pLoss += p.LossID
  gPlayed = len(previousGamesList)
  if gPlayed > 0:
    tg.TStatsP.update(pMIN/gPlayed, pPTS/gPlayed, pFGM/gPlayed, pFGA/gPlayed, pFM3/gPlayed,
                      pFA3/gPlayed, pFTM/gPlayed, pFTA/gPlayed, pREB/gPlayed, pAST/gPlayed,
                      pSTL/gPlayed, pBLK/gPlayed, pOREB/gPlayed, pTO/gPlayed, pPF/gPlayed)
    tg.TStatsP.addWinRate(pWin, pLoss)
  else:
    tg.TStatsP.update(234, 100, 44, 90, 10,
                      30, 20, 25, 45, 25,
                      7, 7, 11, 15, 22)
    tg.TStatsP.addWinRate(1, 1)
    #Random for the first game
allGames = []
for d in allData:
  d.updateLastWRate(dic[d.TeamID])
  sameGameList = list(filter(lambda g: g.GameID == d.GameID, allGames))
  if len(sameGameList) > 0:
    for g in sameGameList:
      if g.Home: 
        g.OppStats = deepcopy(d.TStats)
        g.OppStatsP = deepcopy(d.TStatsP)
      else:
        d.OppStats = deepcopy(g.TStats)
        d.OppStatsP = deepcopy(g.TStatsP)
        allGames.remove(g)
        allGames.append(d)
  else:
    allGames.append(d)
allData = allGames
print(len(allData))
# Out:
# 1290

# %%
print(len(allData18))
allGames18 = []
setGameID = set(map(lambda g: g.GameID, allData18))

for d in setGameID:
  #d.updateLastWRate(dic[d.TeamID])
  sameGame = list(filter(lambda g: g.GameID == d, allData18))[0]
  sameGame.previous = True
  allGames18.append(sameGame)
allData18 = list(filter(lambda g: not g.Playoffs, allGames18))
print(len(allData18))
allData18.sort(key = lambda g: g.GameDay)
print(len(allData18))
# Out:
# 2622
# 1230
# 1230

# %%
def sep2Groups(allD, afterN, oldData):#For Ranking
  allDataP = list(filter(lambda g:not g.Playoffs, allD))
  test_daysAfterN = list(filter(lambda g: g.DayCount >= afterN, allDataP))
  test_daysAfterN = list(map(lambda g: g.DayCount, test_daysAfterN))
  test_days = list(set(test_daysAfterN))
  test_days.sort()

  test_listGroups = []
  train_listGroups = []
  for daysC in test_days:
    tempL = list(filter(lambda g: g.DayCount < daysC, allDataP))
    train_listGroups.append(tempL + oldData)
    test_listGroups.append(list(filter(lambda g: g.DayCount >= daysC, allDataP)))
  return (train_listGroups, test_listGroups)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

def gametoTensor(g : aGame):
  tensor = torch.zeros(1, 1, 82)
  
  tensor[0][0][g.TeamID] = 1
  tensor[0][0][g.OpponentID+37] = 1
  tensor[0][0][77] = g.DayCount/300
  tensor[0][0][78] = int(g.previous)
  tensor[0][0][79] = g.TStatsP.Win/72
  tensor[0][0][80] = g.TStatsP.Loss/72
  tensor[0][0][81] = g.TStatsP.WinRate
  #winloss
  #previous win loss
  
  return tensor

def gamestoTensorTrain(games, test = False):
  g_tensor_list = []
  currentWinRecord = []
  for g in games:
    g_tensor_list.append((gametoTensor(g), g.WinID))
    if g.WinID > 0 and not g.previous:
      currentWinRecord.append(g.TeamID)
    elif not g.previous:
      currentWinRecord.append(g.OpponentID)
  return g_tensor_list, currentWinRecord
def gamestoTensorTest(games, test = False):
  g_tensor_list = []
  for g in games:
    g_tensor_list.append((gametoTensor(g), g.WinID, g.TeamID, g.OpponentID))
  return g_tensor_list

# %%
def allTeamsComb(day):
  rankTestList = []
  tempLine = ['2018-10-16', '985248', '5', 'Boston', '28', 'Philadelphia', 
                'H', '', '', '', 'W', '', '234', '103', '41', '96', '11', '37', 
                '10', '14', '54', '21', '7', '6', '12', '14', '20']
  for a in tIDs:
    for b in tIDs:
      if a != b:
        testG = aLinetoGame(tempLine)
        testG.TeamID = a
        testG.OpponentID = b
        testG.DayCount = day
        testG.updateLastWRate(dic[a])
        testG.TStatsP.addWinRate(1, 1)
        rankTestList.append((gametoTensor(testG), a, b))
  return rankTestList

# %%
def getRankList(rankRecord):
  #print(len(rankRecord))
  rC = Counter(rankRecord).most_common()

  r = list(map(lambda x: x[0], rC))
  nRank = []
  for a in tIDs:
    if a not in r:
      nRank.append(30)
    else:
      nRank.append(r.index(a)+1)
  return nRank

# %%
allRecord = []
nonPlayoffData = list(filter(lambda g:not g.Playoffs, allData))
print(len(allData))
for g in nonPlayoffData:
  if g.WinID> 0 :
    allRecord.append(g.TeamID)
  else:
    allRecord.append(g.OpponentID)
print(len(allRecord))
playOffRanking = getRankList(allRecord)
print(playOffRanking)
# Out:
# 1290
# 1208
# [7, 21, 17, 6, 9, 26, 1, 27, 28, 2, 13, 15, 29, 18, 19, 10, 12, 25, 30, 14, 23, 4, 3, 8, 20, 5, 22, 11, 16, 24]

# %%
eastDiv = [6, 5, 36, 3, 8, 9, 18, 16, 7, 21, 13, 28, 10, 20, 22]
westDiv = [23, 24, 25, 1, 11, 27, 31, 2, 38, 35, 14, 4, 15, 17, 26]

# %%
def getPlayoffRank(ranking):
  westPlayoff = []
  eastPlayoff = []
  w = 0
  e = 0
  for p in ranking:
    if p in westDiv and w < 8:
      w += 1
      westPlayoff.append(p)
    elif p in eastDiv and e < 8:
      e += 1
      eastPlayoff.append(p)
  return (westPlayoff, eastPlayoff) 
realWPlayoff, realEPlayoff = getPlayoffRank(playOffRanking)
print(realWPlayoff)
print(realEPlayoff)
def compareRealRank(ranking):
  wPlayoff, ePlayoff = getPlayoffRank(ranking)
  w = list(set(wPlayoff) & set(realWPlayoff))
  e = list(set(ePlayoff) & set(realEPlayoff))
  return (len(w), len(e))
print(compareRealRank(playOffRanking))
# Out:
# [17, 26, 1, 27, 2, 15, 25, 14]
# [7, 21, 6, 9, 28, 13, 18, 10]
# (8, 8)

# %%
import time
import math
from statistics import mean
import scipy.stats as stats
from scipy.stats import kendalltau
def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def runModel(train_listGroups, test_listGroups):
  start = time.time()
  train_tlistGroups = list(map(lambda group: gamestoTensorTrain(group), train_listGroups))
  test_tlistGroups = list(map(lambda group: gamestoTensorTest(group, test = True), test_listGroups))
  totalR_list = []
  print(len(train_tlistGroups), len(test_tlistGroups))
  for t in range(len(train_tlistGroups)):
    print('Model: ', t)
    model = nn.Sequential(nn.Linear(82, 64),
                          nn.Tanh(),
                          nn.Linear(64, 16),
                          nn.Tanh(),
                          nn.Linear(16, 2),
                          nn.LogSoftmax(dim=1))
    #model = model.to(device=device)
    learning_rate = 0.005
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    loss_fn = nn.NLLLoss()#meansquarerror
    n_epochs = 30
    currentRecord = train_tlistGroups[t][1]
    #print(len(currentRecord))
    for epoch in range(n_epochs):
      
      train_loader = torch.utils.data.DataLoader(train_tlistGroups[t][0], batch_size = 2, shuffle = True)
      for gs, labels in train_loader:
        #gs = gs.to(device=device)
        #labels = labels.to(device = device)
        batch_size = gs.shape[0]
        outputs = model(gs.view(batch_size, -1))
        loss = loss_fn(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
      if (epoch+1)%10 == 0:
        print(timeSince(start))
        print("Epoch: %d, Loss: %f" % (epoch, float(loss)))

    powerTestList = allTeamsComb(test_listGroups[t][0].DayCount)
    powerRankRecord = []
    for k, a, b in powerTestList:
      outputs = model(k.view(1, -1))
      #print(outputs)
      _, predicted = torch.max(outputs, dim=1)
      #print(predicted)
      if predicted == 1:
        powerRankRecord.append(a)
      else:
        powerRankRecord.append(b)
    powerRankList = getRankList(powerRankRecord)#Power Ranking
    #print(playOffRanking)
    powW, powE = compareRealRank(powerRankList)
    scheduleRecord = []
    for gt, label, tID, oID in test_tlistGroups[t]:
      outputs = model(gt.view(1, -1))
      _, predicted = torch.max(outputs, dim=1)
      if predicted:
        scheduleRecord.append(tID)
      else:
        scheduleRecord.append(oID)
    #print(len(currentRecord+scheduleRecord))
    fakePlayOffRanking = getRankList(currentRecord+scheduleRecord)
    allW, allE = compareRealRank(fakePlayOffRanking)
    tempR = (t, powW, powE, allW, allE)
    print(tempR)
    totalR_list.append(tempR)
  print(timeSince(start))
  return totalR_list

# %%
def writeInRank(newRecord):
  p1Name='/content/gdrive/My Drive/2021 Fall/Thesis I/Records/Rank1819Playoff.txt'
  p1file=open(p1Name)
  p1file_content = p1file.read()
  p1file=open(p1Name,"w")
  p1file.write(p1file_content)
  for t, powW, powE, allW, allE in newRecord:
    p1file.write(str(t)+" "+ str(powW) + " " + str(powE) + " " + str(allW) + " " + str(allE) + "\n")
  p1file.write("-\n")
  p1file=open(p1Name)
  p1file_content = p1file.read()
  #print(p1file_content)
  p1file.close()

# %%
allData18.sort(key = lambda x: x.GameDay)
print(len(allData18))
trainGs, testGs = sep2Groups(allData, 5, allData18[-int(len(allData18)/4):])
print(len(trainGs), len(testGs))
# Out:
# 1230
# 163 163

# %%
for i in range(30):
  print('Run %d' %i)
  writeInRank(runModel(trainGs, testGs))
# Out:
# Streaming output truncated to the last 5000 lines.
# Model:  28
# 2m 7s
# Epoch: 9, Loss: 0.594939
# 2m 9s
# Epoch: 19, Loss: 0.485948
# 2m 10s
# Epoch: 29, Loss: 0.485351
# (28, 5, 3, 5, 3)
# Model:  29
# 2m 12s
# Epoch: 9, Loss: 0.839059
# 2m 14s
# Epoch: 19, Loss: 0.887316
# 2m 15s
# Epoch: 29, Loss: 0.373717
# (29, 6, 5, 6, 5)
# Model:  30
# 2m 17s
# Epoch: 9, Loss: 0.486803
# 2m 19s
# Epoch: 19, Loss: 0.877380
# 2m 20s
# Epoch: 29, Loss: 0.296808
# (30, 5, 3, 5, 5)
# Model:  31
# 2m 22s
# Epoch: 9, Loss: 0.692707
# 2m 24s
# Epoch: 19, Loss: 1.137905
# 2m 25s
# Epoch: 29, Loss: 0.125760
# (31, 5, 5, 5, 5)
# Model:  32
# 2m 27s
# Epoch: 9, Loss: 0.682257
# 2m 29s
# Epoch: 19, Loss: 0.482823
# 2m 30s
# Epoch: 29, Loss: 0.734256
# (32, 5, 5, 5, 5)
# Model:  33
# 2m 32s
# Epoch: 9, Loss: 0.552296
# 2m 34s
# Epoch: 19, Loss: 1.477547
# 2m 36s
# Epoch: 29, Loss: 0.681747
# (33, 6, 7, 5, 5)
# Model:  34
# 2m 38s
# Epoch: 9, Loss: 0.943322
# 2m 39s
# Epoch: 19, Loss: 0.479028
# 2m 41s
# Epoch: 29, Loss: 0.507080
# (34, 6, 6, 7, 3)
# Model:  35
# 2m 43s
# Epoch: 9, Loss: 0.803574
# 2m 45s
# Epoch: 19, Loss: 0.341752
# 2m 46s
# Epoch: 29, Loss: 0.239044
# (35, 6, 4, 5, 5)
# Model:  36
# 2m 48s
# Epoch: 9, Loss: 0.569430
# 2m 50s
# Epoch: 19, Loss: 0.335514
# 2m 52s
# Epoch: 29, Loss: 0.862253
# (36, 5, 5, 5, 5)
# Model:  37
# 2m 54s
# Epoch: 9, Loss: 0.804245
# 2m 55s
# Epoch: 19, Loss: 1.187999
# 2m 57s
# Epoch: 29, Loss: 0.422579
# (37, 5, 5, 5, 4)
# Model:  38
# 2m 59s
# Epoch: 9, Loss: 0.675821
# 3m 1s
# Epoch: 19, Loss: 0.369491
# 3m 3s
# Epoch: 29, Loss: 0.214919
# (38, 5, 6, 7, 4)
# Model:  39
# 3m 5s
# Epoch: 9, Loss: 0.813769
# 3m 6s
# Epoch: 19, Loss: 0.355435
# 3m 8s
# Epoch: 29, Loss: 0.316860
# (39, 6, 7, 5, 4)
# Model:  40
# 3m 10s
# Epoch: 9, Loss: 0.455150
# 3m 12s
# Epoch: 19, Loss: 0.791443
# 3m 14s
# Epoch: 29, Loss: 0.174466
# (40, 5, 4, 4, 4)
# Model:  41
# 3m 16s
# Epoch: 9, Loss: 0.591196
# 3m 18s
# Epoch: 19, Loss: 0.432152
# 3m 19s
# Epoch: 29, Loss: 0.360361
# (41, 5, 6, 5, 5)
# Model:  42
# 3m 21s
# Epoch: 9, Loss: 0.541119
# 3m 23s
# Epoch: 19, Loss: 0.514723
# 3m 25s
# Epoch: 29, Loss: 0.570139
# (42, 6, 6, 5, 5)
# Model:  43
# 3m 27s
# Epoch: 9, Loss: 0.595280
# 3m 29s
# Epoch: 19, Loss: 0.569776
# 3m 31s
# Epoch: 29, Loss: 0.574196
# (43, 5, 6, 4, 5)
# Model:  44
# 3m 33s
# Epoch: 9, Loss: 0.502544
# 3m 35s
# Epoch: 19, Loss: 0.708069
# 3m 37s
# Epoch: 29, Loss: 0.501395
# (44, 4, 4, 5, 6)
# Model:  45
# 3m 39s
# Epoch: 9, Loss: 0.645288
# 3m 41s
# Epoch: 19, Loss: 0.543302
# 3m 43s
# Epoch: 29, Loss: 0.252124
# (45, 5, 5, 4, 5)
# Model:  46
# 3m 45s
# Epoch: 9, Loss: 0.575388
# 3m 47s
# Epoch: 19, Loss: 0.487999
# 3m 49s
# Epoch: 29, Loss: 0.352662
# (46, 5, 5, 5, 6)
# Model:  47
# 3m 51s
# Epoch: 9, Loss: 0.582813
# 3m 53s
# Epoch: 19, Loss: 0.428665
# 3m 54s
# Epoch: 29, Loss: 0.695338
# (47, 5, 5, 5, 5)
# Model:  48
# 3m 57s
# Epoch: 9, Loss: 0.581062
# 3m 59s
# Epoch: 19, Loss: 0.375234
# 4m 0s
# Epoch: 29, Loss: 0.314662
# (48, 6, 5, 5, 4)
# Model:  49
# 4m 3s
# Epoch: 9, Loss: 0.615642
# 4m 5s
# Epoch: 19, Loss: 0.418676
# 4m 7s
# Epoch: 29, Loss: 0.243891
# (49, 6, 6, 6, 4)
# Model:  50
# 4m 9s
# Epoch: 9, Loss: 0.735378
# 4m 11s
# Epoch: 19, Loss: 0.853178
# 4m 13s
# Epoch: 29, Loss: 0.715733
# (50, 5, 5, 6, 5)
# Model:  51
# 4m 15s
# Epoch: 9, Loss: 0.823162
# 4m 17s
# Epoch: 19, Loss: 0.393649
# 4m 19s
# Epoch: 29, Loss: 0.349939
# (51, 5, 2, 5, 5)
# Model:  52
# 4m 21s
# Epoch: 9, Loss: 0.548327
# 4m 23s
# Epoch: 19, Loss: 1.031532
# 4m 25s
# Epoch: 29, Loss: 0.434182
# (52, 5, 4, 6, 5)
# Model:  53
# 4m 27s
# Epoch: 9, Loss: 0.764143
# 4m 29s
# Epoch: 19, Loss: 0.864215
# 4m 31s
# Epoch: 29, Loss: 0.182892
# (53, 5, 4, 6, 3)
# Model:  54
# 4m 34s
# Epoch: 9, Loss: 0.996467
# 4m 36s
# Epoch: 19, Loss: 0.761920
# 4m 38s
# Epoch: 29, Loss: 0.694487
# (54, 5, 5, 7, 4)
# Model:  55
# 4m 40s
# Epoch: 9, Loss: 0.675865
# 4m 42s
# Epoch: 19, Loss: 0.324324
# 4m 44s
# Epoch: 29, Loss: 0.410695
# (55, 7, 6, 6, 3)
# Model:  56
# 4m 47s
# Epoch: 9, Loss: 0.650890
# 4m 49s
# Epoch: 19, Loss: 0.536034
# 4m 51s
# Epoch: 29, Loss: 0.615748
# (56, 5, 4, 5, 4)
# Model:  57
# 4m 53s
# Epoch: 9, Loss: 0.735604
# 4m 55s
# Epoch: 19, Loss: 0.374098
# 4m 57s
# Epoch: 29, Loss: 0.379744
# (57, 5, 4, 6, 5)
# Model:  58
# 5m 0s
# Epoch: 9, Loss: 0.621008
# 5m 2s
# Epoch: 19, Loss: 0.591954
# 5m 4s
# Epoch: 29, Loss: 0.707830
# (58, 5, 5, 6, 5)
# Model:  59
# 5m 6s
# Epoch: 9, Loss: 0.701343
# 5m 8s
# Epoch: 19, Loss: 0.463899
# 5m 10s
# Epoch: 29, Loss: 0.938104
# (59, 6, 6, 6, 6)
# Model:  60
# 5m 13s
# Epoch: 9, Loss: 0.728010
# 5m 15s
# Epoch: 19, Loss: 0.406241
# 5m 17s
# Epoch: 29, Loss: 0.345087
# (60, 5, 6, 6, 6)
# Model:  61
# 5m 20s
# Epoch: 9, Loss: 0.685798
# 5m 22s
# Epoch: 19, Loss: 0.575603
# 5m 24s
# Epoch: 29, Loss: 0.162215
# (61, 5, 4, 6, 5)
# Model:  62
# 5m 27s
# Epoch: 9, Loss: 0.630346
# 5m 29s
# Epoch: 19, Loss: 0.353502
# 5m 31s
# Epoch: 29, Loss: 0.547570
# (62, 5, 4, 6, 6)
# Model:  63
# 5m 34s
# Epoch: 9, Loss: 0.636371
# 5m 36s
# Epoch: 19, Loss: 0.562802
# 5m 38s
# Epoch: 29, Loss: 0.565847
# (63, 6, 3, 4, 5)
# Model:  64
# 5m 40s
# Epoch: 9, Loss: 0.563845
# 5m 43s
# Epoch: 19, Loss: 0.683194
# 5m 45s
# Epoch: 29, Loss: 0.335810
# (64, 6, 4, 7, 6)
# Model:  65
# 5m 47s
# Epoch: 9, Loss: 0.572364
# 5m 50s
# Epoch: 19, Loss: 1.259990
# 5m 52s
# Epoch: 29, Loss: 0.771456
# (65, 6, 4, 6, 5)
# Model:  66
# 5m 55s
# Epoch: 9, Loss: 0.402021
# 5m 57s
# Epoch: 19, Loss: 0.590759
# 5m 59s
# Epoch: 29, Loss: 0.856773
# (66, 5, 7, 5, 4)
# Model:  67
# 6m 2s
# Epoch: 9, Loss: 0.795028
# 6m 4s
# Epoch: 19, Loss: 0.383270
# 6m 6s
# Epoch: 29, Loss: 0.162382
# (67, 5, 4, 6, 5)
# Model:  68
# 6m 9s
# Epoch: 9, Loss: 0.643042
# 6m 11s
# Epoch: 19, Loss: 0.761682
# 6m 13s
# Epoch: 29, Loss: 0.563340
# (68, 5, 5, 5, 6)
# Model:  69
# 6m 16s
# Epoch: 9, Loss: 0.946562
# 6m 18s
# Epoch: 19, Loss: 0.833644
# 6m 21s
# Epoch: 29, Loss: 0.280277
# (69, 5, 5, 6, 5)
# Model:  70
# 6m 23s
# Epoch: 9, Loss: 0.847331
# 6m 26s
# Epoch: 19, Loss: 0.474007
# 6m 28s
# Epoch: 29, Loss: 0.199711
# (70, 7, 4, 6, 6)
# Model:  71
# 6m 31s
# Epoch: 9, Loss: 0.553650
# 6m 33s
# Epoch: 19, Loss: 0.616836
# 6m 35s
# Epoch: 29, Loss: 0.207122
# (71, 5, 4, 7, 4)
# Model:  72
# 6m 38s
# Epoch: 9, Loss: 0.341084
# 6m 41s
# Epoch: 19, Loss: 0.165091
# 6m 43s
# Epoch: 29, Loss: 1.302964
# (72, 6, 5, 5, 6)
# Model:  73
# 6m 46s
# Epoch: 9, Loss: 0.715255
# 6m 48s
# Epoch: 19, Loss: 0.441077
# 6m 50s
# Epoch: 29, Loss: 0.598802
# (73, 5, 5, 4, 5)
# Model:  74
# 6m 53s
# Epoch: 9, Loss: 0.690603
# 6m 55s
# Epoch: 19, Loss: 0.792653
# 6m 58s
# Epoch: 29, Loss: 0.822020
# (74, 4, 5, 5, 7)
# Model:  75
# 7m 0s
# Epoch: 9, Loss: 0.505904
# 7m 3s
# Epoch: 19, Loss: 0.734209
# 7m 5s
# Epoch: 29, Loss: 0.272149
# (75, 6, 7, 5, 5)
# Model:  76
# 7m 8s
# Epoch: 9, Loss: 0.530193
# 7m 10s
# Epoch: 19, Loss: 0.122483
# 7m 13s
# Epoch: 29, Loss: 0.612836
# (76, 5, 4, 5, 4)
# Model:  77
# 7m 16s
# Epoch: 9, Loss: 0.735348
# 7m 18s
# Epoch: 19, Loss: 0.229459
# 7m 20s
# Epoch: 29, Loss: 0.218890
# (77, 6, 5, 5, 4)
# Model:  78
# 7m 23s
# Epoch: 9, Loss: 0.674843
# 7m 26s
# Epoch: 19, Loss: 0.449168
# 7m 28s
# Epoch: 29, Loss: 0.325329
# (78, 5, 5, 5, 5)
# Model:  79
# 7m 31s
# Epoch: 9, Loss: 0.606902
# 7m 33s
# Epoch: 19, Loss: 0.342748
# 7m 36s
# Epoch: 29, Loss: 0.966498
# (79, 7, 5, 5, 6)
# Model:  80
# 7m 39s
# Epoch: 9, Loss: 0.908894
# 7m 41s
# Epoch: 19, Loss: 0.442706
# 7m 44s
# Epoch: 29, Loss: 0.904164
# (80, 6, 4, 7, 6)
# Model:  81
# 7m 47s
# Epoch: 9, Loss: 0.815704
# 7m 49s
# Epoch: 19, Loss: 0.260653
# 7m 52s
# Epoch: 29, Loss: 0.583097
# (81, 6, 4, 5, 6)
# Model:  82
# 7m 55s
# Epoch: 9, Loss: 0.453552
# 7m 57s
# Epoch: 19, Loss: 0.862251
# 8m 0s
# Epoch: 29, Loss: 1.443127
# (82, 6, 6, 5, 5)
# Model:  83
# 8m 2s
# Epoch: 9, Loss: 0.530640
# 8m 5s
# Epoch: 19, Loss: 0.416515
# 8m 8s
# Epoch: 29, Loss: 0.572380
# (83, 7, 6, 6, 5)
# Model:  84
# 8m 11s
# Epoch: 9, Loss: 0.993539
# 8m 13s
# Epoch: 19, Loss: 0.572738
# 8m 16s
# Epoch: 29, Loss: 0.781287
# (84, 5, 5, 5, 4)
# Model:  85
# 8m 19s
# Epoch: 9, Loss: 0.948910
# 8m 21s
# Epoch: 19, Loss: 0.772900
# 8m 24s
# Epoch: 29, Loss: 0.441136
# (85, 4, 5, 5, 4)
# Model:  86
# 8m 27s
# Epoch: 9, Loss: 0.454327
# 8m 30s
# Epoch: 19, Loss: 0.406294
# 8m 32s
# Epoch: 29, Loss: 0.294769
# (86, 7, 6, 5, 4)
# Model:  87
# 8m 35s
# Epoch: 9, Loss: 0.498103
# 8m 38s
# Epoch: 19, Loss: 0.819455
# 8m 41s
# Epoch: 29, Loss: 0.360597
# (87, 6, 4, 5, 5)
# Model:  88
# 8m 44s
# Epoch: 9, Loss: 0.644410
# 8m 47s
# Epoch: 19, Loss: 0.176605
# 8m 49s
# Epoch: 29, Loss: 0.566387
# (88, 5, 4, 5, 5)
# Model:  89
# 8m 52s
# Epoch: 9, Loss: 0.692710
# 8m 55s
# Epoch: 19, Loss: 0.805326
# 8m 58s
# Epoch: 29, Loss: 0.383969
# (89, 7, 5, 5, 5)
# Model:  90
# 9m 1s
# Epoch: 9, Loss: 0.786958
# 9m 3s
# Epoch: 19, Loss: 0.124899
# 9m 6s
# Epoch: 29, Loss: 1.027174
# (90, 4, 3, 5, 4)
# Model:  91
# 9m 9s
# Epoch: 9, Loss: 0.756036
# 9m 12s
# Epoch: 19, Loss: 0.937399
# 9m 15s
# Epoch: 29, Loss: 0.134900
# (91, 5, 5, 4, 5)
# Model:  92
# 9m 18s
# Epoch: 9, Loss: 0.631560
# 9m 20s
# Epoch: 19, Loss: 0.543598
# 9m 23s
# Epoch: 29, Loss: 0.189796
# (92, 5, 5, 5, 6)
# Model:  93
# 9m 26s
# Epoch: 9, Loss: 0.319748
# 9m 29s
# Epoch: 19, Loss: 0.444264
# 9m 32s
# Epoch: 29, Loss: 0.325623
# (93, 4, 5, 5, 5)
# Model:  94
# 9m 35s
# Epoch: 9, Loss: 0.488681
# 9m 38s
# Epoch: 19, Loss: 0.336729
# 9m 41s
# Epoch: 29, Loss: 0.455591
# (94, 6, 6, 5, 7)
# Model:  95
# 9m 44s
# Epoch: 9, Loss: 1.487823
# 9m 47s
# Epoch: 19, Loss: 0.415100
# 9m 49s
# Epoch: 29, Loss: 1.079109
# (95, 6, 6, 5, 5)
# Model:  96
# 9m 53s
# Epoch: 9, Loss: 0.781499
# 9m 55s
# Epoch: 19, Loss: 0.496220
# 9m 58s
# Epoch: 29, Loss: 0.520012
# (96, 5, 5, 5, 4)
# Model:  97
# 10m 1s
# Epoch: 9, Loss: 0.452895
# 10m 4s
# Epoch: 19, Loss: 0.138585
# 10m 7s
# Epoch: 29, Loss: 0.307983
# (97, 4, 5, 5, 3)
# Model:  98
# 10m 10s
# Epoch: 9, Loss: 0.344000
# 10m 13s
# Epoch: 19, Loss: 0.394807
# 10m 16s
# Epoch: 29, Loss: 0.983741
# (98, 4, 6, 6, 5)
# Model:  99
# 10m 19s
# Epoch: 9, Loss: 0.551666
# 10m 22s
# Epoch: 19, Loss: 1.065441
# 10m 25s
# Epoch: 29, Loss: 0.232948
# (99, 4, 6, 6, 7)
# Model:  100
# 10m 28s
# Epoch: 9, Loss: 1.223128
# 10m 31s
# Epoch: 19, Loss: 1.597881
# 10m 34s
# Epoch: 29, Loss: 0.801487
# (100, 4, 6, 5, 4)
# Model:  101
# 10m 37s
# Epoch: 9, Loss: 0.512752
# 10m 40s
# Epoch: 19, Loss: 1.019461
# 10m 43s
# Epoch: 29, Loss: 0.303447
# (101, 4, 7, 5, 6)
# Model:  102
# 10m 46s
# Epoch: 9, Loss: 0.302669
# 10m 49s
# Epoch: 19, Loss: 0.507005
# 10m 52s
# Epoch: 29, Loss: 1.310937
# (102, 4, 5, 6, 7)
# Model:  103
# 10m 55s
# Epoch: 9, Loss: 0.542903
# 10m 58s
# Epoch: 19, Loss: 0.412298
# 11m 1s
# Epoch: 29, Loss: 0.566081
# (103, 4, 6, 5, 7)
# Model:  104
# 11m 4s
# Epoch: 9, Loss: 0.470659
# 11m 7s
# Epoch: 19, Loss: 2.453062
# 11m 10s
# Epoch: 29, Loss: 0.615080
# (104, 5, 6, 6, 6)
# Model:  105
# 11m 14s
# Epoch: 9, Loss: 0.807776
# 11m 17s
# Epoch: 19, Loss: 0.260502
# 11m 20s
# Epoch: 29, Loss: 0.148996
# (105, 4, 6, 5, 7)
# Model:  106
# 11m 23s
# Epoch: 9, Loss: 0.304054
# 11m 26s
# Epoch: 19, Loss: 0.368796
# 11m 29s
# Epoch: 29, Loss: 0.756635
# (106, 6, 6, 5, 6)
# Model:  107
# 11m 32s
# Epoch: 9, Loss: 0.510387
# 11m 36s
# Epoch: 19, Loss: 0.369884
# 11m 39s
# Epoch: 29, Loss: 0.360168
# (107, 6, 6, 5, 6)
# Model:  108
# 11m 42s
# Epoch: 9, Loss: 1.012779
# 11m 45s
# Epoch: 19, Loss: 1.629045
# 11m 48s
# Epoch: 29, Loss: 0.275420
# (108, 6, 5, 5, 6)
# Model:  109
# 11m 51s
# Epoch: 9, Loss: 0.737017
# 11m 54s
# Epoch: 19, Loss: 0.358427
# 11m 58s
# Epoch: 29, Loss: 0.758668
# (109, 5, 4, 5, 6)
# Model:  110
# 12m 1s
# Epoch: 9, Loss: 0.853530
# 12m 4s
# Epoch: 19, Loss: 0.213524
# 12m 7s
# Epoch: 29, Loss: 0.082972
# (110, 5, 6, 7, 6)
# Model:  111
# 12m 10s
# Epoch: 9, Loss: 0.646896
# 12m 13s
# Epoch: 19, Loss: 2.313298
# 12m 16s
# Epoch: 29, Loss: 0.668453
# (111, 4, 5, 6, 5)
# Model:  112
# 12m 20s
# Epoch: 9, Loss: 0.919619
# 12m 23s
# Epoch: 19, Loss: 0.414454
# 12m 26s
# Epoch: 29, Loss: 0.305750
# (112, 4, 4, 6, 6)
# Model:  113
# 12m 30s
# Epoch: 9, Loss: 0.462638
# 12m 33s
# Epoch: 19, Loss: 0.436337
# 12m 36s
# Epoch: 29, Loss: 0.557200
# (113, 6, 6, 6, 6)
# Model:  114
# 12m 39s
# Epoch: 9, Loss: 0.449573
# 12m 42s
# Epoch: 19, Loss: 0.165614
# 12m 45s
# Epoch: 29, Loss: 0.559318
# (114, 6, 4, 6, 5)
# Model:  115
# 12m 49s
# Epoch: 9, Loss: 0.650873
# 12m 52s
# Epoch: 19, Loss: 0.446742
# 12m 55s
# Epoch: 29, Loss: 1.110023
# (115, 6, 6, 6, 6)
# Model:  116
# 12m 59s
# Epoch: 9, Loss: 0.740533
# 13m 2s
# Epoch: 19, Loss: 0.528607
# 13m 5s
# Epoch: 29, Loss: 0.955968
# (116, 6, 6, 6, 6)
# Model:  117
# 13m 9s
# Epoch: 9, Loss: 0.777524
# 13m 12s
# Epoch: 19, Loss: 1.469326
# 13m 15s
# Epoch: 29, Loss: 0.789321
# (117, 5, 5, 6, 5)
# Model:  118
# 13m 18s
# Epoch: 9, Loss: 0.631355
# 13m 22s
# Epoch: 19, Loss: 0.323902
# 13m 25s
# Epoch: 29, Loss: 0.823058
# (118, 6, 6, 6, 7)
# Model:  119
# 13m 28s
# Epoch: 9, Loss: 0.450937
# 13m 32s
# Epoch: 19, Loss: 0.649777
# 13m 35s
# Epoch: 29, Loss: 0.509791
# (119, 6, 5, 6, 7)
# Model:  120
# 13m 39s
# Epoch: 9, Loss: 0.766250
# 13m 42s
# Epoch: 19, Loss: 0.212487
# 13m 45s
# Epoch: 29, Loss: 0.372589
# (120, 6, 6, 6, 6)
# Model:  121
# 13m 49s
# Epoch: 9, Loss: 0.275970
# 13m 52s
# Epoch: 19, Loss: 0.361525
# 13m 55s
# Epoch: 29, Loss: 0.711932
# (121, 5, 6, 6, 5)
# Model:  122
# 13m 59s
# Epoch: 9, Loss: 1.033601
# 14m 2s
# Epoch: 19, Loss: 1.214969
# 14m 5s
# Epoch: 29, Loss: 0.377758
# (122, 5, 5, 6, 6)
# Model:  123
# 14m 9s
# Epoch: 9, Loss: 1.096588
# 14m 12s
# Epoch: 19, Loss: 1.039316
# 14m 15s
# Epoch: 29, Loss: 1.294151
# (123, 5, 4, 6, 6)
# Model:  124
# 14m 19s
# Epoch: 9, Loss: 0.938465
# 14m 22s
# Epoch: 19, Loss: 0.557989
# 14m 26s
# Epoch: 29, Loss: 0.297089
# (124, 5, 5, 6, 6)
# Model:  125
# 14m 29s
# Epoch: 9, Loss: 1.520943
# 14m 33s
# Epoch: 19, Loss: 0.335005
# 14m 36s
# Epoch: 29, Loss: 1.074545
# (125, 6, 6, 6, 6)
# Model:  126
# 14m 40s
# Epoch: 9, Loss: 1.134124
# 14m 43s
# Epoch: 19, Loss: 1.431196
# 14m 47s
# Epoch: 29, Loss: 0.461894
# (126, 5, 5, 6, 5)
# Model:  127
# 14m 50s
# Epoch: 9, Loss: 0.325762
# 14m 54s
# Epoch: 19, Loss: 0.796727
# 14m 57s
# Epoch: 29, Loss: 0.382321
# (127, 5, 3, 6, 6)
# Model:  128
# 15m 1s
# Epoch: 9, Loss: 0.480517
# 15m 4s
# Epoch: 19, Loss: 1.216220
# 15m 8s
# Epoch: 29, Loss: 0.252093
# (128, 6, 4, 6, 7)
# Model:  129
# 15m 12s
# Epoch: 9, Loss: 0.499093
# 15m 15s
# Epoch: 19, Loss: 0.615697
# 15m 19s
# Epoch: 29, Loss: 0.459702
# (129, 6, 5, 6, 6)
# Model:  130
# 15m 22s
# Epoch: 9, Loss: 0.613689
# 15m 26s
# Epoch: 19, Loss: 1.391882
# 15m 30s
# Epoch: 29, Loss: 0.463299
# (130, 5, 3, 6, 5)
# Model:  131
# 15m 33s
# Epoch: 9, Loss: 0.934792
# 15m 37s
# Epoch: 19, Loss: 0.416010
# 15m 41s
# Epoch: 29, Loss: 0.185750
# (131, 6, 5, 6, 5)
# Model:  132
# 15m 44s
# Epoch: 9, Loss: 1.144228
# 15m 48s
# Epoch: 19, Loss: 1.278151
# 15m 52s
# Epoch: 29, Loss: 0.984451
# (132, 7, 3, 6, 5)
# Model:  133
# 15m 55s
# Epoch: 9, Loss: 0.556839
# 15m 59s
# Epoch: 19, Loss: 1.399484
# 16m 3s
# Epoch: 29, Loss: 0.374484
# (133, 6, 6, 6, 6)
# Model:  134
# 16m 7s
# Epoch: 9, Loss: 0.653302
# 16m 10s
# Epoch: 19, Loss: 0.438398
# 16m 14s
# Epoch: 29, Loss: 0.427491
# (134, 5, 6, 6, 6)
# Model:  135
# 16m 18s
# Epoch: 9, Loss: 0.218484
# 16m 21s
# Epoch: 19, Loss: 0.582935
# 16m 25s
# Epoch: 29, Loss: 0.510799
# (135, 6, 7, 6, 6)
# Model:  136
# 16m 29s
# Epoch: 9, Loss: 0.540557
# 16m 32s
# Epoch: 19, Loss: 0.255886
# 16m 36s
# Epoch: 29, Loss: 0.123068
# (136, 6, 6, 7, 6)
# Model:  137
# 16m 40s
# Epoch: 9, Loss: 0.769087
# 16m 44s
# Epoch: 19, Loss: 0.212631
# 16m 48s
# Epoch: 29, Loss: 0.184880
# (137, 5, 6, 6, 5)
# Model:  138
# 16m 51s
# Epoch: 9, Loss: 0.563223
# 16m 55s
# Epoch: 19, Loss: 0.639071
# 16m 59s
# Epoch: 29, Loss: 0.517011
# (138, 5, 7, 7, 6)
# Model:  139
# 17m 3s
# Epoch: 9, Loss: 0.431023
# 17m 7s
# Epoch: 19, Loss: 0.211387
# 17m 10s
# Epoch: 29, Loss: 0.629026
# (139, 6, 5, 6, 5)
# Model:  140
# 17m 14s
# Epoch: 9, Loss: 0.869144
# 17m 18s
# Epoch: 19, Loss: 0.826249
# 17m 22s
# Epoch: 29, Loss: 0.215278
# (140, 4, 5, 6, 5)
# Model:  141
# 17m 26s
# Epoch: 9, Loss: 0.316481
# 17m 29s
# Epoch: 19, Loss: 0.651369
# 17m 33s
# Epoch: 29, Loss: 0.999161
# (141, 5, 5, 7, 5)
# Model:  142
# 17m 37s
# Epoch: 9, Loss: 0.601085
# 17m 41s
# Epoch: 19, Loss: 0.353010
# 17m 44s
# Epoch: 29, Loss: 0.681709
# (142, 5, 4, 6, 6)
# Model:  143
# 17m 49s
# Epoch: 9, Loss: 0.491641
# 17m 52s
# Epoch: 19, Loss: 0.222824
# 17m 56s
# Epoch: 29, Loss: 0.467153
# (143, 6, 5, 7, 6)
# Model:  144
# 18m 0s
# Epoch: 9, Loss: 0.733592
# 18m 4s
# Epoch: 19, Loss: 0.213869
# 18m 8s
# Epoch: 29, Loss: 0.900860
# (144, 6, 6, 8, 6)
# Model:  145
# 18m 12s
# Epoch: 9, Loss: 0.953231
# 18m 16s
# Epoch: 19, Loss: 0.478838
# 18m 19s
# Epoch: 29, Loss: 0.336595
# (145, 6, 4, 7, 6)
# Model:  146
# 18m 23s
# Epoch: 9, Loss: 0.691386
# 18m 27s
# Epoch: 19, Loss: 0.746133
# 18m 31s
# Epoch: 29, Loss: 0.539644
# (146, 6, 4, 6, 5)
# Model:  147
# 18m 35s
# Epoch: 9, Loss: 0.395495
# 18m 39s
# Epoch: 19, Loss: 0.592820
# 18m 43s
# Epoch: 29, Loss: 0.857586
# (147, 7, 4, 6, 5)
# Model:  148
# 18m 47s
# Epoch: 9, Loss: 0.325220
# 18m 51s
# Epoch: 19, Loss: 0.441919
# 18m 54s
# Epoch: 29, Loss: 0.790574
# (148, 7, 4, 7, 5)
# Model:  149
# 18m 59s
# Epoch: 9, Loss: 0.511096
# 19m 2s
# Epoch: 19, Loss: 0.762140
# 19m 6s
# Epoch: 29, Loss: 1.354025
# (149, 7, 4, 6, 6)
# Model:  150
# 19m 10s
# Epoch: 9, Loss: 0.974097
# 19m 14s
# Epoch: 19, Loss: 0.379372
# 19m 18s
# Epoch: 29, Loss: 0.322803
# (150, 6, 5, 6, 6)
# Model:  151
# 19m 22s
# Epoch: 9, Loss: 0.342733
# 19m 26s
# Epoch: 19, Loss: 0.846481
# 19m 30s
# Epoch: 29, Loss: 0.486342
# (151, 6, 6, 6, 5)
# Model:  152
# 19m 34s
# Epoch: 9, Loss: 0.765716
# 19m 38s
# Epoch: 19, Loss: 0.350240
# 19m 42s
# Epoch: 29, Loss: 0.210192
# (152, 7, 4, 6, 5)
# Model:  153
# 19m 46s
# Epoch: 9, Loss: 0.358985
# 19m 50s
# Epoch: 19, Loss: 0.115463
# 19m 54s
# Epoch: 29, Loss: 0.514511
# (153, 5, 6, 6, 5)
# Model:  154
# 19m 58s
# Epoch: 9, Loss: 0.340533
# 20m 2s
# Epoch: 19, Loss: 1.391803
# 20m 6s
# Epoch: 29, Loss: 0.493513
# (154, 6, 4, 7, 5)
# Model:  155
# 20m 10s
# Epoch: 9, Loss: 1.169933
# 20m 14s
# Epoch: 19, Loss: 0.315246
# 20m 18s
# Epoch: 29, Loss: 0.193694
# (155, 7, 6, 6, 5)
# Model:  156
# 20m 22s
# Epoch: 9, Loss: 0.693874
# 20m 26s
# Epoch: 19, Loss: 0.283975
# 20m 30s
# Epoch: 29, Loss: 0.313198
# (156, 7, 6, 6, 5)
# Model:  157
# 20m 34s
# Epoch: 9, Loss: 0.471700
# 20m 38s
# Epoch: 19, Loss: 0.804372
# 20m 42s
# Epoch: 29, Loss: 0.103770
# (157, 7, 5, 6, 5)
# Model:  158
# 20m 47s
# Epoch: 9, Loss: 0.984258
# 20m 51s
# Epoch: 19, Loss: 0.285494
# 20m 55s
# Epoch: 29, Loss: 0.615128
# (158, 7, 6, 7, 5)
# Model:  159
# 20m 59s
# Epoch: 9, Loss: 0.465539
# 21m 3s
# Epoch: 19, Loss: 0.894292
# 21m 7s
# Epoch: 29, Loss: 0.786289
# (159, 6, 4, 6, 5)
# Model:  160
# 21m 12s
# Epoch: 9, Loss: 0.427174
# 21m 16s
# Epoch: 19, Loss: 0.804016
# 21m 20s
# Epoch: 29, Loss: 0.286956
# (160, 7, 6, 6, 5)
# Model:  161
# 21m 24s
# Epoch: 9, Loss: 0.132037
# 21m 29s
# Epoch: 19, Loss: 0.494043
# 21m 33s
# Epoch: 29, Loss: 1.443403
# (161, 6, 6, 7, 6)
# Model:  162
# 21m 37s
# Epoch: 9, Loss: 0.495181
# 21m 41s
# Epoch: 19, Loss: 0.409809
# 21m 46s
# Epoch: 29, Loss: 0.267634
# (162, 6, 5, 7, 7)
# 21m 46s
# Run 27
# 163 163
# Model:  0
# 0m 14s
# Epoch: 9, Loss: 0.644334
# 0m 15s
# Epoch: 19, Loss: 0.743908
# 0m 16s
# Epoch: 29, Loss: 0.220807
# (0, 5, 5, 5, 5)
# Model:  1
# 0m 17s
# Epoch: 9, Loss: 0.585919
# 0m 18s
# Epoch: 19, Loss: 0.575643
# 0m 19s
# Epoch: 29, Loss: 0.374537
# (1, 6, 7, 5, 5)
# Model:  2
# 0m 20s
# Epoch: 9, Loss: 0.684066
# 0m 21s
# Epoch: 19, Loss: 0.621706
# 0m 22s
# Epoch: 29, Loss: 0.380961
# (2, 4, 7, 5, 5)
# Model:  3
# 0m 24s
# Epoch: 9, Loss: 0.639087
# 0m 25s
# Epoch: 19, Loss: 0.729091
# 0m 26s
# Epoch: 29, Loss: 0.470283
# (3, 5, 6, 7, 5)
# Model:  4
# 0m 27s
# Epoch: 9, Loss: 0.628346
# 0m 28s
# Epoch: 19, Loss: 0.653553
# 0m 29s
# Epoch: 29, Loss: 0.673778
# (4, 7, 6, 7, 5)
# Model:  5
# 0m 30s
# Epoch: 9, Loss: 0.642811
# 0m 32s
# Epoch: 19, Loss: 0.745610
# 0m 33s
# Epoch: 29, Loss: 0.774094
# (5, 5, 4, 6, 5)
# Model:  6
# 0m 34s
# Epoch: 9, Loss: 0.677160
# 0m 35s
# Epoch: 19, Loss: 0.610549
# 0m 36s
# Epoch: 29, Loss: 0.419849
# (6, 5, 6, 5, 5)
# Model:  7
# 0m 38s
# Epoch: 9, Loss: 0.754607
# 0m 39s
# Epoch: 19, Loss: 0.544040
# 0m 40s
# Epoch: 29, Loss: 0.869434
# (7, 5, 4, 4, 5)
# Model:  8
# 0m 41s
# Epoch: 9, Loss: 0.662055
# 0m 42s
# Epoch: 19, Loss: 0.862333
# 0m 43s
# Epoch: 29, Loss: 0.232349
# (8, 5, 6, 5, 4)
# Model:  9
# 0m 45s
# Epoch: 9, Loss: 0.743172
# 0m 46s
# Epoch: 19, Loss: 0.594751
# 0m 47s
# Epoch: 29, Loss: 0.510141
# (9, 4, 5, 5, 5)
# Model:  10
# 0m 48s
# Epoch: 9, Loss: 0.743794
# 0m 50s
# Epoch: 19, Loss: 0.530207
# 0m 51s
# Epoch: 29, Loss: 0.304183
# (10, 5, 4, 7, 4)
# Model:  11
# 0m 52s
# Epoch: 9, Loss: 0.666564
# 0m 53s
# Epoch: 19, Loss: 0.573702
# 0m 55s
# Epoch: 29, Loss: 0.288498
# (11, 7, 4, 6, 4)
# Model:  12
# 0m 56s
# Epoch: 9, Loss: 0.776847
# 0m 57s
# Epoch: 19, Loss: 0.235977
# 0m 58s
# Epoch: 29, Loss: 0.609295
# (12, 4, 6, 6, 5)
# Model:  13
# 1m 0s
# Epoch: 9, Loss: 0.614492
# 1m 1s
# Epoch: 19, Loss: 0.564545
# 1m 2s
# Epoch: 29, Loss: 0.162672
# (13, 4, 3, 6, 5)
# Model:  14
# 1m 4s
# Epoch: 9, Loss: 0.651373
# 1m 5s
# Epoch: 19, Loss: 0.537849
# 1m 6s
# Epoch: 29, Loss: 0.636473
# (14, 5, 5, 6, 6)
# Model:  15
# 1m 8s
# Epoch: 9, Loss: 0.512245
# 1m 9s
# Epoch: 19, Loss: 0.573576
# 1m 10s
# Epoch: 29, Loss: 0.421937
# (15, 5, 6, 5, 6)
# Model:  16
# 1m 12s
# Epoch: 9, Loss: 0.766536
# 1m 13s
# Epoch: 19, Loss: 0.661677
# 1m 15s
# Epoch: 29, Loss: 0.752465
# (16, 4, 4, 5, 5)
# Model:  17
# 1m 16s
# Epoch: 9, Loss: 0.757954
# 1m 17s
# Epoch: 19, Loss: 0.760371
# 1m 19s
# Epoch: 29, Loss: 0.528679
# (17, 5, 5, 6, 5)
# Model:  18
# 1m 20s
# Epoch: 9, Loss: 0.679259
# 1m 22s
# Epoch: 19, Loss: 0.732490
# 1m 23s
# Epoch: 29, Loss: 0.214892
# (18, 6, 5, 5, 4)
# Model:  19
# 1m 25s
# Epoch: 9, Loss: 0.665013
# 1m 26s
# Epoch: 19, Loss: 0.625844
# 1m 27s
# Epoch: 29, Loss: 1.162411
# (19, 5, 3, 5, 5)
# Model:  20
# 1m 29s
# Epoch: 9, Loss: 0.513431
# 1m 30s
# Epoch: 19, Loss: 0.271595
# 1m 31s
# Epoch: 29, Loss: 2.155240
# (20, 6, 4, 5, 5)
# Model:  21
# 1m 33s
# Epoch: 9, Loss: 0.577882
# 1m 34s
# Epoch: 19, Loss: 0.782358
# 1m 36s
# Epoch: 29, Loss: 0.802313
# (21, 5, 6, 5, 4)
# Model:  22
# 1m 37s
# Epoch: 9, Loss: 0.768303
# 1m 39s
# Epoch: 19, Loss: 0.297862
# 1m 40s
# Epoch: 29, Loss: 0.298113
# (22, 5, 4, 5, 3)
# Model:  23
# 1m 42s
# Epoch: 9, Loss: 0.605390
# 1m 43s
# Epoch: 19, Loss: 0.442274
# 1m 45s
# Epoch: 29, Loss: 0.440023
# (23, 4, 5, 4, 5)
# Model:  24
# 1m 46s
# Epoch: 9, Loss: 0.746457
# 1m 48s
# Epoch: 19, Loss: 0.520922
# 1m 49s
# Epoch: 29, Loss: 0.558066
# (24, 4, 4, 6, 5)
# Model:  25
# 1m 51s
# Epoch: 9, Loss: 0.692845
# 1m 52s
# Epoch: 19, Loss: 0.606281
# 1m 54s
# Epoch: 29, Loss: 0.244430
# (25, 4, 4, 5, 6)
# Model:  26
# 1m 56s
# Epoch: 9, Loss: 0.745065
# 1m 57s
# Epoch: 19, Loss: 0.496336
# 1m 58s
# Epoch: 29, Loss: 0.314586
# (26, 7, 3, 6, 5)
# Model:  27
# 2m 0s
# Epoch: 9, Loss: 0.474831
# 2m 2s
# Epoch: 19, Loss: 0.694284
# 2m 3s
# Epoch: 29, Loss: 0.347944
# (27, 5, 3, 4, 4)
# Model:  28
# 2m 5s
# Epoch: 9, Loss: 0.765779
# 2m 6s
# Epoch: 19, Loss: 0.608569
# 2m 8s
# Epoch: 29, Loss: 0.571253
# (28, 5, 3, 5, 6)
# Model:  29
# 2m 10s
# Epoch: 9, Loss: 0.515466
# 2m 11s
# Epoch: 19, Loss: 0.706308
# 2m 13s
# Epoch: 29, Loss: 0.279772
# (29, 5, 6, 5, 5)
# Model:  30
# 2m 14s
# Epoch: 9, Loss: 0.533095
# 2m 16s
# Epoch: 19, Loss: 0.443186
# 2m 17s
# Epoch: 29, Loss: 0.642358
# (30, 7, 6, 5, 5)
# Model:  31
# 2m 19s
# Epoch: 9, Loss: 0.639108
# 2m 21s
# Epoch: 19, Loss: 0.359362
# 2m 22s
# Epoch: 29, Loss: 0.283384
# (31, 7, 4, 6, 5)
# Model:  32
# 2m 24s
# Epoch: 9, Loss: 0.658695
# 2m 26s
# Epoch: 19, Loss: 0.177535
# 2m 27s
# Epoch: 29, Loss: 1.585821
# (32, 6, 5, 4, 4)
# Model:  33
# 2m 29s
# Epoch: 9, Loss: 0.783640
# 2m 31s
# Epoch: 19, Loss: 0.359000
# 2m 32s
# Epoch: 29, Loss: 0.386485
# (33, 6, 4, 6, 5)
# Model:  34
# 2m 34s
# Epoch: 9, Loss: 0.708286
# 2m 36s
# Epoch: 19, Loss: 0.534517
# 2m 38s
# Epoch: 29, Loss: 0.383581
# (34, 6, 3, 6, 5)
# Model:  35
# 2m 40s
# Epoch: 9, Loss: 0.808923
# 2m 41s
# Epoch: 19, Loss: 0.260748
# 2m 43s
# Epoch: 29, Loss: 0.420633
# (35, 5, 4, 4, 5)
# Model:  36
# 2m 45s
# Epoch: 9, Loss: 0.725656
# 2m 46s
# Epoch: 19, Loss: 0.530960
# 2m 48s
# Epoch: 29, Loss: 0.522544
# (36, 6, 5, 5, 5)
# Model:  37
# 2m 50s
# Epoch: 9, Loss: 0.724793
# 2m 52s
# Epoch: 19, Loss: 0.421046
# 2m 54s
# Epoch: 29, Loss: 0.680113
# (37, 6, 6, 5, 5)
# Model:  38
# 2m 56s
# Epoch: 9, Loss: 0.475034
# 2m 57s
# Epoch: 19, Loss: 0.135379
# 2m 59s
# Epoch: 29, Loss: 0.206096
# (38, 6, 6, 6, 5)
# Model:  39
# 3m 1s
# Epoch: 9, Loss: 0.449170
# 3m 3s
# Epoch: 19, Loss: 0.470401
# 3m 5s
# Epoch: 29, Loss: 0.567646
# (39, 5, 4, 5, 3)
# Model:  40
# 3m 7s
# Epoch: 9, Loss: 0.682922
# 3m 8s
# Epoch: 19, Loss: 0.329463
# 3m 10s
# Epoch: 29, Loss: 0.407128
# (40, 5, 5, 6, 3)
# Model:  41
# 3m 12s
# Epoch: 9, Loss: 0.633983
# 3m 14s
# Epoch: 19, Loss: 0.364675
# 3m 16s
# Epoch: 29, Loss: 1.463979
# (41, 5, 6, 5, 4)
# Model:  42
# 3m 18s
# Epoch: 9, Loss: 0.702199
# 3m 20s
# Epoch: 19, Loss: 0.483715
# 3m 21s
# Epoch: 29, Loss: 0.401974
# (42, 5, 5, 5, 5)
# Model:  43
# 3m 23s
# Epoch: 9, Loss: 0.577141
# 3m 25s
# Epoch: 19, Loss: 0.553077
# 3m 27s
# Epoch: 29, Loss: 0.653184
# (43, 5, 5, 6, 6)
# Model:  44
# 3m 29s
# Epoch: 9, Loss: 0.650956
# 3m 31s
# Epoch: 19, Loss: 0.747729
# 3m 33s
# Epoch: 29, Loss: 0.306426
# (44, 5, 4, 4, 5)
# Model:  45
# 3m 35s
# Epoch: 9, Loss: 0.777433
# 3m 37s
# Epoch: 19, Loss: 0.544637
# 3m 39s
# Epoch: 29, Loss: 0.481663
# (45, 5, 5, 4, 5)
# Model:  46
# 3m 41s
# Epoch: 9, Loss: 0.632612
# 3m 43s
# Epoch: 19, Loss: 0.390211
# 3m 45s
# Epoch: 29, Loss: 0.208711
# (46, 6, 4, 5, 5)
# Model:  47
# 3m 47s
# Epoch: 9, Loss: 0.595479
# 3m 49s
# Epoch: 19, Loss: 0.538874
# 3m 51s
# Epoch: 29, Loss: 0.398605
# (47, 6, 5, 4, 4)
# Model:  48
# 3m 53s
# Epoch: 9, Loss: 0.706500
# 3m 55s
# Epoch: 19, Loss: 0.653942
# 3m 57s
# Epoch: 29, Loss: 0.750606
# (48, 6, 5, 5, 5)
# Model:  49
# 3m 59s
# Epoch: 9, Loss: 0.323311
# 4m 1s
# Epoch: 19, Loss: 0.570349
# 4m 3s
# Epoch: 29, Loss: 0.762019
# (49, 5, 6, 5, 4)
# Model:  50
# 4m 5s
# Epoch: 9, Loss: 0.667640
# 4m 7s
# Epoch: 19, Loss: 0.329973
# 4m 9s
# Epoch: 29, Loss: 0.785643
# (50, 5, 4, 5, 5)
# Model:  51
# 4m 11s
# Epoch: 9, Loss: 0.521640
# 4m 13s
# Epoch: 19, Loss: 0.929641
# 4m 15s
# Epoch: 29, Loss: 1.363912
# (51, 5, 5, 5, 4)
# Model:  52
# 4m 17s
# Epoch: 9, Loss: 0.561259
# 4m 19s
# Epoch: 19, Loss: 0.286171
# 4m 21s
# Epoch: 29, Loss: 0.464860
# (52, 5, 5, 5, 5)
# Model:  53
# 4m 23s
# Epoch: 9, Loss: 0.445469
# 4m 25s
# Epoch: 19, Loss: 0.396087
# 4m 27s
# Epoch: 29, Loss: 0.635929
# (53, 6, 5, 5, 4)
# Model:  54
# 4m 30s
# Epoch: 9, Loss: 0.816778
# 4m 32s
# Epoch: 19, Loss: 0.919433
# 4m 34s
# Epoch: 29, Loss: 0.748006
# (54, 5, 5, 5, 5)
# Model:  55
# 4m 36s
# Epoch: 9, Loss: 0.539686
# 4m 38s
# Epoch: 19, Loss: 0.885510
# 4m 40s
# Epoch: 29, Loss: 0.752136
# (55, 5, 4, 6, 4)
# Model:  56
# 4m 42s
# Epoch: 9, Loss: 0.569682
# 4m 44s
# Epoch: 19, Loss: 1.109083
# 4m 46s
# Epoch: 29, Loss: 0.692568
# (56, 5, 5, 5, 5)
# Model:  57
# 4m 49s
# Epoch: 9, Loss: 0.588204
# 4m 51s
# Epoch: 19, Loss: 0.555064
# 4m 53s
# Epoch: 29, Loss: 0.324969
# (57, 5, 5, 5, 5)
# Model:  58
# 4m 55s
# Epoch: 9, Loss: 0.439747
# 4m 57s
# Epoch: 19, Loss: 0.616033
# 5m 0s
# Epoch: 29, Loss: 0.565694
# (58, 6, 5, 7, 4)
# Model:  59
# 5m 2s
# Epoch: 9, Loss: 0.553941
# 5m 4s
# Epoch: 19, Loss: 0.832973
# 5m 6s
# Epoch: 29, Loss: 1.283357
# (59, 5, 5, 7, 5)
# Model:  60
# 5m 8s
# Epoch: 9, Loss: 0.681038
# 5m 11s
# Epoch: 19, Loss: 1.445784
# 5m 13s
# Epoch: 29, Loss: 1.088904
# (60, 6, 6, 6, 5)
# Model:  61
# 5m 15s
# Epoch: 9, Loss: 0.502404
# 5m 17s
# Epoch: 19, Loss: 0.449877
# 5m 19s
# Epoch: 29, Loss: 0.437088
# (61, 6, 4, 7, 5)
# Model:  62
# 5m 22s
# Epoch: 9, Loss: 0.405881
# 5m 24s
# Epoch: 19, Loss: 1.099322
# 5m 26s
# Epoch: 29, Loss: 0.677268
# (62, 5, 6, 7, 4)
# Model:  63
# 5m 29s
# Epoch: 9, Loss: 0.403421
# 5m 31s
# Epoch: 19, Loss: 0.668309
# 5m 33s
# Epoch: 29, Loss: 0.158214
# (63, 6, 3, 7, 5)
# Model:  64
# 5m 35s
# Epoch: 9, Loss: 0.669414
# 5m 38s
# Epoch: 19, Loss: 0.883656
# 5m 40s
# Epoch: 29, Loss: 0.526363
# (64, 5, 5, 7, 5)
# Model:  65
# 5m 42s
# Epoch: 9, Loss: 0.643450
# 5m 45s
# Epoch: 19, Loss: 0.282803
# 5m 47s
# Epoch: 29, Loss: 0.807132
# (65, 4, 4, 5, 5)
# Model:  66
# 5m 49s
# Epoch: 9, Loss: 0.802560
# 5m 52s
# Epoch: 19, Loss: 0.385080
# 5m 54s
# Epoch: 29, Loss: 0.191399
# (66, 6, 7, 6, 5)
# Model:  67
# 5m 56s
# Epoch: 9, Loss: 0.974989
# 5m 59s
# Epoch: 19, Loss: 0.082360
# 6m 1s
# Epoch: 29, Loss: 0.281863
# (67, 7, 4, 6, 5)
# Model:  68
# 6m 3s
# Epoch: 9, Loss: 0.545923
# 6m 6s
# Epoch: 19, Loss: 0.183819
# 6m 8s
# Epoch: 29, Loss: 0.396585
# (68, 6, 5, 7, 6)
# Model:  69
# 6m 11s
# Epoch: 9, Loss: 0.588315
# 6m 13s
# Epoch: 19, Loss: 0.541272
# 6m 15s
# Epoch: 29, Loss: 0.846336
# (69, 6, 5, 6, 5)
# Model:  70
# 6m 18s
# Epoch: 9, Loss: 0.499942
# 6m 20s
# Epoch: 19, Loss: 0.571535
# 6m 22s
# Epoch: 29, Loss: 0.325569
# (70, 5, 5, 7, 6)
# Model:  71
# 6m 25s
# Epoch: 9, Loss: 0.794953
# 6m 27s
# Epoch: 19, Loss: 0.325293
# 6m 30s
# Epoch: 29, Loss: 0.220198
# (71, 6, 5, 5, 5)
# Model:  72
# 6m 32s
# Epoch: 9, Loss: 0.454441
# 6m 35s
# Epoch: 19, Loss: 0.477977
# 6m 37s
# Epoch: 29, Loss: 0.085371
# (72, 5, 5, 6, 5)
# Model:  73
# 6m 40s
# Epoch: 9, Loss: 0.577269
# 6m 42s
# Epoch: 19, Loss: 0.709788
# 6m 44s
# Epoch: 29, Loss: 1.472456
# (73, 5, 4, 6, 5)
# Model:  74
# 6m 47s
# Epoch: 9, Loss: 0.639587
# 6m 49s
# Epoch: 19, Loss: 0.529263
# 6m 52s
# Epoch: 29, Loss: 0.307805
# (74, 5, 3, 5, 7)
# Model:  75
# 6m 55s
# Epoch: 9, Loss: 0.849962
# 6m 57s
# Epoch: 19, Loss: 0.550079
# 6m 59s
# Epoch: 29, Loss: 0.315466
# (75, 5, 6, 6, 7)
# Model:  76
# 7m 2s
# Epoch: 9, Loss: 0.459377
# 7m 5s
# Epoch: 19, Loss: 0.579749
# 7m 7s
# Epoch: 29, Loss: 0.662340
# (76, 6, 4, 5, 6)
# Model:  77
# 7m 10s
# Epoch: 9, Loss: 0.612137
# 7m 12s
# Epoch: 19, Loss: 0.612218
# 7m 15s
# Epoch: 29, Loss: 0.878880
# (77, 6, 5, 7, 5)
# Model:  78
# 7m 17s
# Epoch: 9, Loss: 0.563543
# 7m 20s
# Epoch: 19, Loss: 0.476213
# 7m 22s
# Epoch: 29, Loss: 0.398080
# (78, 4, 4, 4, 4)
# Model:  79
# 7m 25s
# Epoch: 9, Loss: 0.631114
# 7m 28s
# Epoch: 19, Loss: 0.716360
# 7m 30s
# Epoch: 29, Loss: 0.969910
# (79, 5, 5, 5, 5)
# Model:  80
# 7m 33s
# Epoch: 9, Loss: 0.521619
# 7m 35s
# Epoch: 19, Loss: 0.626503
# 7m 38s
# Epoch: 29, Loss: 0.325653
# (80, 7, 4, 5, 5)
# Model:  81
# 7m 41s
# Epoch: 9, Loss: 0.719039
# 7m 43s
# Epoch: 19, Loss: 0.266985
# 7m 46s
# Epoch: 29, Loss: 0.531321
# (81, 5, 4, 5, 6)
# Model:  82
# 7m 49s
# Epoch: 9, Loss: 0.868087
# 7m 51s
# Epoch: 19, Loss: 0.862316
# 7m 54s
# Epoch: 29, Loss: 0.422832
# (82, 7, 3, 5, 5)
# Model:  83
# 7m 57s
# Epoch: 9, Loss: 0.702527
# 7m 59s
# Epoch: 19, Loss: 0.563169
# 8m 2s
# Epoch: 29, Loss: 0.820510
# (83, 5, 4, 7, 4)
# Model:  84
# 8m 5s
# Epoch: 9, Loss: 0.689998
# 8m 8s
# Epoch: 19, Loss: 0.619428
# 8m 10s
# Epoch: 29, Loss: 0.533164
# (84, 6, 5, 6, 5)
# Model:  85
# 8m 13s
# Epoch: 9, Loss: 0.550060
# 8m 16s
# Epoch: 19, Loss: 0.445634
# 8m 18s
# Epoch: 29, Loss: 0.227013
# (85, 7, 5, 6, 4)
# Model:  86
# 8m 21s
# Epoch: 9, Loss: 0.556737
# 8m 24s
# Epoch: 19, Loss: 0.944231
# 8m 27s
# Epoch: 29, Loss: 0.429821
# (86, 6, 5, 5, 6)
# Model:  87
# 8m 30s
# Epoch: 9, Loss: 0.818356
# 8m 33s
# Epoch: 19, Loss: 0.169126
# 8m 35s
# Epoch: 29, Loss: 0.338622
# (87, 6, 3, 5, 4)
# Model:  88
# 8m 38s
# Epoch: 9, Loss: 0.740298
# 8m 41s
# Epoch: 19, Loss: 0.135026
# 8m 44s
# Epoch: 29, Loss: 0.498978
# (88, 6, 5, 5, 5)
# Model:  89
# 8m 47s
# Epoch: 9, Loss: 0.678033
# 8m 50s
# Epoch: 19, Loss: 0.505990
# 8m 52s
# Epoch: 29, Loss: 1.125606
# (89, 5, 4, 5, 6)
# Model:  90
# 8m 55s
# Epoch: 9, Loss: 0.701039
# 8m 58s
# Epoch: 19, Loss: 0.982104
# 9m 1s
# Epoch: 29, Loss: 0.398429
# (90, 6, 4, 5, 6)
# Model:  91
# 9m 4s
# Epoch: 9, Loss: 0.824825
# 9m 7s
# Epoch: 19, Loss: 0.748228
# 9m 9s
# Epoch: 29, Loss: 0.288424
# (91, 6, 3, 4, 4)
# Model:  92
# 9m 12s
# Epoch: 9, Loss: 0.300185
# 9m 15s
# Epoch: 19, Loss: 1.809767
# 9m 18s
# Epoch: 29, Loss: 0.314162
# (92, 4, 4, 6, 6)
# Model:  93
# 9m 21s
# Epoch: 9, Loss: 0.493635
# 9m 24s
# Epoch: 19, Loss: 0.920865
# 9m 27s
# Epoch: 29, Loss: 0.320263
# (93, 6, 4, 5, 6)
# Model:  94
# 9m 30s
# Epoch: 9, Loss: 0.290828
# 9m 33s
# Epoch: 19, Loss: 0.211078
# 9m 36s
# Epoch: 29, Loss: 0.572654
# (94, 6, 6, 4, 6)
# Model:  95
# 9m 39s
# Epoch: 9, Loss: 0.391732
# 9m 42s
# Epoch: 19, Loss: 0.089374
# 9m 44s
# Epoch: 29, Loss: 0.806361
# (95, 6, 5, 6, 6)
# Model:  96
# 9m 48s
# Epoch: 9, Loss: 0.621169
# 9m 50s
# Epoch: 19, Loss: 0.404286
# 9m 53s
# Epoch: 29, Loss: 0.638503
# (96, 4, 4, 5, 5)
# Model:  97
# 9m 57s
# Epoch: 9, Loss: 0.337128
# 10m 0s
# Epoch: 19, Loss: 0.116850
# 10m 2s
# Epoch: 29, Loss: 0.383050
# (97, 5, 4, 5, 4)
# Model:  98
# 10m 6s
# Epoch: 9, Loss: 0.367825
# 10m 8s
# Epoch: 19, Loss: 0.229416
# 10m 11s
# Epoch: 29, Loss: 0.340950
# (98, 5, 6, 5, 4)
# Model:  99
# 10m 14s
# Epoch: 9, Loss: 0.442134
# 10m 17s
# Epoch: 19, Loss: 0.140228
# 10m 20s
# Epoch: 29, Loss: 1.060994
# (99, 4, 5, 5, 5)
# Model:  100
# 10m 23s
# Epoch: 9, Loss: 0.469689
# 10m 26s
# Epoch: 19, Loss: 0.434195
# 10m 29s
# Epoch: 29, Loss: 1.645455
# (100, 4, 6, 6, 6)
# Model:  101
# 10m 32s
# Epoch: 9, Loss: 0.547963
# 10m 35s
# Epoch: 19, Loss: 0.287438
# 10m 38s
# Epoch: 29, Loss: 1.433855
# (101, 5, 6, 6, 4)
# Model:  102
# 10m 42s
# Epoch: 9, Loss: 0.705351
# 10m 45s
# Epoch: 19, Loss: 0.379819
# 10m 48s
# Epoch: 29, Loss: 0.449853
# (102, 4, 4, 6, 6)
# Model:  103
# 10m 51s
# Epoch: 9, Loss: 0.851349
# 10m 54s
# Epoch: 19, Loss: 0.875411
# 10m 57s
# Epoch: 29, Loss: 0.646814
# (103, 5, 5, 5, 6)
# Model:  104
# 11m 0s
# Epoch: 9, Loss: 0.780479
# 11m 3s
# Epoch: 19, Loss: 0.210765
# 11m 6s
# Epoch: 29, Loss: 0.117826
# (104, 4, 5, 5, 6)
# Model:  105
# 11m 10s
# Epoch: 9, Loss: 0.556858
# 11m 13s
# Epoch: 19, Loss: 1.007264
# 11m 16s
# Epoch: 29, Loss: 0.400925
# (105, 5, 6, 5, 6)
# Model:  106
# 11m 19s
# Epoch: 9, Loss: 0.313533
# 11m 22s
# Epoch: 19, Loss: 0.563673
# 11m 25s
# Epoch: 29, Loss: 0.166437
# (106, 7, 6, 5, 5)
# Model:  107
# 11m 28s
# Epoch: 9, Loss: 0.450658
# 11m 31s
# Epoch: 19, Loss: 0.352707
# 11m 34s
# Epoch: 29, Loss: 0.341408
# (107, 5, 7, 6, 5)
# Model:  108
# 11m 38s
# Epoch: 9, Loss: 0.415671
# 11m 41s
# Epoch: 19, Loss: 0.889235
# 11m 44s
# Epoch: 29, Loss: 0.101844
# (108, 5, 7, 5, 5)
# Model:  109
# 11m 47s
# Epoch: 9, Loss: 0.328138
# 11m 50s
# Epoch: 19, Loss: 0.703823
# 11m 53s
# Epoch: 29, Loss: 0.212349
# (109, 6, 6, 5, 6)
# Model:  110
# 11m 57s
# Epoch: 9, Loss: 0.699155
# 12m 0s
# Epoch: 19, Loss: 0.671376
# 12m 3s
# Epoch: 29, Loss: 0.192318
# (110, 5, 4, 5, 6)
# Model:  111
# 12m 6s
# Epoch: 9, Loss: 0.509014
# 12m 10s
# Epoch: 19, Loss: 1.391946
# 12m 13s
# Epoch: 29, Loss: 0.205989
# (111, 5, 7, 6, 5)
# Model:  112
# 12m 16s
# Epoch: 9, Loss: 0.434146
# 12m 19s
# Epoch: 19, Loss: 0.860973
# 12m 22s
# Epoch: 29, Loss: 0.212584
# (112, 6, 6, 6, 5)
# Model:  113
# 12m 26s
# Epoch: 9, Loss: 0.687081
# 12m 29s
# Epoch: 19, Loss: 0.586233
# 12m 32s
# Epoch: 29, Loss: 1.046429
# (113, 5, 6, 5, 4)
# Model:  114
# 12m 36s
# Epoch: 9, Loss: 0.563597
# 12m 39s
# Epoch: 19, Loss: 0.617483
# 12m 42s
# Epoch: 29, Loss: 0.775801
# (114, 6, 5, 5, 5)
# Model:  115
# 12m 45s
# Epoch: 9, Loss: 0.983025
# 12m 49s
# Epoch: 19, Loss: 0.641216
# 12m 52s
# Epoch: 29, Loss: 0.306846
# (115, 6, 7, 5, 6)
# Model:  116
# 12m 55s
# Epoch: 9, Loss: 0.846190
# 12m 59s
# Epoch: 19, Loss: 0.249360
# 13m 2s
# Epoch: 29, Loss: 0.451161
# (116, 6, 6, 5, 5)
# Model:  117
# 13m 6s
# Epoch: 9, Loss: 1.083000
# 13m 9s
# Epoch: 19, Loss: 0.121567
# 13m 12s
# Epoch: 29, Loss: 0.255836
# (117, 6, 6, 6, 6)
# Model:  118
# 13m 16s
# Epoch: 9, Loss: 0.242597
# 13m 19s
# Epoch: 19, Loss: 0.297382
# 13m 22s
# Epoch: 29, Loss: 1.256351
# (118, 6, 4, 6, 7)
# Model:  119
# 13m 26s
# Epoch: 9, Loss: 0.888410
# 13m 29s
# Epoch: 19, Loss: 0.333310
# 13m 32s
# Epoch: 29, Loss: 0.567864
# (119, 6, 6, 6, 5)
# Model:  120
# 13m 36s
# Epoch: 9, Loss: 0.900448
# 13m 39s
# Epoch: 19, Loss: 1.019964
# 13m 43s
# Epoch: 29, Loss: 0.445955
# (120, 5, 4, 6, 5)
# Model:  121
# 13m 46s
# Epoch: 9, Loss: 0.405937
# 13m 50s
# Epoch: 19, Loss: 0.278889
# 13m 53s
# Epoch: 29, Loss: 1.733120
# (121, 6, 7, 5, 5)
# Model:  122
# 13m 57s
# Epoch: 9, Loss: 0.593714
# 14m 0s
# Epoch: 19, Loss: 0.523594
# 14m 4s
# Epoch: 29, Loss: 0.351144
# (122, 6, 5, 6, 5)
# Model:  123
# 14m 7s
# Epoch: 9, Loss: 0.931456
# 14m 11s
# Epoch: 19, Loss: 0.649190
# 14m 14s
# Epoch: 29, Loss: 0.209570
# (123, 6, 5, 6, 6)
# Model:  124
# 14m 18s
# Epoch: 9, Loss: 1.179479
# 14m 21s
# Epoch: 19, Loss: 1.340129
# 14m 25s
# Epoch: 29, Loss: 0.256529
# (124, 5, 6, 6, 5)
# Model:  125
# 14m 28s
# Epoch: 9, Loss: 0.383489
# 14m 32s
# Epoch: 19, Loss: 1.906674
# 14m 35s
# Epoch: 29, Loss: 0.126482
# (125, 6, 5, 6, 7)
# Model:  126
# 14m 39s
# Epoch: 9, Loss: 0.451278
# 14m 43s
# Epoch: 19, Loss: 0.570109
# 14m 46s
# Epoch: 29, Loss: 0.254523
# (126, 6, 5, 6, 4)
# Model:  127
# 14m 50s
# Epoch: 9, Loss: 0.738561
# 14m 54s
# Epoch: 19, Loss: 0.276780
# 14m 57s
# Epoch: 29, Loss: 0.222516
# (127, 5, 4, 7, 7)
# Model:  128
# 15m 1s
# Epoch: 9, Loss: 0.469074
# 15m 5s
# Epoch: 19, Loss: 0.977045
# 15m 8s
# Epoch: 29, Loss: 0.346968
# (128, 6, 5, 7, 6)
# Model:  129
# 15m 12s
# Epoch: 9, Loss: 0.545507
# 15m 15s
# Epoch: 19, Loss: 0.636718
# 15m 19s
# Epoch: 29, Loss: 0.338263
# (129, 5, 7, 6, 6)
# Model:  130
# 15m 23s
# Epoch: 9, Loss: 0.587873
# 15m 26s
# Epoch: 19, Loss: 0.625198
# 15m 30s
# Epoch: 29, Loss: 0.309925
# (130, 5, 4, 6, 6)
# Model:  131
# 15m 34s
# Epoch: 9, Loss: 1.137291
# 15m 37s
# Epoch: 19, Loss: 0.181291
# 15m 41s
# Epoch: 29, Loss: 0.356349
# (131, 7, 6, 6, 5)
# Model:  132
# 15m 45s
# Epoch: 9, Loss: 1.067908
# 15m 48s
# Epoch: 19, Loss: 0.251971
# 15m 52s
# Epoch: 29, Loss: 0.497547
# (132, 6, 6, 6, 6)
# Model:  133
# 15m 56s
# Epoch: 9, Loss: 0.971062
# 15m 59s
# Epoch: 19, Loss: 0.531776
# 16m 3s
# Epoch: 29, Loss: 0.569408
# (133, 7, 6, 7, 7)
# Model:  134
# 16m 7s
# Epoch: 9, Loss: 0.801111
# 16m 11s
# Epoch: 19, Loss: 0.748376
# 16m 14s
# Epoch: 29, Loss: 1.459998
# (134, 6, 5, 7, 6)
# Model:  135
# 16m 18s
# Epoch: 9, Loss: 0.421375
# 16m 22s
# Epoch: 19, Loss: 0.630393
# 16m 25s
# Epoch: 29, Loss: 0.969730
# (135, 5, 4, 7, 6)
# Model:  136
# 16m 29s
# Epoch: 9, Loss: 0.346495
# 16m 33s
# Epoch: 19, Loss: 0.354574
# 16m 36s
# Epoch: 29, Loss: 1.228936
# (136, 6, 7, 7, 6)
# Model:  137
# 16m 40s
# Epoch: 9, Loss: 0.881648
# 16m 44s
# Epoch: 19, Loss: 0.409491
# 16m 47s
# Epoch: 29, Loss: 0.272762
# (137, 6, 5, 6, 5)
# Model:  138
# 16m 51s
# Epoch: 9, Loss: 0.295879
# 16m 55s
# Epoch: 19, Loss: 0.607116
# 16m 58s
# Epoch: 29, Loss: 1.019745
# (138, 5, 5, 7, 6)
# Model:  139
# 17m 2s
# Epoch: 9, Loss: 0.460503
# 17m 6s
# Epoch: 19, Loss: 0.421476
# 17m 10s
# Epoch: 29, Loss: 1.258438
# (139, 6, 5, 6, 5)
# Model:  140
# 17m 14s
# Epoch: 9, Loss: 0.209974
# 17m 17s
# Epoch: 19, Loss: 0.183938
# 17m 21s
# Epoch: 29, Loss: 0.385836
# (140, 5, 4, 7, 6)
# Model:  141
# 17m 25s
# Epoch: 9, Loss: 0.638035
# 17m 29s
# Epoch: 19, Loss: 0.212265
# 17m 33s
# Epoch: 29, Loss: 0.424598
# (141, 5, 4, 6, 5)
# Model:  142
# 17m 37s
# Epoch: 9, Loss: 0.548326
# 17m 40s
# Epoch: 19, Loss: 0.831068
# 17m 44s
# Epoch: 29, Loss: 0.208145
# (142, 6, 4, 7, 6)
# Model:  143
# 17m 48s
# Epoch: 9, Loss: 0.372346
# 17m 52s
# Epoch: 19, Loss: 0.867173
# 17m 56s
# Epoch: 29, Loss: 0.547671
# (143, 5, 5, 7, 6)
# Model:  144
# 18m 0s
# Epoch: 9, Loss: 0.568557
# 18m 4s
# Epoch: 19, Loss: 0.577898
# 18m 7s
# Epoch: 29, Loss: 0.329058
# (144, 6, 5, 8, 6)
# Model:  145
# 18m 11s
# Epoch: 9, Loss: 0.490220
# 18m 15s
# Epoch: 19, Loss: 1.119285
# 18m 19s
# Epoch: 29, Loss: 0.789308
# (145, 6, 4, 7, 5)
# Model:  146
# 18m 23s
# Epoch: 9, Loss: 0.288937
# 18m 27s
# Epoch: 19, Loss: 0.170316
# 18m 31s
# Epoch: 29, Loss: 1.769090
# (146, 6, 5, 6, 5)
# Model:  147
# 18m 35s
# Epoch: 9, Loss: 0.275850
# 18m 39s
# Epoch: 19, Loss: 0.494513
# 18m 42s
# Epoch: 29, Loss: 0.201653
# (147, 5, 5, 6, 6)
# Model:  148
# 18m 47s
# Epoch: 9, Loss: 0.234596
# 18m 50s
# Epoch: 19, Loss: 0.588327
# 18m 54s
# Epoch: 29, Loss: 0.336092
# (148, 7, 4, 6, 6)
# Model:  149
# 18m 58s
# Epoch: 9, Loss: 0.277973
# 19m 2s
# Epoch: 19, Loss: 0.854094
# 19m 6s
# Epoch: 29, Loss: 0.284631
# (149, 6, 4, 7, 5)
# Model:  150
# 19m 10s
# Epoch: 9, Loss: 0.420764
# 19m 14s
# Epoch: 19, Loss: 0.763373
# 19m 18s
# Epoch: 29, Loss: 0.209142
# (150, 7, 5, 6, 6)
# Model:  151
# 19m 23s
# Epoch: 9, Loss: 0.567747
# 19m 27s
# Epoch: 19, Loss: 0.246638
# 19m 30s
# Epoch: 29, Loss: 0.510925
# (151, 7, 5, 7, 5)
# Model:  152
# 19m 35s
# Epoch: 9, Loss: 0.513588
# 19m 39s
# Epoch: 19, Loss: 1.184388
# 19m 43s
# Epoch: 29, Loss: 0.712415
# (152, 7, 6, 7, 4)
# Model:  153
# 19m 47s
# Epoch: 9, Loss: 1.166789
# 19m 51s
# Epoch: 19, Loss: 1.028001
# 19m 55s
# Epoch: 29, Loss: 0.207517
# (153, 7, 4, 7, 6)
# Model:  154
# 19m 59s
# Epoch: 9, Loss: 0.565146
# 20m 3s
# Epoch: 19, Loss: 0.761306
# 20m 7s
# Epoch: 29, Loss: 0.976830
# (154, 5, 6, 7, 5)
# Model:  155
# 20m 11s
# Epoch: 9, Loss: 1.002053
# 20m 15s
# Epoch: 19, Loss: 0.488576
# 20m 19s
# Epoch: 29, Loss: 0.956558
# (155, 7, 5, 6, 5)
# Model:  156
# 20m 24s
# Epoch: 9, Loss: 1.157014
# 20m 28s
# Epoch: 19, Loss: 0.082605
# 20m 32s
# Epoch: 29, Loss: 0.503015
# (156, 6, 4, 6, 6)
# Model:  157
# 20m 36s
# Epoch: 9, Loss: 1.012453
# 20m 40s
# Epoch: 19, Loss: 0.319155
# 20m 44s
# Epoch: 29, Loss: 0.320551
# (157, 7, 5, 6, 5)
# Model:  158
# 20m 48s
# Epoch: 9, Loss: 0.694741
# 20m 52s
# Epoch: 19, Loss: 0.284000
# 20m 56s
# Epoch: 29, Loss: 1.060132
# (158, 6, 5, 7, 5)
# Model:  159
# 21m 0s
# Epoch: 9, Loss: 0.226227
# 21m 5s
# Epoch: 19, Loss: 0.381043
# 21m 9s
# Epoch: 29, Loss: 1.294192
# (159, 7, 5, 6, 4)
# Model:  160
# 21m 13s
# Epoch: 9, Loss: 0.460678
# 21m 17s
# Epoch: 19, Loss: 0.254960
# 21m 21s
# Epoch: 29, Loss: 0.546798
# (160, 6, 6, 6, 5)
# Model:  161
# 21m 26s
# Epoch: 9, Loss: 0.477049
# 21m 30s
# Epoch: 19, Loss: 0.058706
# 21m 34s
# Epoch: 29, Loss: 0.588718
# (161, 6, 4, 6, 5)
# Model:  162
# 21m 39s
# Epoch: 9, Loss: 0.423181
# 21m 43s
# Epoch: 19, Loss: 0.552777
# 21m 47s
# Epoch: 29, Loss: 0.365336
# (162, 6, 6, 7, 7)
# 21m 47s
# Run 28
# 163 163
# Model:  0
# 0m 14s
# Epoch: 9, Loss: 0.768239
# 0m 15s
# Epoch: 19, Loss: 0.716536
# 0m 16s
# Epoch: 29, Loss: 0.347291
# (0, 4, 5, 6, 4)
# Model:  1
# 0m 17s
# Epoch: 9, Loss: 0.739058
# 0m 18s
# Epoch: 19, Loss: 0.438999
# 0m 19s
# Epoch: 29, Loss: 0.475457
# (1, 4, 5, 5, 5)
# Model:  2
# 0m 20s
# Epoch: 9, Loss: 0.667912
# 0m 21s
# Epoch: 19, Loss: 0.653653
# 0m 22s
# Epoch: 29, Loss: 0.829493
# (2, 6, 6, 6, 7)
# Model:  3
# 0m 23s
# Epoch: 9, Loss: 0.634682
# 0m 24s
# Epoch: 19, Loss: 0.716116
# 0m 25s
# Epoch: 29, Loss: 0.351317
# (3, 5, 7, 5, 6)
# Model:  4
# 0m 27s
# Epoch: 9, Loss: 0.723447
# 0m 28s
# Epoch: 19, Loss: 0.503148
# 0m 29s
# Epoch: 29, Loss: 0.592594
# (4, 5, 5, 4, 3)
# Model:  5
# 0m 30s
# Epoch: 9, Loss: 0.775113
# 0m 31s
# Epoch: 19, Loss: 0.620094
# 0m 32s
# Epoch: 29, Loss: 0.801860
# (5, 6, 4, 6, 5)
# Model:  6
# 0m 34s
# Epoch: 9, Loss: 0.661920
# 0m 35s
# Epoch: 19, Loss: 0.654613
# 0m 36s
# Epoch: 29, Loss: 0.196889
# (6, 4, 4, 6, 4)
# Model:  7
# 0m 37s
# Epoch: 9, Loss: 0.686302
# 0m 38s
# Epoch: 19, Loss: 0.651403
# 0m 39s
# Epoch: 29, Loss: 0.578284
# (7, 5, 4, 5, 6)
# Model:  8
# 0m 41s
# Epoch: 9, Loss: 0.633703
# 0m 42s
# Epoch: 19, Loss: 0.680250
# 0m 43s
# Epoch: 29, Loss: 0.233519
# (8, 6, 5, 5, 4)
# Model:  9
# 0m 44s
# Epoch: 9, Loss: 0.684147
# 0m 45s
# Epoch: 19, Loss: 0.733433
# 0m 47s
# Epoch: 29, Loss: 0.746926
# (9, 5, 4, 5, 4)
# Model:  10
# 0m 48s
# Epoch: 9, Loss: 0.691953
# 0m 49s
# Epoch: 19, Loss: 0.596454
# 0m 50s
# Epoch: 29, Loss: 0.482074
# (10, 4, 4, 5, 5)
# Model:  11
# 0m 52s
# Epoch: 9, Loss: 0.615296
# 0m 53s
# Epoch: 19, Loss: 0.613463
# 0m 54s
# Epoch: 29, Loss: 0.900426
# (11, 5, 4, 6, 4)
# Model:  12
# 0m 55s
# Epoch: 9, Loss: 0.502992
# 0m 57s
# Epoch: 19, Loss: 0.502715
# 0m 58s
# Epoch: 29, Loss: 0.123480
# (12, 4, 5, 6, 5)
# Model:  13
# 0m 59s
# Epoch: 9, Loss: 0.728652
# 1m 0s
# Epoch: 19, Loss: 0.916109
# 1m 2s
# Epoch: 29, Loss: 0.468322
# (13, 6, 5, 4, 5)
# Model:  14
# 1m 3s
# Epoch: 9, Loss: 0.686719
# 1m 4s
# Epoch: 19, Loss: 0.614180
# 1m 6s
# Epoch: 29, Loss: 0.354938
# (14, 5, 5, 5, 4)
# Model:  15
# 1m 7s
# Epoch: 9, Loss: 0.732660
# 1m 8s
# Epoch: 19, Loss: 0.626277
# 1m 10s
# Epoch: 29, Loss: 0.570869
# (15, 6, 5, 5, 5)
# Model:  16
# 1m 11s
# Epoch: 9, Loss: 0.741035
# 1m 13s
# Epoch: 19, Loss: 0.718152
# 1m 14s
# Epoch: 29, Loss: 0.201782
# (16, 5, 3, 4, 5)
# Model:  17
# 1m 15s
# Epoch: 9, Loss: 0.706715
# 1m 17s
# Epoch: 19, Loss: 0.717002
# 1m 18s
# Epoch: 29, Loss: 0.411289
# (17, 5, 6, 7, 3)
# Model:  18
# 1m 20s
# Epoch: 9, Loss: 0.675059
# 1m 21s
# Epoch: 19, Loss: 0.688937
# 1m 22s
# Epoch: 29, Loss: 1.393984
# (18, 5, 5, 4, 4)
# Model:  19
# 1m 24s
# Epoch: 9, Loss: 0.544425
# 1m 25s
# Epoch: 19, Loss: 0.476368
# 1m 27s
# Epoch: 29, Loss: 0.268616
# (19, 6, 6, 4, 4)
# Model:  20
# 1m 28s
# Epoch: 9, Loss: 0.860701
# 1m 30s
# Epoch: 19, Loss: 0.306246
# 1m 31s
# Epoch: 29, Loss: 0.606624
# (20, 5, 5, 5, 6)
# Model:  21
# 1m 33s
# Epoch: 9, Loss: 0.577866
# 1m 35s
# Epoch: 19, Loss: 0.248341
# 1m 36s
# Epoch: 29, Loss: 1.283700
# (21, 5, 4, 4, 6)
# Model:  22
# 1m 38s
# Epoch: 9, Loss: 0.721536
# 1m 39s
# Epoch: 19, Loss: 0.532950
# 1m 41s
# Epoch: 29, Loss: 0.232709
# (22, 6, 4, 6, 4)
# Model:  23
# 1m 43s
# Epoch: 9, Loss: 0.774910
# 1m 44s
# Epoch: 19, Loss: 0.809678
# 1m 45s
# Epoch: 29, Loss: 0.640176
# (23, 5, 5, 5, 5)
# Model:  24
# 1m 47s
# Epoch: 9, Loss: 0.747888
# 1m 49s
# Epoch: 19, Loss: 0.799768
# 1m 51s
# Epoch: 29, Loss: 0.635963
# (24, 4, 6, 6, 5)
# Model:  25
# 1m 53s
# Epoch: 9, Loss: 0.629538
# 1m 54s
# Epoch: 19, Loss: 0.528289
# 1m 56s
# Epoch: 29, Loss: 0.814380
# (25, 5, 5, 6, 6)
# Model:  26
# 1m 58s
# Epoch: 9, Loss: 0.884721
# 2m 0s
# Epoch: 19, Loss: 0.696389
# 2m 2s
# Epoch: 29, Loss: 0.552910
# (26, 6, 4, 6, 6)
# Model:  27
# 2m 3s
# Epoch: 9, Loss: 0.610264
# 2m 5s
# Epoch: 19, Loss: 0.554995
# 2m 6s
# Epoch: 29, Loss: 0.252895
# (27, 7, 4, 4, 5)
# Model:  28
# 2m 8s
# Epoch: 9, Loss: 0.609252
# 2m 10s
# Epoch: 19, Loss: 0.597651
# 2m 11s
# Epoch: 29, Loss: 0.997629
# (28, 5, 5, 6, 4)
# Model:  29
# 2m 13s
# Epoch: 9, Loss: 0.473559
# 2m 15s
# Epoch: 19, Loss: 0.682898
# 2m 16s
# Epoch: 29, Loss: 0.526208
# (29, 6, 6, 5, 6)
# Model:  30
# 2m 18s
# Epoch: 9, Loss: 0.599893
# 2m 20s
# Epoch: 19, Loss: 0.289337
# 2m 21s
# Epoch: 29, Loss: 0.246130
# (30, 5, 5, 4, 5)
# Model:  31
# 2m 23s
# Epoch: 9, Loss: 0.543328
# 2m 24s
# Epoch: 19, Loss: 0.521927
# 2m 26s
# Epoch: 29, Loss: 0.177713
# (31, 6, 6, 6, 5)
# Model:  32
# 2m 28s
# Epoch: 9, Loss: 0.676073
# 2m 29s
# Epoch: 19, Loss: 0.903051
# 2m 31s
# Epoch: 29, Loss: 0.147683
# (32, 6, 4, 5, 5)
# Model:  33
# 2m 33s
# Epoch: 9, Loss: 0.684521
# 2m 35s
# Epoch: 19, Loss: 0.428351
# 2m 36s
# Epoch: 29, Loss: 1.043591
# (33, 5, 4, 6, 5)
# Model:  34
# 2m 38s
# Epoch: 9, Loss: 0.588969
# 2m 40s
# Epoch: 19, Loss: 0.460513
# 2m 42s
# Epoch: 29, Loss: 0.960873
# (34, 6, 5, 6, 4)
# Model:  35
# 2m 44s
# Epoch: 9, Loss: 0.495330
# 2m 45s
# Epoch: 19, Loss: 0.739774
# 2m 47s
# Epoch: 29, Loss: 0.508961
# (35, 7, 5, 6, 6)
# Model:  36
# 2m 49s
# Epoch: 9, Loss: 0.641782
# 2m 50s
# Epoch: 19, Loss: 1.002832
# 2m 52s
# Epoch: 29, Loss: 0.497298
# (36, 7, 4, 4, 5)
# Model:  37
# 2m 54s
# Epoch: 9, Loss: 0.580994
# 2m 56s
# Epoch: 19, Loss: 0.638580
# 2m 57s
# Epoch: 29, Loss: 0.393398
# (37, 6, 5, 6, 5)
# Model:  38
# 3m 0s
# Epoch: 9, Loss: 0.768607
# 3m 1s
# Epoch: 19, Loss: 0.298709
# 3m 3s
# Epoch: 29, Loss: 0.975523
# (38, 6, 4, 5, 5)
# Model:  39
# 3m 5s
# Epoch: 9, Loss: 0.782592
# 3m 7s
# Epoch: 19, Loss: 1.073370
# 3m 9s
# Epoch: 29, Loss: 1.168492
# (39, 7, 6, 7, 4)
# Model:  40
# 3m 11s
# Epoch: 9, Loss: 1.092402
# 3m 13s
# Epoch: 19, Loss: 0.829212
# 3m 14s
# Epoch: 29, Loss: 0.593671
# (40, 5, 4, 5, 4)
# Model:  41
# 3m 16s
# Epoch: 9, Loss: 0.708233
# 3m 18s
# Epoch: 19, Loss: 0.678710
# 3m 20s
# Epoch: 29, Loss: 0.662901
# (41, 6, 5, 4, 4)
# Model:  42
# 3m 22s
# Epoch: 9, Loss: 0.587436
# 3m 24s
# Epoch: 19, Loss: 0.521399
# 3m 26s
# Epoch: 29, Loss: 0.163761
# (42, 5, 6, 5, 4)
# Model:  43
# 3m 28s
# Epoch: 9, Loss: 0.808820
# 3m 29s
# Epoch: 19, Loss: 0.281069
# 3m 31s
# Epoch: 29, Loss: 0.745494
# (43, 7, 5, 5, 3)
# Model:  44
# 3m 33s
# Epoch: 9, Loss: 0.511405
# 3m 35s
# Epoch: 19, Loss: 0.896416
# 3m 37s
# Epoch: 29, Loss: 0.795185
# (44, 6, 5, 5, 4)
# Model:  45
# 3m 39s
# Epoch: 9, Loss: 0.649901
# 3m 41s
# Epoch: 19, Loss: 0.377241
# 3m 43s
# Epoch: 29, Loss: 0.333027
# (45, 4, 5, 4, 4)
# Model:  46
# 3m 45s
# Epoch: 9, Loss: 0.743330
# 3m 47s
# Epoch: 19, Loss: 0.673098
# 3m 49s
# Epoch: 29, Loss: 0.413740
# (46, 5, 5, 5, 5)
# Model:  47
# 3m 51s
# Epoch: 9, Loss: 0.712067
# 3m 53s
# Epoch: 19, Loss: 0.432818
# 3m 54s
# Epoch: 29, Loss: 0.856425
# (47, 5, 4, 5, 5)
# Model:  48
# 3m 57s
# Epoch: 9, Loss: 0.371972
# 3m 59s
# Epoch: 19, Loss: 0.578042
# 4m 0s
# Epoch: 29, Loss: 0.400288
# (48, 5, 5, 5, 6)
# Model:  49
# 4m 3s
# Epoch: 9, Loss: 0.678201
# 4m 5s
# Epoch: 19, Loss: 0.766755
# 4m 6s
# Epoch: 29, Loss: 0.704511
# (49, 5, 6, 4, 4)
# Model:  50
# 4m 9s
# Epoch: 9, Loss: 0.674838
# 4m 11s
# Epoch: 19, Loss: 0.363635
# 4m 13s
# Epoch: 29, Loss: 0.869962
# (50, 4, 2, 6, 3)
# Model:  51
# 4m 15s
# Epoch: 9, Loss: 1.021277
# 4m 17s
# Epoch: 19, Loss: 0.817923
# 4m 19s
# Epoch: 29, Loss: 1.088081
# (51, 5, 5, 5, 4)
# Model:  52
# 4m 21s
# Epoch: 9, Loss: 0.804184
# 4m 23s
# Epoch: 19, Loss: 0.893179
# 4m 25s
# Epoch: 29, Loss: 1.613073
# (52, 5, 5, 5, 4)
# Model:  53
# 4m 27s
# Epoch: 9, Loss: 0.749007
# 4m 29s
# Epoch: 19, Loss: 1.689196
# 4m 31s
# Epoch: 29, Loss: 0.459134
# (53, 5, 5, 6, 5)
# Model:  54
# 4m 33s
# Epoch: 9, Loss: 1.085781
# 4m 35s
# Epoch: 19, Loss: 0.968449
# 4m 37s
# Epoch: 29, Loss: 0.319841
# (54, 6, 3, 6, 4)
# Model:  55
# 4m 40s
# Epoch: 9, Loss: 0.688955
# 4m 42s
# Epoch: 19, Loss: 1.127829
# 4m 44s
# Epoch: 29, Loss: 0.966205
# (55, 6, 5, 6, 5)
# Model:  56
# 4m 46s
# Epoch: 9, Loss: 0.653413
# 4m 48s
# Epoch: 19, Loss: 0.338657
# 4m 50s
# Epoch: 29, Loss: 0.627305
# (56, 6, 4, 6, 4)
# Model:  57
# 4m 53s
# Epoch: 9, Loss: 0.877182
# 4m 55s
# Epoch: 19, Loss: 0.703777
# 4m 57s
# Epoch: 29, Loss: 0.556521
# (57, 6, 5, 6, 5)
# Model:  58
# 4m 59s
# Epoch: 9, Loss: 0.908614
# 5m 1s
# Epoch: 19, Loss: 0.645489
# 5m 3s
# Epoch: 29, Loss: 0.460796
# (58, 5, 5, 5, 6)
# Model:  59
# 5m 6s
# Epoch: 9, Loss: 0.477968
# 5m 8s
# Epoch: 19, Loss: 0.169333
# 5m 10s
# Epoch: 29, Loss: 0.381081
# (59, 5, 4, 7, 6)
# Model:  60
# 5m 12s
# Epoch: 9, Loss: 0.660124
# 5m 14s
# Epoch: 19, Loss: 0.272151
# 5m 17s
# Epoch: 29, Loss: 0.274039
# (60, 7, 5, 7, 6)
# Model:  61
# 5m 19s
# Epoch: 9, Loss: 0.479622
# 5m 21s
# Epoch: 19, Loss: 1.046788
# 5m 23s
# Epoch: 29, Loss: 0.270016
# (61, 5, 3, 6, 4)
# Model:  62
# 5m 26s
# Epoch: 9, Loss: 0.520181
# 5m 28s
# Epoch: 19, Loss: 0.390836
# 5m 30s
# Epoch: 29, Loss: 0.638161
# (62, 5, 4, 6, 6)
# Model:  63
# 5m 33s
# Epoch: 9, Loss: 0.633951
# 5m 35s
# Epoch: 19, Loss: 0.507304
# 5m 37s
# Epoch: 29, Loss: 1.056656
# (63, 5, 4, 6, 5)
# Model:  64
# 5m 39s
# Epoch: 9, Loss: 0.805224
# 5m 42s
# Epoch: 19, Loss: 0.160360
# 5m 44s
# Epoch: 29, Loss: 0.170489
# (64, 6, 3, 7, 5)
# Model:  65
# 5m 46s
# Epoch: 9, Loss: 0.520887
# 5m 49s
# Epoch: 19, Loss: 0.307900
# 5m 51s
# Epoch: 29, Loss: 0.330843
# (65, 5, 4, 6, 5)
# Model:  66
# 5m 53s
# Epoch: 9, Loss: 1.057948
# 5m 56s
# Epoch: 19, Loss: 0.343170
# 5m 58s
# Epoch: 29, Loss: 0.446362
# (66, 6, 5, 7, 6)
# Model:  67
# 6m 0s
# Epoch: 9, Loss: 0.489018
# 6m 3s
# Epoch: 19, Loss: 0.216790
# 6m 5s
# Epoch: 29, Loss: 0.217947
# (67, 5, 4, 5, 6)
# Model:  68
# 6m 8s
# Epoch: 9, Loss: 0.651645
# 6m 10s
# Epoch: 19, Loss: 0.959711
# 6m 12s
# Epoch: 29, Loss: 1.249441
# (68, 6, 5, 6, 5)
# Model:  69
# 6m 15s
# Epoch: 9, Loss: 0.541055
# 6m 17s
# Epoch: 19, Loss: 0.518011
# 6m 20s
# Epoch: 29, Loss: 0.647566
# (69, 5, 4, 5, 6)
# Model:  70
# 6m 22s
# Epoch: 9, Loss: 0.584228
# 6m 25s
# Epoch: 19, Loss: 0.468379
# 6m 27s
# Epoch: 29, Loss: 0.501965
# (70, 7, 5, 5, 5)
# Model:  71
# 6m 30s
# Epoch: 9, Loss: 0.420362
# 6m 32s
# Epoch: 19, Loss: 0.528199
# 6m 34s
# Epoch: 29, Loss: 0.744394
# (71, 4, 5, 6, 6)
# Model:  72
# 6m 37s
# Epoch: 9, Loss: 0.787372
# 6m 39s
# Epoch: 19, Loss: 0.540823
# 6m 42s
# Epoch: 29, Loss: 0.946512
# (72, 5, 5, 5, 4)
# Model:  73
# 6m 44s
# Epoch: 9, Loss: 0.611760
# 6m 47s
# Epoch: 19, Loss: 0.863942
# 6m 49s
# Epoch: 29, Loss: 0.206782
# (73, 5, 4, 6, 4)
# Model:  74
# 6m 52s
# Epoch: 9, Loss: 0.736272
# 6m 54s
# Epoch: 19, Loss: 0.387035
# 6m 57s
# Epoch: 29, Loss: 0.692159
# (74, 5, 4, 5, 6)
# Model:  75
# 6m 59s
# Epoch: 9, Loss: 0.331808
# 7m 2s
# Epoch: 19, Loss: 0.358849
# 7m 4s
# Epoch: 29, Loss: 0.285556
# (75, 5, 3, 6, 6)
# Model:  76
# 7m 7s
# Epoch: 9, Loss: 0.705510
# 7m 9s
# Epoch: 19, Loss: 0.661026
# 7m 12s
# Epoch: 29, Loss: 0.128813
# (76, 5, 3, 6, 4)
# Model:  77
# 7m 15s
# Epoch: 9, Loss: 0.433137
# 7m 17s
# Epoch: 19, Loss: 0.357806
# 7m 20s
# Epoch: 29, Loss: 0.553677
# (77, 5, 4, 7, 5)
# Model:  78
# 7m 22s
# Epoch: 9, Loss: 0.738070
# 7m 25s
# Epoch: 19, Loss: 0.416026
# 7m 27s
# ...
# Epoch: 9, Loss: 0.708846
# 2m 56s
# Epoch: 19, Loss: 0.518361
# 2m 58s
# Epoch: 29, Loss: 0.132509
# (38, 6, 5, 5, 4)
# Model:  39
# 3m 0s
# Epoch: 9, Loss: 0.597892
# 3m 1s
# Epoch: 19, Loss: 0.370414
# 3m 3s
# Epoch: 29, Loss: 1.097922
# (39, 6, 5, 6, 4)
# Model:  40
# 3m 5s
# Epoch: 9, Loss: 0.495727
# 3m 7s
# Epoch: 19, Loss: 0.599250
# 3m 9s
# Epoch: 29, Loss: 0.733657
# (40, 5, 5, 6, 2)
# Model:  41
# 3m 11s
# Epoch: 9, Loss: 0.788706
# 3m 13s
# Epoch: 19, Loss: 0.863584
# 3m 14s
# Epoch: 29, Loss: 0.988293
# (41, 5, 5, 5, 4)
# Model:  42
# 3m 16s
# Epoch: 9, Loss: 0.904323
# 3m 18s
# Epoch: 19, Loss: 0.648725
# 3m 20s
# Epoch: 29, Loss: 0.436088
# (42, 5, 5, 6, 3)
# Model:  43
# 3m 22s
# Epoch: 9, Loss: 0.687898
# 3m 24s
# Epoch: 19, Loss: 0.408643
# 3m 26s
# Epoch: 29, Loss: 0.847423
# (43, 5, 5, 5, 6)
# Model:  44
# 3m 28s
# Epoch: 9, Loss: 0.430853
# 3m 30s
# Epoch: 19, Loss: 0.455282
# 3m 32s
# Epoch: 29, Loss: 0.167897
# (44, 5, 5, 5, 5)
# Model:  45
# 3m 34s
# Epoch: 9, Loss: 0.439606
# 3m 36s
# Epoch: 19, Loss: 0.352735
# 3m 37s
# Epoch: 29, Loss: 1.489264
# (45, 5, 6, 4, 5)
# Model:  46
# 3m 39s
# Epoch: 9, Loss: 0.747059
# 3m 41s
# Epoch: 19, Loss: 0.390029
# 3m 43s
# Epoch: 29, Loss: 0.254653
# (46, 5, 5, 5, 5)
# Model:  47
# 3m 45s
# Epoch: 9, Loss: 0.796014
# 3m 47s
# Epoch: 19, Loss: 1.488735
# 3m 49s
# Epoch: 29, Loss: 0.641318
# (47, 5, 5, 4, 6)
# Model:  48
# 3m 51s
# Epoch: 9, Loss: 0.834084
# 3m 53s
# Epoch: 19, Loss: 0.214204
# 3m 55s
# Epoch: 29, Loss: 0.676685
# (48, 5, 5, 4, 4)
# Model:  49
# 3m 57s
# Epoch: 9, Loss: 0.417975
# 3m 59s
# Epoch: 19, Loss: 0.221024
# 4m 1s
# Epoch: 29, Loss: 0.435707
# (49, 6, 6, 5, 5)
# Model:  50
# 4m 3s
# Epoch: 9, Loss: 0.625417
# 4m 5s
# Epoch: 19, Loss: 0.336817
# 4m 7s
# Epoch: 29, Loss: 0.363180
# (50, 5, 3, 5, 4)
# Model:  51
# 4m 10s
# Epoch: 9, Loss: 0.375383
# 4m 12s
# Epoch: 19, Loss: 0.829651
# 4m 13s
# Epoch: 29, Loss: 0.351493
# (51, 6, 4, 5, 5)
# Model:  52
# 4m 16s
# Epoch: 9, Loss: 0.676593
# 4m 18s
# Epoch: 19, Loss: 0.314244
# 4m 20s
# Epoch: 29, Loss: 0.998245
# (52, 5, 5, 5, 5)
# Model:  53
# 4m 22s
# Epoch: 9, Loss: 0.818207
# 4m 24s
# Epoch: 19, Loss: 0.894267
# 4m 26s
# Epoch: 29, Loss: 0.593951
# (53, 5, 3, 7, 5)
# Model:  54
# 4m 28s
# Epoch: 9, Loss: 0.983865
# 4m 30s
# Epoch: 19, Loss: 0.321093
# 4m 32s
# Epoch: 29, Loss: 0.659831
# (54, 5, 5, 7, 4)
# Model:  55
# 4m 35s
# Epoch: 9, Loss: 0.643545
# 4m 37s
# Epoch: 19, Loss: 0.629181
# 4m 39s
# Epoch: 29, Loss: 0.527796
# (55, 5, 5, 5, 6)
# Model:  56
# 4m 41s
# Epoch: 9, Loss: 0.570836
# 4m 43s
# Epoch: 19, Loss: 0.680915
# 4m 45s
# Epoch: 29, Loss: 0.105121
# (56, 4, 4, 5, 3)
# Model:  57
# 4m 47s
# Epoch: 9, Loss: 0.816592
# 4m 49s
# Epoch: 19, Loss: 0.565524
# 4m 51s
# Epoch: 29, Loss: 0.234645
# (57, 6, 6, 6, 5)
# Model:  58
# 4m 54s
# Epoch: 9, Loss: 0.647372
# 4m 56s
# Epoch: 19, Loss: 0.292828
# 4m 58s
# Epoch: 29, Loss: 0.550956
# (58, 5, 4, 7, 6)
# Model:  59
# 5m 0s
# Epoch: 9, Loss: 0.840478
# 5m 2s
# Epoch: 19, Loss: 0.410507
# 5m 4s
# Epoch: 29, Loss: 0.687791
# (59, 6, 6, 6, 4)
# Model:  60
# 5m 7s
# Epoch: 9, Loss: 0.565804
# 5m 9s
# Epoch: 19, Loss: 0.426228
# 5m 11s
# Epoch: 29, Loss: 0.277489
# (60, 6, 5, 6, 6)
# Model:  61
# 5m 14s
# Epoch: 9, Loss: 0.921774
# 5m 16s
# Epoch: 19, Loss: 0.521889
# 5m 18s
# Epoch: 29, Loss: 0.292693
# (61, 6, 6, 6, 3)
# Model:  62
# 5m 20s
# Epoch: 9, Loss: 0.960027
# 5m 23s
# Epoch: 19, Loss: 0.447823
# 5m 25s
# Epoch: 29, Loss: 0.974446
# (62, 5, 4, 7, 5)
# Model:  63
# 5m 27s
# Epoch: 9, Loss: 0.660744
# 5m 29s
# Epoch: 19, Loss: 1.039315
# 5m 32s
# Epoch: 29, Loss: 0.135702
# (63, 5, 6, 6, 6)
# Model:  64
# 5m 34s
# Epoch: 9, Loss: 0.869980
# 5m 36s
# Epoch: 19, Loss: 0.541843
# 5m 39s
# Epoch: 29, Loss: 0.743884
# (64, 5, 3, 6, 6)
# Model:  65
# 5m 41s
# Epoch: 9, Loss: 0.764601
# 5m 43s
# Epoch: 19, Loss: 0.466356
# 5m 46s
# Epoch: 29, Loss: 0.959361
# (65, 6, 5, 7, 5)
# Model:  66
# 5m 48s
# Epoch: 9, Loss: 0.902138
# 5m 50s
# Epoch: 19, Loss: 0.191568
# 5m 53s
# Epoch: 29, Loss: 0.876324
# (66, 5, 5, 7, 6)
# Model:  67
# 5m 55s
# Epoch: 9, Loss: 0.474919
# 5m 58s
# Epoch: 19, Loss: 0.551446
# 6m 0s
# Epoch: 29, Loss: 2.417715
# (67, 6, 4, 6, 6)
# Model:  68
# 6m 3s
# Epoch: 9, Loss: 0.554557
# 6m 5s
# Epoch: 19, Loss: 0.445779
# 6m 7s
# Epoch: 29, Loss: 0.526093
# (68, 5, 5, 6, 6)
# Model:  69
# 6m 10s
# Epoch: 9, Loss: 0.846016
# 6m 12s
# Epoch: 19, Loss: 0.612508
# 6m 15s
# Epoch: 29, Loss: 0.255614
# (69, 5, 5, 6, 5)
# Model:  70
# 6m 18s
# Epoch: 9, Loss: 0.781626
# 6m 20s
# Epoch: 19, Loss: 1.635462
# 6m 23s
# Epoch: 29, Loss: 1.202113
# (70, 6, 5, 6, 5)
# Model:  71
# 6m 25s
# Epoch: 9, Loss: 0.722435
# 6m 28s
# Epoch: 19, Loss: 0.594370
# 6m 30s
# Epoch: 29, Loss: 0.954297
# (71, 5, 5, 5, 5)
# Model:  72
# 6m 33s
# Epoch: 9, Loss: 0.541794
# 6m 35s
# Epoch: 19, Loss: 0.789640
# 6m 38s
# Epoch: 29, Loss: 0.333809
# (72, 6, 3, 6, 5)
# Model:  73
# 6m 40s
# Epoch: 9, Loss: 0.480114
# 6m 43s
# Epoch: 19, Loss: 0.618077
# 6m 45s
# Epoch: 29, Loss: 0.564753
# (73, 5, 4, 5, 5)
# Model:  74
# 6m 48s
# Epoch: 9, Loss: 0.541837
# 6m 50s
# Epoch: 19, Loss: 0.368821
# 6m 53s
# Epoch: 29, Loss: 0.351702
# (74, 5, 3, 6, 3)
# Model:  75
# 6m 55s
# Epoch: 9, Loss: 0.650375
# 6m 58s
# Epoch: 19, Loss: 0.355087
# 7m 0s
# Epoch: 29, Loss: 0.506585
# (75, 5, 4, 5, 5)
# Model:  76
# 7m 3s
# Epoch: 9, Loss: 0.763435
# 7m 6s
# Epoch: 19, Loss: 1.006549
# 7m 8s
# Epoch: 29, Loss: 2.698102
# (76, 5, 4, 6, 5)
# Model:  77
# 7m 11s
# Epoch: 9, Loss: 0.582352
# 7m 13s
# Epoch: 19, Loss: 0.212110
# 7m 16s
# Epoch: 29, Loss: 0.543820
# (77, 6, 5, 6, 6)
# Model:  78
# 7m 19s
# Epoch: 9, Loss: 0.617964
# 7m 21s
# Epoch: 19, Loss: 0.411633
# 7m 24s
# Epoch: 29, Loss: 0.761879
# (78, 4, 6, 5, 5)
# Model:  79
# 7m 27s
# Epoch: 9, Loss: 0.597278
# 7m 29s
# Epoch: 19, Loss: 0.831613
# 7m 32s
# Epoch: 29, Loss: 0.154884
# (79, 5, 5, 6, 4)
# Model:  80
# 7m 35s
# Epoch: 9, Loss: 0.461141
# 7m 37s
# Epoch: 19, Loss: 0.552251
# 7m 40s
# Epoch: 29, Loss: 0.455373
# (80, 5, 5, 6, 6)
# Model:  81
# 7m 42s
# Epoch: 9, Loss: 0.473990
# 7m 45s
# Epoch: 19, Loss: 0.367930
# 7m 48s
# Epoch: 29, Loss: 1.640477
# (81, 7, 5, 5, 6)
# Model:  82
# 7m 50s
# Epoch: 9, Loss: 0.838111
# 7m 53s
# Epoch: 19, Loss: 1.080360
# 7m 56s
# Epoch: 29, Loss: 0.446009
# (82, 6, 6, 7, 6)
# Model:  83
# 7m 59s
# Epoch: 9, Loss: 0.819861
# 8m 1s
# Epoch: 19, Loss: 0.775392
# 8m 4s
# Epoch: 29, Loss: 0.244851
# (83, 5, 4, 6, 6)
# Model:  84
# 8m 7s
# Epoch: 9, Loss: 0.666544
# 8m 9s
# Epoch: 19, Loss: 0.763123
# 8m 12s
# Epoch: 29, Loss: 0.203297
# (84, 6, 4, 5, 4)
# Model:  85
# 8m 15s
# Epoch: 9, Loss: 0.591672
# 8m 18s
# Epoch: 19, Loss: 0.345133
# 8m 21s
# Epoch: 29, Loss: 0.798709
# (85, 6, 5, 5, 4)
# Model:  86
# 8m 23s
# Epoch: 9, Loss: 0.626582
# 8m 26s
# Epoch: 19, Loss: 0.718544
# 8m 29s
# Epoch: 29, Loss: 0.490135
# (86, 5, 3, 5, 4)
# Model:  87
# 8m 32s
# Epoch: 9, Loss: 0.402994
# 8m 34s
# Epoch: 19, Loss: 0.808028
# 8m 37s
# Epoch: 29, Loss: 0.159277
# (87, 5, 5, 5, 5)
# Model:  88
# 8m 40s
# Epoch: 9, Loss: 0.990551
# 8m 43s
# Epoch: 19, Loss: 0.174573
# 8m 46s
# Epoch: 29, Loss: 0.551888
# (88, 5, 3, 5, 6)
# Model:  89
# 8m 48s
# Epoch: 9, Loss: 0.556171
# 8m 51s
# Epoch: 19, Loss: 0.390350
# 8m 54s
# Epoch: 29, Loss: 0.338414
# (89, 5, 4, 5, 6)
# Model:  90
# 8m 57s
# Epoch: 9, Loss: 1.095621
# 9m 0s
# Epoch: 19, Loss: 1.189845
# 9m 2s
# Epoch: 29, Loss: 0.262096
# (90, 4, 5, 5, 5)
# Model:  91
# 9m 5s
# Epoch: 9, Loss: 0.552285
# 9m 8s
# Epoch: 19, Loss: 0.893567
# 9m 11s
# Epoch: 29, Loss: 0.127189
# (91, 5, 3, 6, 5)
# Model:  92
# 9m 14s
# Epoch: 9, Loss: 0.866450
# 9m 17s
# Epoch: 19, Loss: 0.975342
# 9m 19s
# Epoch: 29, Loss: 0.158918
# (92, 4, 5, 4, 7)
# Model:  93
# 9m 23s
# Epoch: 9, Loss: 0.445671
# 9m 25s
# Epoch: 19, Loss: 0.563921
# 9m 28s
# Epoch: 29, Loss: 0.806942
# (93, 6, 5, 5, 7)
# Model:  94
# 9m 31s
# Epoch: 9, Loss: 0.894249
# 9m 34s
# Epoch: 19, Loss: 0.392174
# 9m 37s
# Epoch: 29, Loss: 1.360289
# (94, 5, 5, 5, 6)
# Model:  95
# 9m 40s
# Epoch: 9, Loss: 0.308479
# 9m 43s
# Epoch: 19, Loss: 1.122683
# 9m 46s
# Epoch: 29, Loss: 0.340844
# (95, 5, 5, 5, 6)
# Model:  96
# 9m 49s
# Epoch: 9, Loss: 0.476757
# 9m 52s
# Epoch: 19, Loss: 0.512864
# 9m 55s
# Epoch: 29, Loss: 0.266828
# (96, 5, 5, 5, 5)
# Model:  97
# 9m 58s
# Epoch: 9, Loss: 0.646444
# 10m 1s
# Epoch: 19, Loss: 0.168038
# 10m 4s
# Epoch: 29, Loss: 0.878831
# (97, 4, 4, 5, 5)
# Model:  98
# 10m 7s
# Epoch: 9, Loss: 0.656025
# 10m 10s
# Epoch: 19, Loss: 0.546414
# 10m 13s
# Epoch: 29, Loss: 0.445530
# (98, 5, 4, 5, 5)
# Model:  99
# 10m 16s
# Epoch: 9, Loss: 0.675575
# 10m 19s
# Epoch: 19, Loss: 1.975772
# 10m 22s
# Epoch: 29, Loss: 0.265972
# (99, 5, 4, 5, 5)
# Model:  100
# 10m 25s
# Epoch: 9, Loss: 0.380706
# 10m 28s
# Epoch: 19, Loss: 0.695076
# 10m 31s
# Epoch: 29, Loss: 0.157598
# (100, 4, 5, 5, 6)
# Model:  101
# 10m 35s
# Epoch: 9, Loss: 0.861386
# 10m 38s
# Epoch: 19, Loss: 0.143186
# 10m 41s
# Epoch: 29, Loss: 1.466278
# (101, 5, 6, 5, 5)
# Model:  102
# 10m 44s
# Epoch: 9, Loss: 0.952002
# 10m 47s
# Epoch: 19, Loss: 0.589432
# 10m 50s
# Epoch: 29, Loss: 0.560047
# (102, 5, 6, 5, 6)
# Model:  103
# 10m 53s
# Epoch: 9, Loss: 0.522091
# 10m 56s
# Epoch: 19, Loss: 0.537721
# 10m 59s
# Epoch: 29, Loss: 0.421833
# (103, 5, 6, 5, 5)
# Model:  104
# 11m 2s
# Epoch: 9, Loss: 1.223038
# 11m 5s
# Epoch: 19, Loss: 0.585680
# 11m 8s
# Epoch: 29, Loss: 0.340626
# (104, 5, 6, 5, 6)
# Model:  105
# 11m 11s
# Epoch: 9, Loss: 0.420758
# 11m 14s
# Epoch: 19, Loss: 0.480167
# 11m 18s
# Epoch: 29, Loss: 1.083891
# (105, 5, 6, 6, 7)
# Model:  106
# 11m 21s
# Epoch: 9, Loss: 0.619025
# 11m 24s
# Epoch: 19, Loss: 0.433082
# 11m 28s
# Epoch: 29, Loss: 0.408423
# (106, 5, 5, 5, 6)
# Model:  107
# 11m 31s
# Epoch: 9, Loss: 0.557726
# 11m 34s
# Epoch: 19, Loss: 1.489114
# 11m 37s
# Epoch: 29, Loss: 0.525468
# (107, 6, 5, 6, 5)
# Model:  108
# 11m 40s
# Epoch: 9, Loss: 0.277656
# 11m 44s
# Epoch: 19, Loss: 1.448099
# 11m 47s
# Epoch: 29, Loss: 0.295553
# (108, 6, 5, 5, 6)
# Model:  109
# 11m 50s
# Epoch: 9, Loss: 0.929925
# 11m 53s
# Epoch: 19, Loss: 1.227625
# 11m 56s
# Epoch: 29, Loss: 0.333636
# (109, 6, 5, 6, 6)
# Model:  110
# 12m 0s
# Epoch: 9, Loss: 0.155562
# 12m 3s
# Epoch: 19, Loss: 0.193457
# 12m 6s
# Epoch: 29, Loss: 0.126485
# (110, 6, 5, 6, 5)
# Model:  111
# 12m 9s
# Epoch: 9, Loss: 0.482753
# 12m 12s
# Epoch: 19, Loss: 0.332750
# 12m 16s
# Epoch: 29, Loss: 1.006949
# (111, 5, 5, 6, 6)
# Model:  112
# 12m 19s
# Epoch: 9, Loss: 0.580203
# 12m 22s
# Epoch: 19, Loss: 1.606482
# 12m 25s
# Epoch: 29, Loss: 0.203055
# (112, 4, 7, 5, 6)
# Model:  113
# 12m 29s
# Epoch: 9, Loss: 0.472576
# 12m 32s
# Epoch: 19, Loss: 0.306640
# 12m 35s
# Epoch: 29, Loss: 0.365838
# (113, 6, 6, 5, 6)
# Model:  114
# 12m 38s
# Epoch: 9, Loss: 0.625621
# 12m 42s
# Epoch: 19, Loss: 0.915765
# 12m 45s
# Epoch: 29, Loss: 0.497487
# (114, 6, 6, 5, 6)
# Model:  115
# 12m 48s
# Epoch: 9, Loss: 0.351364
# 12m 51s
# Epoch: 19, Loss: 0.177054
# 12m 55s
# Epoch: 29, Loss: 0.476300
# (115, 5, 5, 6, 5)
# Model:  116
# 12m 58s
# Epoch: 9, Loss: 0.295898
# 13m 1s
# Epoch: 19, Loss: 0.320859
# 13m 4s
# Epoch: 29, Loss: 0.408754
# (116, 6, 6, 6, 5)
# Model:  117
# 13m 8s
# Epoch: 9, Loss: 1.366693
# 13m 11s
# Epoch: 19, Loss: 1.133502
# 13m 14s
# Epoch: 29, Loss: 0.554738
# (117, 5, 5, 6, 5)
# Model:  118
# 13m 18s
# Epoch: 9, Loss: 0.367949
# 13m 21s
# Epoch: 19, Loss: 0.272770
# 13m 25s
# Epoch: 29, Loss: 0.150317
# (118, 6, 7, 5, 6)
# Model:  119
# 13m 28s
# Epoch: 9, Loss: 0.351093
# 13m 32s
# Epoch: 19, Loss: 0.907006
# 13m 35s
# Epoch: 29, Loss: 0.966916
# (119, 5, 4, 6, 7)
# Model:  120
# 13m 38s
# Epoch: 9, Loss: 0.927600
# 13m 42s
# Epoch: 19, Loss: 0.419221
# 13m 45s
# Epoch: 29, Loss: 0.174944
# (120, 5, 5, 6, 6)
# Model:  121
# 13m 49s
# Epoch: 9, Loss: 0.822430
# 13m 52s
# Epoch: 19, Loss: 0.486115
# 13m 55s
# Epoch: 29, Loss: 0.153148
# (121, 6, 5, 6, 6)
# Model:  122
# 13m 59s
# Epoch: 9, Loss: 0.860477
# 14m 3s
# Epoch: 19, Loss: 0.325898
# 14m 6s
# Epoch: 29, Loss: 0.797458
# (122, 5, 5, 6, 5)
# Model:  123
# 14m 10s
# Epoch: 9, Loss: 0.431988
# 14m 13s
# Epoch: 19, Loss: 0.600554
# 14m 16s
# Epoch: 29, Loss: 0.614027
# (123, 6, 5, 6, 5)
# Model:  124
# 14m 20s
# Epoch: 9, Loss: 0.401353
# 14m 23s
# Epoch: 19, Loss: 0.593083
# 14m 27s
# Epoch: 29, Loss: 0.480794
# (124, 5, 4, 6, 6)
# Model:  125
# 14m 31s
# Epoch: 9, Loss: 0.756216
# 14m 34s
# Epoch: 19, Loss: 0.252033
# 14m 38s
# Epoch: 29, Loss: 0.357142
# (125, 5, 4, 6, 6)
# Model:  126
# 14m 41s
# Epoch: 9, Loss: 0.476827
# 14m 45s
# Epoch: 19, Loss: 0.591643
# 14m 48s
# Epoch: 29, Loss: 0.211496
# (126, 5, 4, 7, 6)
# Model:  127
# 14m 52s
# Epoch: 9, Loss: 0.717822
# 14m 56s
# Epoch: 19, Loss: 0.929635
# 14m 59s
# Epoch: 29, Loss: 0.588221
# (127, 6, 5, 6, 5)
# Model:  128
# 15m 3s
# Epoch: 9, Loss: 0.529935
# 15m 6s
# Epoch: 19, Loss: 0.599142
# 15m 10s
# Epoch: 29, Loss: 0.314640
# (128, 6, 5, 6, 4)
# Model:  129
# 15m 14s
# Epoch: 9, Loss: 0.638387
# 15m 17s
# Epoch: 19, Loss: 0.533414
# 15m 21s
# Epoch: 29, Loss: 0.822245
# (129, 5, 6, 6, 6)
# Model:  130
# 15m 25s
# Epoch: 9, Loss: 0.743791
# 15m 28s
# Epoch: 19, Loss: 0.649786
# 15m 32s
# Epoch: 29, Loss: 0.680977
# (130, 4, 6, 6, 6)
# Model:  131
# 15m 35s
# Epoch: 9, Loss: 0.458173
# 15m 39s
# Epoch: 19, Loss: 0.609533
# 15m 43s
# Epoch: 29, Loss: 0.939752
# (131, 6, 5, 6, 7)
# Model:  132
# 15m 46s
# Epoch: 9, Loss: 0.475064
# 15m 50s
# Epoch: 19, Loss: 0.624395
# 15m 54s
# Epoch: 29, Loss: 0.508474
# (132, 5, 7, 6, 5)
# Model:  133
# 15m 57s
# Epoch: 9, Loss: 0.600598
# 16m 1s
# Epoch: 19, Loss: 0.632451
# 16m 5s
# Epoch: 29, Loss: 0.699310
# (133, 7, 5, 7, 6)
# Model:  134
# 16m 8s
# Epoch: 9, Loss: 0.997995
# 16m 12s
# Epoch: 19, Loss: 0.938600
# 16m 16s
# Epoch: 29, Loss: 0.993046
# (134, 5, 6, 6, 6)
# Model:  135
# 16m 19s
# Epoch: 9, Loss: 0.920247
# 16m 23s
# Epoch: 19, Loss: 0.078517
# 16m 27s
# Epoch: 29, Loss: 0.418150
# (135, 6, 5, 7, 6)
# Model:  136
# 16m 31s
# Epoch: 9, Loss: 0.357034
# 16m 34s
# Epoch: 19, Loss: 1.535583
# 16m 38s
# Epoch: 29, Loss: 0.323202
# (136, 5, 4, 6, 5)
# Model:  137
# 16m 42s
# Epoch: 9, Loss: 0.400382
# 16m 46s
# Epoch: 19, Loss: 0.263539
# 16m 49s
# Epoch: 29, Loss: 0.209492
# (137, 5, 5, 7, 5)
# Model:  138
# 16m 53s
# Epoch: 9, Loss: 0.473154
# 16m 57s
# Epoch: 19, Loss: 0.148277
# 17m 0s
# Epoch: 29, Loss: 0.879125
# (138, 6, 5, 6, 6)
# Model:  139
# 17m 4s
# Epoch: 9, Loss: 0.781934
# 17m 8s
# Epoch: 19, Loss: 0.791944
# 17m 12s
# Epoch: 29, Loss: 0.627144
# (139, 6, 3, 7, 6)
# Model:  140
# 17m 16s
# Epoch: 9, Loss: 0.255877
# 17m 19s
# Epoch: 19, Loss: 0.333551
# 17m 23s
# Epoch: 29, Loss: 0.176192
# (140, 5, 5, 7, 5)
# Model:  141
# 17m 27s
# Epoch: 9, Loss: 0.494211
# 17m 31s
# Epoch: 19, Loss: 0.229441
# 17m 35s
# Epoch: 29, Loss: 1.010993
# (141, 6, 3, 6, 6)
# Model:  142
# 17m 39s
# Epoch: 9, Loss: 0.782099
# 17m 42s
# Epoch: 19, Loss: 0.360228
# 17m 46s
# Epoch: 29, Loss: 0.182051
# (142, 6, 7, 7, 6)
# Model:  143
# 17m 50s
# Epoch: 9, Loss: 0.698970
# 17m 54s
# Epoch: 19, Loss: 1.486293
# 17m 58s
# Epoch: 29, Loss: 0.501156
# (143, 6, 5, 6, 6)
# Model:  144
# 18m 2s
# Epoch: 9, Loss: 1.269344
# 18m 5s
# Epoch: 19, Loss: 0.229964
# 18m 9s
# Epoch: 29, Loss: 0.331783
# (144, 6, 4, 7, 6)
# Model:  145
# 18m 13s
# Epoch: 9, Loss: 1.191624
# 18m 17s
# Epoch: 19, Loss: 0.314710
# 18m 21s
# Epoch: 29, Loss: 0.157732
# (145, 6, 4, 7, 5)
# Model:  146
# 18m 25s
# Epoch: 9, Loss: 0.373920
# 18m 29s
# Epoch: 19, Loss: 0.466835
# 18m 33s
# Epoch: 29, Loss: 0.476797
# (146, 5, 5, 6, 6)
# Model:  147
# 18m 36s
# Epoch: 9, Loss: 0.410260
# 18m 40s
# Epoch: 19, Loss: 0.341188
# 18m 44s
# Epoch: 29, Loss: 0.607577
# (147, 5, 4, 6, 6)
# Model:  148
# 18m 48s
# Epoch: 9, Loss: 0.808911
# 18m 52s
# Epoch: 19, Loss: 0.391714
# 18m 56s
# Epoch: 29, Loss: 0.852296
# (148, 6, 5, 7, 4)
# Model:  149
# 19m 0s
# Epoch: 9, Loss: 0.370342
# 19m 4s
# Epoch: 19, Loss: 1.763622
# 19m 8s
# Epoch: 29, Loss: 1.039377
# (149, 7, 6, 7, 6)
# Model:  150
# 19m 12s
# Epoch: 9, Loss: 0.328723
# 19m 15s
# Epoch: 19, Loss: 0.512542
# 19m 19s
# Epoch: 29, Loss: 0.654110
# (150, 6, 5, 6, 6)
# Model:  151
# 19m 24s
# Epoch: 9, Loss: 0.725611
# 19m 27s
# Epoch: 19, Loss: 0.892495
# 19m 31s
# Epoch: 29, Loss: 0.930094
# (151, 7, 5, 7, 5)
# Model:  152
# 19m 35s
# Epoch: 9, Loss: 0.465390
# 19m 39s
# Epoch: 19, Loss: 0.441538
# 19m 43s
# Epoch: 29, Loss: 0.345625
# (152, 6, 4, 7, 4)
# Model:  153
# 19m 47s
# Epoch: 9, Loss: 0.329949
# 19m 51s
# Epoch: 19, Loss: 0.509493
# 19m 55s
# Epoch: 29, Loss: 0.805381
# (153, 6, 5, 6, 5)
# Model:  154
# 19m 59s
# Epoch: 9, Loss: 0.396627
# 20m 4s
# Epoch: 19, Loss: 0.141849
# 20m 7s
# Epoch: 29, Loss: 1.058835
# (154, 6, 4, 7, 5)
# Model:  155
# 20m 12s
# Epoch: 9, Loss: 0.348952
# 20m 16s
# Epoch: 19, Loss: 0.957280
# 20m 20s
# Epoch: 29, Loss: 0.269255
# (155, 6, 5, 6, 6)
# Model:  156
# 20m 24s
# Epoch: 9, Loss: 0.663507
# 20m 28s
# Epoch: 19, Loss: 0.981802
# 20m 32s
# Epoch: 29, Loss: 0.979432
# (156, 6, 6, 6, 5)
# Model:  157
# 20m 36s
# Epoch: 9, Loss: 0.671305
# 20m 40s
# Epoch: 19, Loss: 0.357190
# 20m 45s
# Epoch: 29, Loss: 1.202175
# (157, 7, 4, 6, 5)
# Model:  158
# 20m 49s
# Epoch: 9, Loss: 1.088376
# 20m 53s
# Epoch: 19, Loss: 0.308230
# 20m 57s
# Epoch: 29, Loss: 0.707441
# (158, 6, 6, 6, 5)
# Model:  159
# 21m 1s
# Epoch: 9, Loss: 0.764795
# 21m 5s
# Epoch: 19, Loss: 0.470358
# 21m 9s
# Epoch: 29, Loss: 0.477663
# (159, 8, 5, 6, 4)
# Model:  160
# 21m 13s
# Epoch: 9, Loss: 0.153748
# 21m 18s
# Epoch: 19, Loss: 1.031082
# 21m 22s
# Epoch: 29, Loss: 0.270252
# (160, 8, 6, 6, 5)
# Model:  161
# 21m 26s
# Epoch: 9, Loss: 1.673942
# 21m 30s
# Epoch: 19, Loss: 0.397485
# 21m 34s
# Epoch: 29, Loss: 2.492314
# (161, 7, 5, 7, 7)
# Model:  162
# 21m 39s
# Epoch: 9, Loss: 0.569591
# 21m 43s
# Epoch: 19, Loss: 1.477472
# 21m 47s
# Epoch: 29, Loss: 0.405914
# (162, 7, 4, 7, 7)
# 21m 47s
