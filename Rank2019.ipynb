# %% [markdown]
# <a href="https://colab.research.google.com/github/flee2-trinity/Deep-Learning-in-Sports-Result-Prediction-/blob/main/Rank2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#add n days no win rate
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

from google.colab import drive

drive.mount('/content/gdrive')
DATA_PATH = '/content/gdrive/My Drive/2021 Fall/Thesis I'
# Out:
# Mounted at /content/gdrive

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import glob
import os
import datetime

def findFiles(path): 
  return glob.glob(path)

# %%
import csv

filename = '/content/gdrive/My Drive/2021 Fall/Thesis I/NBA Data/nba 18-19/NatStat-NBA2019-Team_Statlines.csv'
with open(filename, newline='') as f:
      reader = csv.reader(f)
      """
      print(list(reader))
      ['GameDay', 'GameID', 'TeamID', 'Team', 'OpponentID', 'Opponent', 'Location',
       'Division', 'Conference', 'Playoffs', 'WinOrLoss', 'PlayerType', 'MIN', 'PTS', 
       'FGM', 'FGA', '3FM', '3FA', 'FTM', 'FTA', 'REB', 'AST', 'STL', 'BLK', 'OREB', 'TO', 'PF']
      """
      next(reader)
      rawDataL = list(reader)
print(rawDataL[0])
# Out:
# ['2018-10-16', '985248', '5', 'Boston', '28', 'Philadelphia', 'H', '', '', '', 'W', '', '234', '103', '41', '96', '11', '37', '10', '14', '54', '21', '7', '6', '12', '14', '20']

# %%
filename18 = '/content/gdrive/My Drive/2021 Fall/Thesis I/NBA Data/nba 17-18/NatStat-NBA2018-Team_Statlines.csv'
with open(filename18, newline='') as f:
      reader = csv.reader(f)
      """
      print(list(reader))
      ['GameDay', 'GameID', 'TeamID', 'Team', 'OpponentID', 'Opponent', 'Location',
       'Division', 'Conference', 'Playoffs', 'WinOrLoss', 'PlayerType', 'MIN', 'PTS', 
       'FGM', 'FGA', '3FM', '3FA', 'FTM', 'FTA', 'REB', 'AST', 'STL', 'BLK', 'OREB', 'TO', 'PF']
      """
      next(reader)
      rawDataL18 = list(reader)
print(rawDataL18[0])
# Out:
# ['2017-10-17', '982028', '1', 'Houston', '25', 'Golden State', 'V', '', 'Western', '', 'W', '', '237', '122', '47', '96', '15', '41', '13', '19', '41', '27', '10', '5', '9', '12', '15']

# %%
import datetime

def readTime(ampm):
  t = 0
  tL = ampm.replace(' ',':').split(':')
  if tL[2] == "PM" and int(tL[0]) < 12:
    t += 12
  t += int(tL[0])
  t += int(tL[1])/60
  return t

seasonBegin = datetime.datetime(2018, 10, 16)
noonTime = readTime("12:00 PM")
#not using
class Stats:
  def __init__(self):
    """
    MIN, PTS,FGM, FGA, 3FM, 3FA, FTM, FTA, REB, AST, STL, BLK, OREB, TO, PF
    """
    self.MIN = 0
    self.PTS = 0
    self.FGM = 0
    self.FGA = 0
    self.FM3 = 0
    self.FA3 = 0
    self.FTM = 0
    self.FTA = 0
    self.REB = 0
    self.AST = 0
    self.STL = 0
    self.BLK = 0
    self.OREB = 0
    self.TO = 0
    self.PF = 0
    self.Win = 0
    self.Loss = 0
    self.WinRate = 0
  def update(self, MIN, PTS,FGM, FGA, FM3, FA3, FTM, FTA, REB, AST, STL, BLK, OREB, TO, PF):
    self.MIN = MIN
    self.PTS = PTS
    self.FGM = FGM
    self.FGA = FGA
    self.FM3 = FM3
    self.FA3 = FA3
    self.FTM = FTM
    self.FTA = FTA
    self.REB = REB
    self.AST = AST
    self.STL = STL
    self.BLK = BLK
    self.OREB = OREB
    self.TO = TO
    self.PF = PF
  def addWinRate(self, Win, Loss):
    self.Win = Win
    self.Loss = Loss
    self.WinRate = Win/(Win+Loss)
  def notEmpty(self):
    return self.MIN>0

class aGame:
  def __init__(self, GameDay, GameID, TeamID, Team, OpponentID, Opponent, Location,
       Division, Conference, Playoffs, WinOrLoss, PlayerType):
    self.GameID = int(GameID)
    self.TeamID = int(TeamID)
    gdL = GameDay.split("-")
    self.GameDay = datetime.datetime(int(gdL[0]), int(gdL[1]), int(gdL[2]))
    #self.GameTime = GameTime
    self.DayCount = (self.GameDay - seasonBegin).days
    self.Team = Team
    self.OpponentID = int(OpponentID)
    self.Opponent = Opponent
    self.Home = Location == 'H'
    self.Division = Division
    self.Conference = Conference
    self.Playoffs = Playoffs == 'Y'
    self.WinOrLoss = WinOrLoss == 'W'
    self.WinID = int(self.WinOrLoss)
    self.LossID = int(not self.WinOrLoss)
    self.PlayerType = PlayerType
    self.TStats = Stats()
    self.OppStats = Stats()
    self.TStatsP = Stats()
    self.OppStatsP = Stats()
    self.previous = False
  def printDay(self):
    print('Day', self.DayCount)
  def updateLastWRate(self, winRate):
    self.lastWinRate = winRate
def aLinetoGame(aline):
  newG = aGame(aline[0], aline[1], aline[2], aline[3], aline[4], aline[5], aline[6],
               aline[7], aline[8], aline[9], aline[10], aline[11])
  for n in range(12, 27):
    aline[n] = int(aline[n])

  newG.TStats.update(aline[12], aline[13], aline[14], aline[15], aline[16], aline[17], 
                     aline[18], aline[19], aline[20], aline[21], aline[22], aline[23], 
                     aline[24], aline[25], aline[26])
  return newG

def readLines(filename):
  with open(filename, newline='') as f:
      reader = csv.reader(f)
      next(reader)
      rawDataL = list(reader)
  #print(rawDataL)
  #'ID', 'GameDay', 'GameTime', 'Home', 'HomeID', 'Visitor', 'VisitorID', 'ScoreVis', 
  #'ScoreHome', 'GameStatus', 'Venue', 'CityState', 'Neutral', 'Division', 'Conference', 'Playoffs'
  #print("RawDataLength ",len(rawDataL))
  data = []
  print(rawDataL[0])
  for oneLine in rawDataL:
    g = aLinetoGame(oneLine)
    data.append(g)
  return data

# %%
from copy import deepcopy
allData18 = readLines(filename18)
print(allData18[1])
print(len(allData18))
winRecord18 = []
lossRecord18 = []
for tg in allData18:
  tg.previous = True
  if tg.WinID and not tg.Playoffs:
    winRecord18.append(tg.TeamID)
  elif not tg.Playoffs:
    lossRecord18.append(tg.TeamID)
print(len(allData18))
# Out:
# ['2017-10-17', '982028', '1', 'Houston', '25', 'Golden State', 'V', '', 'Western', '', 'W', '', '237', '122', '47', '96', '15', '41', '13', '19', '41', '27', '10', '5', '9', '12', '15']
# <__main__.aGame object at 0x7f5f18f87510>
# 2622
# 2622

# %%
from collections import Counter
wr = Counter(winRecord18).most_common()
lr = Counter(lossRecord18).most_common()

# %%
allData = readLines(filename)
print(allData[1])
print(len(allData))
# Out:
# ['2018-10-16', '985248', '5', 'Boston', '28', 'Philadelphia', 'H', '', '', '', 'W', '', '234', '103', '41', '96', '11', '37', '10', '14', '54', '21', '7', '6', '12', '14', '20']
# <__main__.aGame object at 0x7f5f18bd98d0>
# 2580

# %%
tempD = allData[0:400]
tIDs = list(set(map(lambda x: x.TeamID, tempD)))
print(len(tIDs))
# Out:
# 30

# %%
from collections import defaultdict
dic = defaultdict(lambda: "Not Present")
for t in tIDs:
  w = list(filter(lambda x: x[0] == t, wr))[0][1]
  l = list(filter(lambda x: x[0] == t, lr))[0][1]
  dic[t] = w/(w+l)

# %%
for tg in allData:
  previousGamesList = list(filter(lambda g: (g.DayCount < tg.DayCount) and (g.TeamID == tg.TeamID), allData))
  pMIN = 0
  pPTS = 0
  pFGM = 0
  pFGA = 0
  pFM3 = 0
  pFA3 = 0
  pFTM = 0
  pFTA = 0
  pREB = 0
  pAST = 0
  pSTL = 0
  pBLK = 0
  pOREB = 0
  pTO = 0
  pPF = 0
  pWin = 0
  pLoss = 0
  for p in previousGamesList:
    g = p.TStats
    pMIN += g.MIN
    pPTS += g.PTS
    pFGM += g.FGM
    pFGA += g.FGA
    pFM3 += g.FM3
    pFA3 += g.FA3
    pFTM += g.FTM
    pFTA += g.FTA
    pREB += g.REB
    pAST += g.AST
    pSTL += g.STL
    pBLK += g.BLK
    pOREB += g.OREB
    pTO += g.TO
    pPF += g.PF
    pWin += p.WinID
    pLoss += p.LossID
  gPlayed = len(previousGamesList)
  if gPlayed > 0:
    tg.TStatsP.update(pMIN/gPlayed, pPTS/gPlayed, pFGM/gPlayed, pFGA/gPlayed, pFM3/gPlayed,
                      pFA3/gPlayed, pFTM/gPlayed, pFTA/gPlayed, pREB/gPlayed, pAST/gPlayed,
                      pSTL/gPlayed, pBLK/gPlayed, pOREB/gPlayed, pTO/gPlayed, pPF/gPlayed)
    tg.TStatsP.addWinRate(pWin, pLoss)
  else:
    tg.TStatsP.update(234, 100, 44, 90, 10,
                      30, 20, 25, 45, 25,
                      7, 7, 11, 15, 22)
    tg.TStatsP.addWinRate(1, 1)
    #Random for the first game
allGames = []
for d in allData:
  d.updateLastWRate(dic[d.TeamID])
  sameGameList = list(filter(lambda g: g.GameID == d.GameID, allGames))
  if len(sameGameList) > 0:
    for g in sameGameList:
      if g.Home: 
        g.OppStats = deepcopy(d.TStats)
        g.OppStatsP = deepcopy(d.TStatsP)
      else:
        d.OppStats = deepcopy(g.TStats)
        d.OppStatsP = deepcopy(g.TStatsP)
        allGames.remove(g)
        allGames.append(d)
  else:
    allGames.append(d)
allData = allGames
print(len(allData))
# Out:
# 1290

# %%
print(len(allData18))
allGames18 = []
setGameID = set(map(lambda g: g.GameID, allData18))

for d in setGameID:
  #d.updateLastWRate(dic[d.TeamID])
  sameGame = list(filter(lambda g: g.GameID == d, allData18))[0]
  sameGame.previous = True
  allGames18.append(sameGame)
allData18 = list(filter(lambda g: not g.Playoffs, allGames18))
print(len(allData18))
allData18.sort(key = lambda g: g.GameDay)
print(len(allData18))
# Out:
# 2622
# 1230
# 1230

# %%
def sep2Groups(allD, afterN, oldData):#For Ranking
  allDataP = list(filter(lambda g:not g.Playoffs, allD))
  test_daysAfterN = list(filter(lambda g: g.DayCount >= afterN, allDataP))
  test_daysAfterN = list(map(lambda g: g.DayCount, test_daysAfterN))
  test_days = list(set(test_daysAfterN))
  test_days.sort()

  test_listGroups = []
  train_listGroups = []
  for daysC in test_days:
    tempL = list(filter(lambda g: g.DayCount < daysC, allDataP))
    tempOldData = []
    if len(tempL) < len(oldData):
      tempOldData = oldData[(len(tempL) - len(oldData)): ]
    train_listGroups.append(tempL + tempOldData)
    test_listGroups.append(list(filter(lambda g: g.DayCount >= daysC, allDataP)))
  return (train_listGroups, test_listGroups)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

def gametoTensor(g : aGame):
  tensor = torch.zeros(1, 1, 82)
  
  tensor[0][0][g.TeamID] = 1
  tensor[0][0][g.OpponentID+37] = 1
  tensor[0][0][77] = g.DayCount/300
  tensor[0][0][78] = int(g.previous)
  tensor[0][0][79] = g.TStatsP.Win/72
  tensor[0][0][80] = g.TStatsP.Loss/72
  tensor[0][0][81] = g.TStatsP.WinRate
  #winloss
  #previous win loss
  
  return tensor

def gamestoTensorTrain(games, test = False):
  g_tensor_list = []
  currentWinRecord = []
  for g in games:
    g_tensor_list.append((gametoTensor(g), g.WinID))
    if g.WinID > 0 and not g.previous:
      currentWinRecord.append(g.TeamID)
    elif not g.previous:
      currentWinRecord.append(g.OpponentID)
  return g_tensor_list, currentWinRecord
def gamestoTensorTest(games, test = False):
  g_tensor_list = []
  for g in games:
    g_tensor_list.append((gametoTensor(g), g.WinID, g.TeamID, g.OpponentID))
  return g_tensor_list

# %%
def allTeamsComb(day):
  rankTestList = []
  tempLine = ['2018-10-16', '985248', '5', 'Boston', '28', 'Philadelphia', 
                'H', '', '', '', 'W', '', '234', '103', '41', '96', '11', '37', 
                '10', '14', '54', '21', '7', '6', '12', '14', '20']
  for a in tIDs:
    for b in tIDs:
      if a != b:
        testG = aLinetoGame(tempLine)
        testG.TeamID = a
        testG.OpponentID = b
        testG.DayCount = day
        testG.updateLastWRate(dic[a])
        testG.TStatsP.addWinRate(1, 1)
        rankTestList.append((gametoTensor(testG), a, b))
  return rankTestList

# %%
def getRankList(rankRecord):
  #print(len(rankRecord))
  rC = Counter(rankRecord).most_common()

  r = list(map(lambda x: x[0], rC))
  nRank = []
  for a in tIDs:
    if a not in r:
      nRank.append(30)
    else:
      nRank.append(r.index(a)+1)
  return nRank

# %%
allRecord = []
nonPlayoffData = list(filter(lambda g:not g.Playoffs, allData))
print(len(allData))
for g in nonPlayoffData:
  if g.WinID> 0 :
    allRecord.append(g.TeamID)
  else:
    allRecord.append(g.OpponentID)
print(len(allRecord))
playOffRanking = getRankList(allRecord)
print(playOffRanking)
# Out:
# 1290
# 1208
# [7, 21, 17, 6, 9, 26, 1, 27, 28, 2, 13, 15, 29, 18, 19, 10, 12, 25, 30, 14, 23, 4, 3, 8, 20, 5, 22, 11, 16, 24]

# %%
import time
import math
from statistics import mean
import scipy.stats as stats
from scipy.stats import kendalltau
def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def runModel(train_listGroups, test_listGroups):
  start = time.time()
  train_tlistGroups = list(map(lambda group: gamestoTensorTrain(group), train_listGroups))
  test_tlistGroups = list(map(lambda group: gamestoTensorTest(group, test = True), test_listGroups))
  totalR_list = []
  print(len(train_tlistGroups), len(test_tlistGroups))
  for t in range(len(train_tlistGroups)):
    print('Model: ', t)
    model = nn.Sequential(nn.Linear(82, 64),
                          nn.Tanh(),
                          nn.Linear(64, 16),
                          nn.Tanh(),
                          nn.Linear(16, 2),
                          nn.LogSoftmax(dim=1))
    #model = model.to(device=device)
    learning_rate = 0.005
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    loss_fn = nn.NLLLoss()#meansquarerror
    n_epochs = 30
    currentRecord = train_tlistGroups[t][1]
    #print(len(currentRecord))
    for epoch in range(n_epochs):
      
      train_loader = torch.utils.data.DataLoader(train_tlistGroups[t][0], batch_size = 2, shuffle = True)
      for gs, labels in train_loader:
        #gs = gs.to(device=device)
        #labels = labels.to(device = device)
        batch_size = gs.shape[0]
        outputs = model(gs.view(batch_size, -1))
        loss = loss_fn(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
      if (epoch+1)%10 == 0:
        print(timeSince(start))
        print("Epoch: %d, Loss: %f" % (epoch, float(loss)))

    powerTestList = allTeamsComb(test_listGroups[t][0].DayCount)
    powerRankRecord = []
    for k, a, b in powerTestList:
      outputs = model(k.view(1, -1))
      #print(outputs)
      _, predicted = torch.max(outputs, dim=1)
      #print(predicted)
      if predicted == 1:
        powerRankRecord.append(a)
      else:
        powerRankRecord.append(b)
    powerRankList = getRankList(powerRankRecord)#Power Ranking
    #print(playOffRanking)
    powTau, _ = kendalltau(playOffRanking, powerRankList)
    print(powTau)
    scheduleRecord = []
    for gt, label, tID, oID in test_tlistGroups[t]:
      outputs = model(gt.view(1, -1))
      _, predicted = torch.max(outputs, dim=1)
      if predicted:
        scheduleRecord.append(tID)
      else:
        scheduleRecord.append(oID)
    #print(len(currentRecord+scheduleRecord))
    fakePlayOffRanking = getRankList(currentRecord+scheduleRecord)
    playTau, _ = kendalltau(playOffRanking, fakePlayOffRanking)
    print(playTau)
    totalR_list.append((t, powTau, playTau))
  print(timeSince(start))
  return totalR_list

# %%
def writeInRank(newRecord):
  p1Name='/content/gdrive/My Drive/2021 Fall/Thesis I/Records/Rank2_22D.txt'
  p1file=open(p1Name)
  p1file_content = p1file.read()
  p1file=open(p1Name,"w")
  p1file.write(p1file_content)
  for d, pow, p in newRecord:
    p1file.write(str(d)+" "+ str(pow) + " " + str(p) + "\n")
  p1file.write("-\n")
  p1file=open(p1Name)
  p1file_content = p1file.read()
  #print(p1file_content)
  p1file.close()

# %%
allData18.sort(key = lambda x: x.GameDay)
print(len(allData18))
trainGs, testGs = sep2Groups(allData, 5, allData18[-int(len(allData18)/4):])
print(len(trainGs), len(testGs))
# Out:
# 1230
# 163 163

# %%
for i in range(30):
  print('Run %d' %i)
  writeInRank(runModel(trainGs, testGs))
# Out:
# Streaming output truncated to the last 5000 lines.
# 6m 58s
# Epoch: 29, Loss: 0.247969
# 0.7517241379310345
# 0.7379310344827587
# Model:  98
# 7m 0s
# Epoch: 9, Loss: 0.472969
# 7m 2s
# Epoch: 19, Loss: 1.599893
# 7m 4s
# Epoch: 29, Loss: 0.084255
# 0.7471264367816092
# 0.7747126436781608
# Model:  99
# 7m 7s
# Epoch: 9, Loss: 0.993565
# 7m 9s
# Epoch: 19, Loss: 0.520706
# 7m 11s
# Epoch: 29, Loss: 0.863399
# 0.7655172413793103
# 0.7195402298850575
# Model:  100
# 7m 14s
# Epoch: 9, Loss: 1.042636
# 7m 16s
# Epoch: 19, Loss: 0.663585
# 7m 18s
# Epoch: 29, Loss: 1.106344
# 0.7793103448275862
# 0.7747126436781608
# Model:  101
# 7m 20s
# Epoch: 9, Loss: 0.500655
# 7m 23s
# Epoch: 19, Loss: 0.265814
# 7m 25s
# Epoch: 29, Loss: 0.868280
# 0.7931034482758622
# 0.7793103448275862
# Model:  102
# 7m 27s
# Epoch: 9, Loss: 0.737956
# 7m 29s
# Epoch: 19, Loss: 1.124908
# 7m 32s
# Epoch: 29, Loss: 0.251040
# 0.7747126436781608
# 0.8068965517241379
# Model:  103
# 7m 34s
# Epoch: 9, Loss: 0.370188
# 7m 36s
# Epoch: 19, Loss: 1.615630
# 7m 39s
# Epoch: 29, Loss: 0.201202
# 0.7793103448275862
# 0.8206896551724139
# Model:  104
# 7m 41s
# Epoch: 9, Loss: 0.475738
# 7m 43s
# Epoch: 19, Loss: 0.712976
# 7m 45s
# Epoch: 29, Loss: 0.452061
# 0.8022988505747127
# 0.8114942528735632
# Model:  105
# 7m 48s
# Epoch: 9, Loss: 0.675551
# 7m 50s
# Epoch: 19, Loss: 1.096734
# 7m 52s
# Epoch: 29, Loss: 0.613615
# 0.8022988505747127
# 0.7977011494252874
# Model:  106
# 7m 55s
# Epoch: 9, Loss: 0.840197
# 7m 57s
# Epoch: 19, Loss: 0.346007
# 8m 0s
# Epoch: 29, Loss: 0.467181
# 0.7517241379310345
# 0.7977011494252874
# Model:  107
# 8m 2s
# Epoch: 9, Loss: 0.517588
# 8m 5s
# Epoch: 19, Loss: 0.774780
# 8m 7s
# Epoch: 29, Loss: 0.289119
# 0.7839080459770115
# 0.8206896551724139
# Model:  108
# 8m 10s
# Epoch: 9, Loss: 0.657601
# 8m 12s
# Epoch: 19, Loss: 0.519419
# 8m 14s
# Epoch: 29, Loss: 0.174446
# 0.7471264367816092
# 0.8114942528735632
# Model:  109
# 8m 17s
# Epoch: 9, Loss: 0.394943
# 8m 19s
# Epoch: 19, Loss: 0.479296
# 8m 21s
# Epoch: 29, Loss: 0.771771
# 0.7471264367816092
# 0.8206896551724139
# Model:  110
# 8m 24s
# Epoch: 9, Loss: 0.628422
# 8m 26s
# Epoch: 19, Loss: 0.239194
# 8m 29s
# Epoch: 29, Loss: 1.070451
# 0.7471264367816092
# 0.7931034482758622
# Model:  111
# 8m 31s
# Epoch: 9, Loss: 0.871238
# 8m 34s
# Epoch: 19, Loss: 0.178969
# 8m 36s
# Epoch: 29, Loss: 0.727125
# 0.7655172413793103
# 0.8068965517241379
# Model:  112
# 8m 39s
# Epoch: 9, Loss: 0.542913
# 8m 41s
# Epoch: 19, Loss: 0.200724
# 8m 43s
# Epoch: 29, Loss: 0.504122
# 0.7287356321839081
# 0.8022988505747127
# Model:  113
# 8m 46s
# Epoch: 9, Loss: 0.859955
# 8m 49s
# Epoch: 19, Loss: 0.171187
# 8m 51s
# Epoch: 29, Loss: 0.858435
# 0.7839080459770115
# 0.825287356321839
# Model:  114
# 8m 54s
# Epoch: 9, Loss: 0.577420
# 8m 56s
# Epoch: 19, Loss: 0.163517
# 8m 59s
# Epoch: 29, Loss: 0.674650
# 0.7563218390804598
# 0.8436781609195403
# Model:  115
# 9m 1s
# Epoch: 9, Loss: 0.825641
# 9m 4s
# Epoch: 19, Loss: 0.480635
# 9m 6s
# Epoch: 29, Loss: 0.203192
# 0.7655172413793103
# 0.8344827586206897
# Model:  116
# 9m 9s
# Epoch: 9, Loss: 0.575054
# 9m 12s
# Epoch: 19, Loss: 1.083494
# 9m 14s
# Epoch: 29, Loss: 0.576663
# 0.7517241379310345
# 0.8068965517241379
# Model:  117
# 9m 17s
# Epoch: 9, Loss: 0.690673
# 9m 19s
# Epoch: 19, Loss: 0.292981
# 9m 22s
# Epoch: 29, Loss: 0.767155
# 0.7839080459770115
# 0.825287356321839
# Model:  118
# 9m 24s
# Epoch: 9, Loss: 0.641711
# 9m 27s
# Epoch: 19, Loss: 0.289492
# 9m 29s
# Epoch: 29, Loss: 0.138264
# 0.7793103448275862
# 0.8528735632183909
# Model:  119
# 9m 32s
# Epoch: 9, Loss: 0.898031
# 9m 35s
# Epoch: 19, Loss: 0.504198
# 9m 38s
# Epoch: 29, Loss: 0.449504
# 0.7839080459770115
# 0.8574712643678161
# Model:  120
# 9m 41s
# Epoch: 9, Loss: 0.676789
# 9m 43s
# Epoch: 19, Loss: 0.224472
# 9m 46s
# Epoch: 29, Loss: 0.250053
# 0.7931034482758622
# 0.8574712643678161
# Model:  121
# 9m 49s
# Epoch: 9, Loss: 0.817929
# 9m 52s
# Epoch: 19, Loss: 1.104627
# 9m 54s
# Epoch: 29, Loss: 0.441327
# 0.7931034482758622
# 0.8528735632183909
# Model:  122
# 9m 57s
# Epoch: 9, Loss: 0.383994
# 10m 0s
# Epoch: 19, Loss: 0.778606
# 10m 3s
# Epoch: 29, Loss: 0.285064
# 0.7977011494252874
# 0.8758620689655172
# Model:  123
# 10m 6s
# Epoch: 9, Loss: 0.494630
# 10m 9s
# Epoch: 19, Loss: 0.758713
# 10m 12s
# Epoch: 29, Loss: 0.691063
# 0.7885057471264368
# 0.8528735632183909
# Model:  124
# 10m 15s
# Epoch: 9, Loss: 0.881205
# 10m 17s
# Epoch: 19, Loss: 0.781570
# 10m 20s
# Epoch: 29, Loss: 1.102536
# 0.7747126436781608
# 0.871264367816092
# Model:  125
# 10m 23s
# Epoch: 9, Loss: 0.591156
# 10m 26s
# Epoch: 19, Loss: 0.349621
# 10m 29s
# Epoch: 29, Loss: 0.876149
# 0.7977011494252874
# 0.8850574712643677
# Model:  126
# 10m 33s
# Epoch: 9, Loss: 0.539871
# 10m 36s
# Epoch: 19, Loss: 1.214395
# 10m 39s
# Epoch: 29, Loss: 0.182686
# 0.825287356321839
# 0.8620689655172414
# Model:  127
# 10m 42s
# Epoch: 9, Loss: 0.411285
# 10m 45s
# Epoch: 19, Loss: 0.178757
# 10m 48s
# Epoch: 29, Loss: 0.498828
# 0.7931034482758622
# 0.8390804597701149
# Model:  128
# 10m 51s
# Epoch: 9, Loss: 0.505531
# 10m 54s
# Epoch: 19, Loss: 0.486510
# 10m 57s
# Epoch: 29, Loss: 0.257362
# 0.8160919540229885
# 0.8758620689655172
# Model:  129
# 11m 0s
# Epoch: 9, Loss: 0.892586
# 11m 3s
# Epoch: 19, Loss: 0.458250
# 11m 7s
# Epoch: 29, Loss: 0.285667
# 0.8022988505747127
# 0.8436781609195403
# Model:  130
# 11m 10s
# Epoch: 9, Loss: 0.323630
# 11m 13s
# Epoch: 19, Loss: 0.391448
# 11m 17s
# Epoch: 29, Loss: 0.467584
# 0.8068965517241379
# 0.8758620689655172
# Model:  131
# 11m 20s
# Epoch: 9, Loss: 0.522538
# 11m 23s
# Epoch: 19, Loss: 0.487887
# 11m 26s
# Epoch: 29, Loss: 0.669822
# 0.8390804597701149
# 0.903448275862069
# Model:  132
# 11m 30s
# Epoch: 9, Loss: 0.340127
# 11m 33s
# Epoch: 19, Loss: 0.445526
# 11m 37s
# Epoch: 29, Loss: 0.456847
# 0.8298850574712644
# 0.8850574712643677
# Model:  133
# 11m 40s
# Epoch: 9, Loss: 0.355233
# 11m 44s
# Epoch: 19, Loss: 1.482287
# 11m 47s
# Epoch: 29, Loss: 0.492190
# 0.825287356321839
# 0.8482758620689655
# Model:  134
# 11m 51s
# Epoch: 9, Loss: 0.462098
# 11m 54s
# Epoch: 19, Loss: 0.248854
# 11m 57s
# Epoch: 29, Loss: 2.117843
# 0.7977011494252874
# 0.8620689655172414
# Model:  135
# 12m 1s
# Epoch: 9, Loss: 0.633319
# 12m 4s
# Epoch: 19, Loss: 0.553449
# 12m 7s
# Epoch: 29, Loss: 0.720225
# 0.825287356321839
# 0.8666666666666667
# Model:  136
# 12m 11s
# Epoch: 9, Loss: 0.873202
# 12m 15s
# Epoch: 19, Loss: 0.686517
# 12m 18s
# Epoch: 29, Loss: 0.220439
# 0.7977011494252874
# 0.8666666666666667
# Model:  137
# 12m 22s
# Epoch: 9, Loss: 0.518731
# 12m 25s
# Epoch: 19, Loss: 0.174748
# 12m 28s
# Epoch: 29, Loss: 0.634279
# 0.8390804597701149
# 0.8620689655172414
# Model:  138
# 12m 32s
# Epoch: 9, Loss: 0.800490
# 12m 35s
# Epoch: 19, Loss: 0.515825
# 12m 39s
# Epoch: 29, Loss: 1.426329
# 0.8298850574712644
# 0.8850574712643677
# Model:  139
# 12m 42s
# Epoch: 9, Loss: 0.521191
# 12m 46s
# Epoch: 19, Loss: 0.227328
# 12m 49s
# Epoch: 29, Loss: 0.144614
# 0.8022988505747127
# 0.8758620689655172
# Model:  140
# 12m 53s
# Epoch: 9, Loss: 0.546057
# 12m 56s
# Epoch: 19, Loss: 1.169245
# 13m 0s
# Epoch: 29, Loss: 0.688913
# 0.8298850574712644
# 0.9080459770114943
# Model:  141
# 13m 3s
# Epoch: 9, Loss: 0.513970
# 13m 6s
# Epoch: 19, Loss: 1.011691
# 13m 10s
# Epoch: 29, Loss: 0.262145
# 0.8528735632183909
# 0.9080459770114943
# Model:  142
# 13m 13s
# Epoch: 9, Loss: 0.638115
# 13m 16s
# Epoch: 19, Loss: 0.752389
# 13m 19s
# Epoch: 29, Loss: 0.319471
# 0.8068965517241379
# 0.8988505747126437
# Model:  143
# 13m 23s
# Epoch: 9, Loss: 0.470996
# 13m 26s
# Epoch: 19, Loss: 0.779583
# 13m 30s
# Epoch: 29, Loss: 1.399478
# 0.871264367816092
# 0.9126436781609196
# Model:  144
# 13m 33s
# Epoch: 9, Loss: 0.241471
# 13m 37s
# Epoch: 19, Loss: 0.615075
# 13m 40s
# Epoch: 29, Loss: 0.357496
# 0.8160919540229885
# 0.871264367816092
# Model:  145
# 13m 43s
# Epoch: 9, Loss: 0.385302
# 13m 47s
# Epoch: 19, Loss: 0.826920
# 13m 50s
# Epoch: 29, Loss: 0.516811
# 0.8528735632183909
# 0.9126436781609196
# Model:  146
# 13m 54s
# Epoch: 9, Loss: 0.981461
# 13m 58s
# Epoch: 19, Loss: 0.625609
# 14m 1s
# Epoch: 29, Loss: 0.997399
# 0.825287356321839
# 0.8758620689655172
# Model:  147
# 14m 5s
# Epoch: 9, Loss: 0.385482
# 14m 8s
# Epoch: 19, Loss: 0.127042
# 14m 11s
# Epoch: 29, Loss: 0.181268
# 0.825287356321839
# 0.8850574712643677
# Model:  148
# 14m 15s
# Epoch: 9, Loss: 0.394359
# 14m 18s
# Epoch: 19, Loss: 0.958560
# 14m 22s
# Epoch: 29, Loss: 0.327819
# 0.825287356321839
# 0.8850574712643677
# Model:  149
# 14m 25s
# Epoch: 9, Loss: 0.577468
# 14m 28s
# Epoch: 19, Loss: 0.792742
# 14m 32s
# Epoch: 29, Loss: 0.705411
# 0.8206896551724139
# 0.9264367816091954
# Model:  150
# 14m 35s
# Epoch: 9, Loss: 0.628466
# 14m 38s
# Epoch: 19, Loss: 0.847336
# 14m 42s
# Epoch: 29, Loss: 0.308258
# 0.8482758620689655
# 0.9310344827586208
# Model:  151
# 14m 45s
# Epoch: 9, Loss: 0.926225
# 14m 48s
# Epoch: 19, Loss: 1.480320
# 14m 52s
# Epoch: 29, Loss: 1.319190
# 0.8160919540229885
# 0.8942528735632185
# Model:  152
# 14m 55s
# Epoch: 9, Loss: 1.000860
# 14m 59s
# Epoch: 19, Loss: 0.227021
# 15m 2s
# Epoch: 29, Loss: 0.097479
# 0.8620689655172414
# 0.9126436781609196
# Model:  153
# 15m 6s
# Epoch: 9, Loss: 0.730536
# 15m 9s
# Epoch: 19, Loss: 0.848498
# 15m 12s
# Epoch: 29, Loss: 0.439284
# 0.8896551724137931
# 0.903448275862069
# Model:  154
# 15m 16s
# Epoch: 9, Loss: 0.564270
# 15m 19s
# Epoch: 19, Loss: 0.826605
# 15m 22s
# Epoch: 29, Loss: 0.367706
# 0.8758620689655172
# 0.8988505747126437
# Model:  155
# 15m 26s
# Epoch: 9, Loss: 0.302475
# 15m 30s
# Epoch: 19, Loss: 1.474840
# 15m 33s
# Epoch: 29, Loss: 0.596664
# 0.8298850574712644
# 0.9126436781609196
# Model:  156
# 15m 37s
# Epoch: 9, Loss: 0.317239
# 15m 40s
# Epoch: 19, Loss: 0.661364
# 15m 44s
# Epoch: 29, Loss: 0.974157
# 0.7977011494252874
# 0.9080459770114943
# Model:  157
# 15m 47s
# Epoch: 9, Loss: 0.671695
# 15m 51s
# Epoch: 19, Loss: 0.599482
# 15m 54s
# Epoch: 29, Loss: 0.437536
# 0.8344827586206897
# 0.9310344827586208
# Model:  158
# 15m 57s
# Epoch: 9, Loss: 0.760237
# 16m 1s
# Epoch: 19, Loss: 0.110600
# 16m 4s
# Epoch: 29, Loss: 0.266471
# 0.8620689655172414
# 0.9264367816091954
# Model:  159
# 16m 8s
# Epoch: 9, Loss: 0.475001
# 16m 11s
# Epoch: 19, Loss: 0.562962
# 16m 15s
# Epoch: 29, Loss: 0.271532
# 0.8528735632183909
# 0.9494252873563218
# Model:  160
# 16m 18s
# Epoch: 9, Loss: 0.659089
# 16m 22s
# Epoch: 19, Loss: 0.527376
# 16m 25s
# Epoch: 29, Loss: 0.602554
# 0.8390804597701149
# 0.9540229885057472
# Model:  161
# 16m 29s
# Epoch: 9, Loss: 0.254739
# 16m 32s
# Epoch: 19, Loss: 0.638071
# 16m 36s
# Epoch: 29, Loss: 0.221601
# 0.8160919540229885
# 0.9908045977011495
# Model:  162
# 16m 39s
# Epoch: 9, Loss: 0.680765
# 16m 43s
# Epoch: 19, Loss: 0.242906
# 16m 46s
# Epoch: 29, Loss: 0.401343
# 0.8482758620689655
# 0.9862068965517242
# 16m 46s
# Run 27
# 163 163
# Model:  0
# 0m 11s
# Epoch: 9, Loss: 0.615102
# 0m 12s
# Epoch: 19, Loss: 0.665200
# 0m 13s
# Epoch: 29, Loss: 0.436750
# 0.37931034482758624
# 0.4574712643678161
# Model:  1
# 0m 14s
# Epoch: 9, Loss: 0.617849
# 0m 15s
# Epoch: 19, Loss: 0.609878
# 0m 16s
# Epoch: 29, Loss: 0.412938
# 0.4298850574712643
# 0.4988505747126437
# Model:  2
# 0m 17s
# Epoch: 9, Loss: 0.677400
# 0m 18s
# Epoch: 19, Loss: 0.632384
# 0m 19s
# Epoch: 29, Loss: 0.482343
# 0.5310344827586208
# 0.6413793103448276
# Model:  3
# 0m 20s
# Epoch: 9, Loss: 0.589728
# 0m 21s
# Epoch: 19, Loss: 0.588467
# 0m 22s
# Epoch: 29, Loss: 0.807192
# 0.5080459770114942
# 0.5770114942528736
# Model:  4
# 0m 23s
# Epoch: 9, Loss: 0.667681
# 0m 24s
# Epoch: 19, Loss: 0.645814
# 0m 25s
# Epoch: 29, Loss: 0.655073
# 0.3701149425287356
# 0.48965517241379314
# Model:  5
# 0m 27s
# Epoch: 9, Loss: 0.650586
# 0m 27s
# Epoch: 19, Loss: 0.612283
# 0m 28s
# Epoch: 29, Loss: 0.256666
# 0.439080459770115
# 0.47126436781609193
# Model:  6
# 0m 30s
# Epoch: 9, Loss: 0.643135
# 0m 30s
# Epoch: 19, Loss: 0.738145
# 0m 31s
# Epoch: 29, Loss: 0.500775
# 0.5172413793103449
# 0.5494252873563219
# Model:  7
# 0m 33s
# Epoch: 9, Loss: 0.762613
# 0m 34s
# Epoch: 19, Loss: 0.643784
# 0m 34s
# Epoch: 29, Loss: 0.375479
# 0.48045977011494256
# 0.5540229885057472
# Model:  8
# 0m 36s
# Epoch: 9, Loss: 0.823093
# 0m 37s
# Epoch: 19, Loss: 0.602482
# 0m 37s
# Epoch: 29, Loss: 0.485600
# 0.48965517241379314
# 0.5678160919540229
# Model:  9
# 0m 39s
# Epoch: 9, Loss: 0.684250
# 0m 40s
# Epoch: 19, Loss: 0.641033
# 0m 41s
# Epoch: 29, Loss: 0.593120
# 0.4850574712643679
# 0.5172413793103449
# Model:  10
# 0m 42s
# Epoch: 9, Loss: 0.700592
# 0m 43s
# Epoch: 19, Loss: 0.646365
# 0m 44s
# Epoch: 29, Loss: 0.937107
# 0.42528735632183906
# 0.5402298850574713
# Model:  11
# 0m 45s
# Epoch: 9, Loss: 0.718731
# 0m 46s
# Epoch: 19, Loss: 0.713805
# 0m 47s
# Epoch: 29, Loss: 0.646842
# 0.24597701149425286
# 0.5678160919540229
# Model:  12
# 0m 48s
# Epoch: 9, Loss: 0.581820
# 0m 49s
# Epoch: 19, Loss: 0.604274
# 0m 50s
# Epoch: 29, Loss: 0.379830
# 0.4942528735632184
# 0.5310344827586208
# Model:  13
# 0m 51s
# Epoch: 9, Loss: 0.590756
# 0m 52s
# Epoch: 19, Loss: 0.547714
# 0m 53s
# Epoch: 29, Loss: 0.358955
# 0.5494252873563219
# 0.6229885057471265
# Model:  14
# 0m 54s
# Epoch: 9, Loss: 0.504794
# 0m 55s
# Epoch: 19, Loss: 0.736125
# 0m 56s
# Epoch: 29, Loss: 0.704077
# 0.5724137931034483
# 0.6183908045977011
# Model:  15
# 0m 57s
# Epoch: 9, Loss: 0.845840
# 0m 58s
# Epoch: 19, Loss: 0.479875
# 0m 59s
# Epoch: 29, Loss: 0.977748
# 0.46206896551724136
# 0.5678160919540229
# Model:  16
# 1m 0s
# Epoch: 9, Loss: 0.566164
# 1m 1s
# Epoch: 19, Loss: 0.395914
# 1m 2s
# Epoch: 29, Loss: 0.322214
# 0.6229885057471265
# 0.6965517241379311
# Model:  17
# 1m 3s
# Epoch: 9, Loss: 0.545315
# 1m 4s
# Epoch: 19, Loss: 0.715449
# 1m 5s
# Epoch: 29, Loss: 0.497809
# 0.5816091954022989
# 0.6
# Model:  18
# 1m 6s
# Epoch: 9, Loss: 0.656808
# 1m 7s
# Epoch: 19, Loss: 0.476743
# 1m 8s
# Epoch: 29, Loss: 0.885808
# 0.7011494252873564
# 0.7011494252873564
# Model:  19
# 1m 9s
# Epoch: 9, Loss: 0.842987
# 1m 10s
# Epoch: 19, Loss: 0.805341
# 1m 11s
# Epoch: 29, Loss: 0.610373
# 0.6
# 0.6459770114942529
# Model:  20
# 1m 12s
# Epoch: 9, Loss: 0.540989
# 1m 13s
# Epoch: 19, Loss: 0.704199
# 1m 14s
# Epoch: 29, Loss: 0.300829
# 0.6735632183908047
# 0.6551724137931034
# Model:  21
# 1m 15s
# Epoch: 9, Loss: 0.514220
# 1m 16s
# Epoch: 19, Loss: 0.643354
# 1m 17s
# Epoch: 29, Loss: 0.385235
# 0.5586206896551724
# 0.6229885057471265
# Model:  22
# 1m 18s
# Epoch: 9, Loss: 0.543362
# 1m 19s
# Epoch: 19, Loss: 0.687113
# 1m 20s
# Epoch: 29, Loss: 0.602128
# 0.6873563218390805
# 0.6873563218390805
# Model:  23
# 1m 21s
# Epoch: 9, Loss: 0.653353
# 1m 22s
# Epoch: 19, Loss: 0.709890
# 1m 23s
# Epoch: 29, Loss: 0.538633
# 0.5678160919540229
# 0.6689655172413793
# Model:  24
# 1m 24s
# Epoch: 9, Loss: 0.542303
# 1m 25s
# Epoch: 19, Loss: 0.386730
# 1m 26s
# Epoch: 29, Loss: 0.219716
# 0.632183908045977
# 0.6827586206896552
# Model:  25
# 1m 27s
# Epoch: 9, Loss: 0.717836
# 1m 28s
# Epoch: 19, Loss: 0.576760
# 1m 29s
# Epoch: 29, Loss: 0.968176
# 0.7149425287356321
# 0.6873563218390805
# Model:  26
# 1m 30s
# Epoch: 9, Loss: 0.757060
# 1m 31s
# Epoch: 19, Loss: 0.514863
# 1m 32s
# Epoch: 29, Loss: 0.850699
# 0.4758620689655172
# 0.6367816091954024
# Model:  27
# 1m 33s
# Epoch: 9, Loss: 0.547801
# 1m 34s
# Epoch: 19, Loss: 0.947607
# 1m 35s
# Epoch: 29, Loss: 0.545457
# 0.5310344827586208
# 0.6183908045977011
# Model:  28
# 1m 36s
# Epoch: 9, Loss: 0.881419
# 1m 37s
# Epoch: 19, Loss: 0.443798
# 1m 38s
# Epoch: 29, Loss: 0.920448
# 0.6459770114942529
# 0.6459770114942529
# Model:  29
# 1m 39s
# Epoch: 9, Loss: 0.581761
# 1m 40s
# Epoch: 19, Loss: 0.445148
# 1m 41s
# Epoch: 29, Loss: 0.351319
# 0.3103448275862069
# 0.5724137931034483
# Model:  30
# 1m 42s
# Epoch: 9, Loss: 0.880041
# 1m 43s
# Epoch: 19, Loss: 0.589193
# 1m 44s
# Epoch: 29, Loss: 0.447516
# 0.42528735632183906
# 0.535632183908046
# Model:  31
# 1m 45s
# Epoch: 9, Loss: 0.481237
# 1m 46s
# Epoch: 19, Loss: 0.489385
# 1m 47s
# Epoch: 29, Loss: 0.528936
# 0.6045977011494253
# 0.5724137931034483
# Model:  32
# 1m 48s
# Epoch: 9, Loss: 0.661970
# 1m 49s
# Epoch: 19, Loss: 0.892557
# 1m 50s
# Epoch: 29, Loss: 0.538299
# 0.5310344827586208
# 0.5908045977011495
# Model:  33
# 1m 51s
# Epoch: 9, Loss: 0.497488
# 1m 52s
# Epoch: 19, Loss: 1.011673
# 1m 53s
# Epoch: 29, Loss: 0.646326
# 0.45287356321839084
# 0.5310344827586208
# Model:  34
# 1m 54s
# Epoch: 9, Loss: 0.895584
# 1m 55s
# Epoch: 19, Loss: 0.386156
# 1m 56s
# Epoch: 29, Loss: 0.249270
# 0.4758620689655172
# 0.5218390804597701
# Model:  35
# 1m 57s
# Epoch: 9, Loss: 0.556660
# 1m 58s
# Epoch: 19, Loss: 0.547484
# 1m 59s
# Epoch: 29, Loss: 0.750404
# 0.40689655172413797
# 0.535632183908046
# Model:  36
# 2m 0s
# Epoch: 9, Loss: 0.492489
# 2m 1s
# Epoch: 19, Loss: 0.838735
# 2m 2s
# Epoch: 29, Loss: 0.441589
# 0.36551724137931035
# 0.4942528735632184
# Model:  37
# 2m 3s
# Epoch: 9, Loss: 0.907002
# 2m 4s
# Epoch: 19, Loss: 0.401260
# 2m 5s
# Epoch: 29, Loss: 0.335916
# 0.6045977011494253
# 0.5954022988505747
# Model:  38
# 2m 6s
# Epoch: 9, Loss: 0.499515
# 2m 7s
# Epoch: 19, Loss: 0.907321
# 2m 8s
# Epoch: 29, Loss: 0.461106
# 0.03908045977011494
# 0.5770114942528736
# Model:  39
# 2m 9s
# Epoch: 9, Loss: 0.483170
# 2m 10s
# Epoch: 19, Loss: 0.383669
# 2m 11s
# Epoch: 29, Loss: 0.545027
# 0.5678160919540229
# 0.5862068965517242
# Model:  40
# 2m 12s
# Epoch: 9, Loss: 0.460942
# 2m 13s
# Epoch: 19, Loss: 0.728732
# 2m 14s
# Epoch: 29, Loss: 0.602261
# 0.4574712643678161
# 0.5586206896551724
# Model:  41
# 2m 15s
# Epoch: 9, Loss: 0.961513
# 2m 16s
# Epoch: 19, Loss: 0.407697
# 2m 17s
# Epoch: 29, Loss: 0.219130
# 0.5172413793103449
# 0.5770114942528736
# Model:  42
# 2m 19s
# Epoch: 9, Loss: 0.897710
# 2m 20s
# Epoch: 19, Loss: 0.465761
# 2m 21s
# Epoch: 29, Loss: 0.745730
# 0.4942528735632184
# 0.6045977011494253
# Model:  43
# 2m 22s
# Epoch: 9, Loss: 0.504261
# 2m 23s
# Epoch: 19, Loss: 1.212995
# 2m 24s
# Epoch: 29, Loss: 0.649397
# 0.4942528735632184
# 0.4666666666666667
# Model:  44
# 2m 25s
# Epoch: 9, Loss: 0.479500
# 2m 26s
# Epoch: 19, Loss: 0.504307
# 2m 27s
# Epoch: 29, Loss: 0.316546
# 0.4850574712643679
# 0.5264367816091954
# Model:  45
# 2m 29s
# Epoch: 9, Loss: 0.463620
# 2m 30s
# Epoch: 19, Loss: 0.477326
# 2m 31s
# Epoch: 29, Loss: 1.049612
# 0.4344827586206897
# 0.5402298850574713
# Model:  46
# 2m 32s
# Epoch: 9, Loss: 0.523848
# 2m 33s
# Epoch: 19, Loss: 0.893839
# 2m 34s
# Epoch: 29, Loss: 0.601594
# 0.5402298850574713
# 0.535632183908046
# Model:  47
# 2m 36s
# Epoch: 9, Loss: 0.917406
# 2m 37s
# Epoch: 19, Loss: 0.595134
# 2m 38s
# Epoch: 29, Loss: 0.399202
# 0.48965517241379314
# 0.5080459770114942
# Model:  48
# 2m 39s
# Epoch: 9, Loss: 0.627181
# 2m 40s
# Epoch: 19, Loss: 0.750716
# 2m 41s
# Epoch: 29, Loss: 0.700389
# 0.5494252873563219
# 0.5678160919540229
# Model:  49
# 2m 43s
# Epoch: 9, Loss: 0.674558
# 2m 44s
# Epoch: 19, Loss: 0.527262
# 2m 45s
# Epoch: 29, Loss: 0.657102
# 0.4988505747126437
# 0.5402298850574713
# Model:  50
# 2m 47s
# Epoch: 9, Loss: 0.490002
# 2m 48s
# Epoch: 19, Loss: 0.516970
# 2m 49s
# Epoch: 29, Loss: 0.340505
# 0.47126436781609193
# 0.5770114942528736
# Model:  51
# 2m 51s
# Epoch: 9, Loss: 0.726649
# 2m 52s
# Epoch: 19, Loss: 0.765144
# 2m 53s
# Epoch: 29, Loss: 0.522068
# 0.5264367816091954
# 0.6183908045977011
# Model:  52
# 2m 54s
# Epoch: 9, Loss: 0.468524
# 2m 56s
# Epoch: 19, Loss: 0.719045
# 2m 57s
# Epoch: 29, Loss: 0.237833
# 0.4942528735632184
# 0.5494252873563219
# Model:  53
# 2m 58s
# Epoch: 9, Loss: 0.467794
# 3m 0s
# Epoch: 19, Loss: 0.447577
# 3m 1s
# Epoch: 29, Loss: 0.238054
# 0.5402298850574713
# 0.5816091954022989
# Model:  54
# 3m 2s
# Epoch: 9, Loss: 0.946192
# 3m 4s
# Epoch: 19, Loss: 0.828725
# 3m 5s
# Epoch: 29, Loss: 0.873446
# 0.5632183908045977
# 0.5770114942528736
# Model:  55
# 3m 6s
# Epoch: 9, Loss: 0.941722
# 3m 8s
# Epoch: 19, Loss: 0.715349
# 3m 9s
# Epoch: 29, Loss: 0.404731
# 0.503448275862069
# 0.5402298850574713
# Model:  56
# 3m 11s
# Epoch: 9, Loss: 0.687567
# 3m 12s
# Epoch: 19, Loss: 0.432945
# 3m 13s
# Epoch: 29, Loss: 0.599193
# 0.5218390804597701
# 0.5908045977011495
# Model:  57
# 3m 15s
# Epoch: 9, Loss: 0.885100
# 3m 16s
# Epoch: 19, Loss: 0.514985
# 3m 17s
# Epoch: 29, Loss: 1.012144
# 0.6137931034482759
# 0.6597701149425287
# Model:  58
# 3m 19s
# Epoch: 9, Loss: 0.474884
# 3m 20s
# Epoch: 19, Loss: 0.250097
# 3m 22s
# Epoch: 29, Loss: 1.053625
# 0.6413793103448276
# 0.6505747126436782
# Model:  59
# 3m 23s
# Epoch: 9, Loss: 0.457612
# 3m 25s
# Epoch: 19, Loss: 0.450605
# 3m 26s
# Epoch: 29, Loss: 0.534013
# 0.7195402298850575
# 0.67816091954023
# Model:  60
# 3m 28s
# Epoch: 9, Loss: 0.506560
# 3m 29s
# Epoch: 19, Loss: 0.454792
# 3m 30s
# Epoch: 29, Loss: 0.581763
# 0.6
# 0.6183908045977011
# Model:  61
# 3m 32s
# Epoch: 9, Loss: 0.458435
# 3m 33s
# Epoch: 19, Loss: 0.779422
# 3m 35s
# Epoch: 29, Loss: 0.872865
# 0.6459770114942529
# 0.6551724137931034
# Model:  62
# 3m 36s
# Epoch: 9, Loss: 0.925185
# 3m 38s
# Epoch: 19, Loss: 0.731500
# 3m 39s
# Epoch: 29, Loss: 0.599036
# 0.6275862068965518
# 0.6505747126436782
# Model:  63
# 3m 41s
# Epoch: 9, Loss: 0.504413
# 3m 42s
# Epoch: 19, Loss: 0.572987
# 3m 44s
# Epoch: 29, Loss: 0.629854
# 0.5908045977011495
# 0.6275862068965518
# Model:  64
# 3m 46s
# Epoch: 9, Loss: 0.460721
# 3m 47s
# Epoch: 19, Loss: 0.418570
# 3m 49s
# Epoch: 29, Loss: 1.073349
# 0.6
# 0.6551724137931034
# Model:  65
# 3m 50s
# Epoch: 9, Loss: 0.472517
# 3m 52s
# Epoch: 19, Loss: 0.381440
# 3m 54s
# Epoch: 29, Loss: 0.561830
# 0.5448275862068965
# 0.5816091954022989
# Model:  66
# 3m 55s
# Epoch: 9, Loss: 0.945856
# 3m 57s
# Epoch: 19, Loss: 0.546125
# 3m 58s
# Epoch: 29, Loss: 0.709440
# 0.5816091954022989
# 0.6275862068965518
# Model:  67
# 4m 0s
# Epoch: 9, Loss: 0.482602
# 4m 2s
# Epoch: 19, Loss: 0.352315
# 4m 3s
# Epoch: 29, Loss: 0.277185
# 0.6229885057471265
# 0.6689655172413793
# Model:  68
# 4m 5s
# Epoch: 9, Loss: 0.472816
# 4m 6s
# Epoch: 19, Loss: 0.462691
# 4m 8s
# Epoch: 29, Loss: 1.307287
# 0.6
# 0.6183908045977011
# Model:  69
# 4m 10s
# Epoch: 9, Loss: 0.461450
# 4m 11s
# Epoch: 19, Loss: 0.903999
# 4m 13s
# Epoch: 29, Loss: 0.475629
# 0.6367816091954024
# 0.6689655172413793
# Model:  70
# 4m 15s
# Epoch: 9, Loss: 0.445334
# 4m 17s
# Epoch: 19, Loss: 0.376922
# 4m 18s
# Epoch: 29, Loss: 0.314635
# 0.5908045977011495
# 0.6459770114942529
# Model:  71
# 4m 20s
# Epoch: 9, Loss: 0.949846
# 4m 22s
# Epoch: 19, Loss: 0.358401
# 4m 23s
# Epoch: 29, Loss: 0.604967
# 0.6597701149425287
# 0.7057471264367816
# Model:  72
# 4m 25s
# Epoch: 9, Loss: 0.545817
# 4m 27s
# Epoch: 19, Loss: 0.523307
# 4m 29s
# Epoch: 29, Loss: 0.410007
# 0.6413793103448276
# 0.6965517241379311
# Model:  73
# 4m 30s
# Epoch: 9, Loss: 0.473137
# 4m 32s
# Epoch: 19, Loss: 0.458413
# 4m 34s
# Epoch: 29, Loss: 0.467482
# 0.6459770114942529
# 0.7471264367816092
# Model:  74
# 4m 35s
# Epoch: 9, Loss: 0.861588
# 4m 37s
# Epoch: 19, Loss: 0.881174
# 4m 39s
# Epoch: 29, Loss: 0.964888
# 0.6735632183908047
# 0.7609195402298851
# Model:  75
# 4m 41s
# Epoch: 9, Loss: 0.420556
# 4m 42s
# Epoch: 19, Loss: 0.303599
# 4m 44s
# Epoch: 29, Loss: 0.517148
# 0.6505747126436782
# 0.7149425287356321
# Model:  76
# 4m 46s
# Epoch: 9, Loss: 0.668649
# 4m 48s
# Epoch: 19, Loss: 0.215395
# 4m 49s
# Epoch: 29, Loss: 0.302592
# 0.7149425287356321
# 0.6827586206896552
# Model:  77
# 4m 51s
# Epoch: 9, Loss: 0.874629
# 4m 53s
# Epoch: 19, Loss: 0.526990
# 4m 55s
# Epoch: 29, Loss: 0.118759
# 0.6413793103448276
# 0.7287356321839081
# Model:  78
# 4m 57s
# Epoch: 9, Loss: 0.401877
# 4m 58s
# Epoch: 19, Loss: 0.183810
# 5m 0s
# Epoch: 29, Loss: 0.258633
# 0.664367816091954
# 0.7333333333333334
# Model:  79
# 5m 2s
# Epoch: 9, Loss: 0.480654
# 5m 4s
# Epoch: 19, Loss: 1.330493
# 5m 5s
# Epoch: 29, Loss: 0.129137
# 0.6045977011494253
# 0.6827586206896552
# Model:  80
# 5m 7s
# Epoch: 9, Loss: 0.881350
# 5m 9s
# Epoch: 19, Loss: 0.522822
# 5m 11s
# Epoch: 29, Loss: 1.434952
# 0.664367816091954
# 0.7057471264367816
# Model:  81
# 5m 13s
# Epoch: 9, Loss: 0.431638
# 5m 15s
# Epoch: 19, Loss: 0.493999
# 5m 17s
# Epoch: 29, Loss: 0.137289
# 0.6551724137931034
# 0.6459770114942529
# Model:  82
# 5m 19s
# Epoch: 9, Loss: 0.539530
# 5m 21s
# Epoch: 19, Loss: 1.049160
# 5m 22s
# Epoch: 29, Loss: 1.262702
# 0.6275862068965518
# 0.6551724137931034
# Model:  83
# 5m 24s
# Epoch: 9, Loss: 0.452678
# 5m 26s
# Epoch: 19, Loss: 0.427759
# 5m 28s
# Epoch: 29, Loss: 0.192824
# 0.6827586206896552
# 0.7149425287356321
# Model:  84
# 5m 30s
# Epoch: 9, Loss: 0.449513
# 5m 32s
# Epoch: 19, Loss: 1.018629
# 5m 34s
# Epoch: 29, Loss: 0.436501
# 0.6873563218390805
# 0.7057471264367816
# Model:  85
# 5m 36s
# Epoch: 9, Loss: 0.932261
# 5m 38s
# Epoch: 19, Loss: 0.314257
# 5m 40s
# Epoch: 29, Loss: 0.304245
# 0.7103448275862069
# 0.7057471264367816
# Model:  86
# 5m 42s
# Epoch: 9, Loss: 0.916181
# 5m 44s
# Epoch: 19, Loss: 0.878780
# 5m 46s
# Epoch: 29, Loss: 0.273235
# 0.7195402298850575
# 0.7287356321839081
# Model:  87
# 5m 48s
# Epoch: 9, Loss: 0.415914
# 5m 50s
# Epoch: 19, Loss: 0.615646
# 5m 52s
# Epoch: 29, Loss: 0.312458
# 0.6735632183908047
# 0.7379310344827587
# Model:  88
# 5m 54s
# Epoch: 9, Loss: 0.461923
# 5m 56s
# Epoch: 19, Loss: 0.919378
# 5m 58s
# Epoch: 29, Loss: 0.558673
# 0.7103448275862069
# 0.7471264367816092
# Model:  89
# 6m 0s
# Epoch: 9, Loss: 0.971049
# 6m 2s
# Epoch: 19, Loss: 0.174979
# 6m 4s
# Epoch: 29, Loss: 0.150325
# 0.7471264367816092
# 0.7747126436781608
# Model:  90
# 6m 6s
# Epoch: 9, Loss: 0.427968
# 6m 8s
# Epoch: 19, Loss: 0.984066
# 6m 10s
# Epoch: 29, Loss: 1.140095
# 0.7563218390804598
# 0.7701149425287357
# Model:  91
# 6m 12s
# Epoch: 9, Loss: 0.897799
# 6m 14s
# Epoch: 19, Loss: 0.198646
# 6m 16s
# Epoch: 29, Loss: 0.665241
# 0.7333333333333334
# 0.7563218390804598
# Model:  92
# 6m 18s
# Epoch: 9, Loss: 0.704063
# 6m 20s
# Epoch: 19, Loss: 0.605091
# 6m 22s
# Epoch: 29, Loss: 0.252044
# 0.7655172413793103
# 0.7839080459770115
# Model:  93
# 6m 25s
# Epoch: 9, Loss: 0.478157
# 6m 27s
# Epoch: 19, Loss: 0.559945
# 6m 29s
# Epoch: 29, Loss: 0.525968
# 0.7425287356321839
# 0.7517241379310345
# Model:  94
# 6m 31s
# Epoch: 9, Loss: 0.378512
# 6m 33s
# Epoch: 19, Loss: 0.206031
# 6m 35s
# Epoch: 29, Loss: 0.343984
# 0.7517241379310345
# 0.7747126436781608
# Model:  95
# 6m 38s
# Epoch: 9, Loss: 0.599976
# 6m 40s
# Epoch: 19, Loss: 0.417757
# 6m 42s
# Epoch: 29, Loss: 0.150401
# 0.7379310344827587
# 0.7701149425287357
# Model:  96
# 6m 44s
# Epoch: 9, Loss: 0.506736
# 6m 46s
# Epoch: 19, Loss: 0.326748
# 6m 48s
# Epoch: 29, Loss: 0.914851
# 0.7241379310344828
# 0.7517241379310345
# Model:  97
# 6m 51s
# Epoch: 9, Loss: 0.890975
# 6m 53s
# Epoch: 19, Loss: 0.534818
# 6m 55s
# Epoch: 29, Loss: 0.324948
# 0.7241379310344828
# 0.7379310344827587
# Model:  98
# 6m 57s
# Epoch: 9, Loss: 0.486957
# 6m 59s
# Epoch: 19, Loss: 0.355062
# 7m 2s
# Epoch: 29, Loss: 0.671483
# 0.7701149425287357
# 0.7793103448275862
# Model:  99
# 7m 4s
# Epoch: 9, Loss: 0.463610
# 7m 6s
# Epoch: 19, Loss: 0.532785
# 7m 8s
# Epoch: 29, Loss: 0.895464
# 0.7287356321839081
# 0.7241379310344828
# Model:  100
# 7m 11s
# Epoch: 9, Loss: 0.935037
# 7m 13s
# Epoch: 19, Loss: 0.548266
# 7m 15s
# Epoch: 29, Loss: 0.130279
# 0.7379310344827587
# 0.7655172413793103
# Model:  101
# 7m 18s
# Epoch: 9, Loss: 0.807180
# 7m 20s
# Epoch: 19, Loss: 0.189847
# 7m 22s
# Epoch: 29, Loss: 0.481953
# 0.7471264367816092
# 0.8068965517241379
# Model:  102
# 7m 25s
# Epoch: 9, Loss: 0.400479
# 7m 27s
# Epoch: 19, Loss: 0.371896
# 7m 29s
# Epoch: 29, Loss: 0.165349
# 0.7609195402298851
# 0.8068965517241379
# Model:  103
# 7m 32s
# Epoch: 9, Loss: 0.822837
# 7m 34s
# Epoch: 19, Loss: 0.967981
# 7m 36s
# Epoch: 29, Loss: 0.994637
# 0.7425287356321839
# 0.8022988505747127
# Model:  104
# 7m 39s
# Epoch: 9, Loss: 0.828807
# 7m 41s
# Epoch: 19, Loss: 0.710428
# 7m 44s
# Epoch: 29, Loss: 0.800779
# 0.7793103448275862
# 0.7885057471264368
# Model:  105
# 7m 46s
# Epoch: 9, Loss: 0.496470
# 7m 49s
# Epoch: 19, Loss: 0.315227
# 7m 51s
# Epoch: 29, Loss: 1.342947
# 0.7931034482758622
# 0.8114942528735632
# Model:  106
# 7m 53s
# Epoch: 9, Loss: 0.611254
# 7m 56s
# Epoch: 19, Loss: 1.333181
# 7m 58s
# Epoch: 29, Loss: 0.596048
# 0.7471264367816092
# 0.8068965517241379
# Model:  107
# 8m 1s
# Epoch: 9, Loss: 1.090247
# 8m 3s
# Epoch: 19, Loss: 0.098121
# 8m 6s
# Epoch: 29, Loss: 0.295156
# 0.7517241379310345
# 0.8022988505747127
# Model:  108
# 8m 9s
# Epoch: 9, Loss: 0.688220
# 8m 11s
# Epoch: 19, Loss: 0.372697
# 8m 14s
# Epoch: 29, Loss: 0.260267
# 0.7563218390804598
# 0.7885057471264368
# Model:  109
# 8m 16s
# Epoch: 9, Loss: 0.468403
# 8m 19s
# Epoch: 19, Loss: 0.134053
# 8m 21s
# Epoch: 29, Loss: 0.218802
# 0.7701149425287357
# 0.8114942528735632
# Model:  110
# 8m 24s
# Epoch: 9, Loss: 0.531752
# 8m 26s
# Epoch: 19, Loss: 0.403971
# 8m 29s
# Epoch: 29, Loss: 0.401680
# 0.7609195402298851
# 0.8022988505747127
# Model:  111
# 8m 31s
# Epoch: 9, Loss: 0.402191
# 8m 34s
# Epoch: 19, Loss: 1.535982
# 8m 37s
# Epoch: 29, Loss: 1.938281
# 0.7471264367816092
# 0.7977011494252874
# Model:  112
# 8m 39s
# Epoch: 9, Loss: 0.725696
# 8m 42s
# Epoch: 19, Loss: 0.971431
# 8m 44s
# Epoch: 29, Loss: 1.036602
# 0.7609195402298851
# 0.8022988505747127
# Model:  113
# 8m 47s
# Epoch: 9, Loss: 0.227905
# 8m 50s
# Epoch: 19, Loss: 0.836940
# 8m 52s
# Epoch: 29, Loss: 0.201180
# 0.7885057471264368
# 0.8298850574712644
# Model:  114
# 8m 55s
# Epoch: 9, Loss: 1.119451
# 8m 58s
# Epoch: 19, Loss: 0.305551
# 9m 0s
# Epoch: 29, Loss: 0.060895
# 0.7609195402298851
# 0.8206896551724139
# Model:  115
# 9m 3s
# Epoch: 9, Loss: 0.600571
# 9m 6s
# Epoch: 19, Loss: 0.444327
# 9m 8s
# Epoch: 29, Loss: 0.408954
# 0.7885057471264368
# 0.8482758620689655
# Model:  116
# 9m 11s
# Epoch: 9, Loss: 1.042201
# 9m 14s
# Epoch: 19, Loss: 0.579721
# 9m 16s
# Epoch: 29, Loss: 0.699801
# 0.7471264367816092
# 0.8344827586206897
# Model:  117
# 9m 19s
# Epoch: 9, Loss: 0.565450
# 9m 22s
# Epoch: 19, Loss: 0.435122
# 9m 24s
# Epoch: 29, Loss: 0.200326
# 0.7747126436781608
# 0.8298850574712644
# Model:  118
# 9m 27s
# Epoch: 9, Loss: 0.652485
# 9m 30s
# Epoch: 19, Loss: 0.417598
# 9m 33s
# Epoch: 29, Loss: 0.152964
# 0.7839080459770115
# 0.8574712643678161
# Model:  119
# 9m 36s
# Epoch: 9, Loss: 0.646687
# 9m 38s
# Epoch: 19, Loss: 0.270121
# 9m 41s
# Epoch: 29, Loss: 0.689362
# 0.7701149425287357
# 0.8574712643678161
# Model:  120
# 9m 44s
# Epoch: 9, Loss: 0.468347
# 9m 47s
# Epoch: 19, Loss: 0.695925
# 9m 50s
# Epoch: 29, Loss: 0.584969
# 0.7931034482758622
# 0.8850574712643677
# Model:  121
# 9m 53s
# Epoch: 9, Loss: 0.691619
# 9m 55s
# Epoch: 19, Loss: 0.157527
# 9m 58s
# Epoch: 29, Loss: 0.737209
# 0.8068965517241379
# 0.871264367816092
# Model:  122
# 10m 1s
# Epoch: 9, Loss: 0.302541
# 10m 4s
# Epoch: 19, Loss: 0.458881
# 10m 7s
# Epoch: 29, Loss: 0.265697
# 0.7885057471264368
# 0.8804597701149426
# Model:  123
# 10m 10s
# Epoch: 9, Loss: 0.421077
# 10m 13s
# Epoch: 19, Loss: 0.261995
# 10m 16s
# Epoch: 29, Loss: 0.245438
# 0.7977011494252874
# 0.871264367816092
# Model:  124
# 10m 19s
# Epoch: 9, Loss: 0.667962
# 10m 22s
# Epoch: 19, Loss: 0.743134
# 10m 24s
# Epoch: 29, Loss: 0.557735
# 0.8022988505747127
# 0.8482758620689655
# Model:  125
# 10m 27s
# Epoch: 9, Loss: 0.766585
# 10m 30s
# Epoch: 19, Loss: 0.263958
# 10m 33s
# Epoch: 29, Loss: 0.211583
# 0.7747126436781608
# 0.8344827586206897
# Model:  126
# 10m 36s
# Epoch: 9, Loss: 0.664812
# 10m 39s
# Epoch: 19, Loss: 0.267907
# 10m 42s
# Epoch: 29, Loss: 0.399418
# 0.7977011494252874
# 0.8620689655172414
# Model:  127
# 10m 45s
# Epoch: 9, Loss: 0.421831
# 10m 49s
# Epoch: 19, Loss: 0.215391
# 10m 52s
# Epoch: 29, Loss: 1.106306
# 0.7931034482758622
# 0.8298850574712644
# Model:  128
# 10m 55s
# Epoch: 9, Loss: 0.944906
# 10m 58s
# Epoch: 19, Loss: 0.187519
# 11m 1s
# Epoch: 29, Loss: 0.365626
# 0.7885057471264368
# 0.8758620689655172
# Model:  129
# 11m 4s
# Epoch: 9, Loss: 0.480227
# 11m 7s
# Epoch: 19, Loss: 0.722843
# 11m 10s
# Epoch: 29, Loss: 0.755758
# 0.8160919540229885
# 0.8574712643678161
# Model:  130
# 11m 13s
# Epoch: 9, Loss: 0.605915
# 11m 16s
# Epoch: 19, Loss: 0.418433
# 11m 19s
# Epoch: 29, Loss: 0.161877
# 0.8436781609195403
# 0.8758620689655172
# Model:  131
# 11m 22s
# Epoch: 9, Loss: 0.656872
# 11m 25s
# Epoch: 19, Loss: 0.407005
# 11m 28s
# Epoch: 29, Loss: 0.171918
# 0.8022988505747127
# 0.8390804597701149
# Model:  132
# 11m 31s
# Epoch: 9, Loss: 0.801441
# 11m 34s
# Epoch: 19, Loss: 0.407691
# 11m 37s
# Epoch: 29, Loss: 0.314853
# 0.8068965517241379
# 0.8390804597701149
# Model:  133
# 11m 40s
# Epoch: 9, Loss: 0.558847
# 11m 43s
# Epoch: 19, Loss: 0.301095
# 11m 46s
# Epoch: 29, Loss: 0.389798
# 0.8160919540229885
# 0.8390804597701149
# Model:  134
# 11m 49s
# Epoch: 9, Loss: 0.688405
# 11m 52s
# Epoch: 19, Loss: 0.476565
# 11m 55s
# Epoch: 29, Loss: 0.416768
# 0.8022988505747127
# 0.8574712643678161
# Model:  135
# 11m 58s
# Epoch: 9, Loss: 0.519385
# 12m 2s
# Epoch: 19, Loss: 0.790430
# 12m 5s
# Epoch: 29, Loss: 0.632474
# 0.7931034482758622
# 0.8666666666666667
# Model:  136
# 12m 8s
# Epoch: 9, Loss: 0.491987
# 12m 11s
# Epoch: 19, Loss: 0.520116
# 12m 13s
# Epoch: 29, Loss: 0.488290
# 0.7931034482758622
# 0.8620689655172414
# Model:  137
# 12m 17s
# Epoch: 9, Loss: 0.657574
# 12m 20s
# Epoch: 19, Loss: 0.341517
# 12m 22s
# Epoch: 29, Loss: 0.666471
# 0.8022988505747127
# 0.8666666666666667
# Model:  138
# 12m 26s
# Epoch: 9, Loss: 0.610207
# 12m 29s
# Epoch: 19, Loss: 0.181870
# 12m 32s
# Epoch: 29, Loss: 0.630045
# 0.8574712643678161
# 0.9126436781609196
# Model:  139
# 12m 35s
# Epoch: 9, Loss: 0.779984
# 12m 38s
# Epoch: 19, Loss: 0.774469
# 12m 41s
# Epoch: 29, Loss: 0.333139
# 0.8160919540229885
# 0.8758620689655172
# Model:  140
# 12m 44s
# Epoch: 9, Loss: 0.788831
# 12m 47s
# Epoch: 19, Loss: 0.457905
# 12m 50s
# Epoch: 29, Loss: 0.264971
# 0.825287356321839
# 0.8528735632183909
# Model:  141
# 12m 53s
# Epoch: 9, Loss: 0.571406
# 12m 56s
# Epoch: 19, Loss: 0.887083
# 12m 59s
# Epoch: 29, Loss: 0.177310
# 0.871264367816092
# 0.9080459770114943
# Model:  142
# 13m 3s
# Epoch: 9, Loss: 0.370298
# 13m 6s
# Epoch: 19, Loss: 1.224524
# 13m 9s
# Epoch: 29, Loss: 2.252378
# 0.8666666666666667
# 0.9356321839080461
# Model:  143
# 13m 12s
# Epoch: 9, Loss: 0.972950
# 13m 15s
# Epoch: 19, Loss: 0.649260
# 13m 18s
# Epoch: 29, Loss: 0.076651
# 0.7747126436781608
# 0.8528735632183909
# Model:  144
# 13m 21s
# Epoch: 9, Loss: 0.265105
# 13m 25s
# Epoch: 19, Loss: 0.231506
# 13m 28s
# Epoch: 29, Loss: 0.514482
# 0.825287356321839
# 0.903448275862069
# Model:  145
# 13m 31s
# Epoch: 9, Loss: 0.697103
# 13m 35s
# Epoch: 19, Loss: 0.434171
# 13m 38s
# Epoch: 29, Loss: 0.834096
# 0.8666666666666667
# 0.9172413793103448
# Model:  146
# 13m 41s
# Epoch: 9, Loss: 0.432040
# 13m 44s
# Epoch: 19, Loss: 1.082750
# 13m 48s
# Epoch: 29, Loss: 0.781306
# 0.825287356321839
# 0.8896551724137931
# Model:  147
# 13m 51s
# Epoch: 9, Loss: 0.718877
# 13m 54s
# Epoch: 19, Loss: 0.111041
# 13m 57s
# Epoch: 29, Loss: 0.694095
# 0.8206896551724139
# 0.871264367816092
# Model:  148
# 14m 1s
# Epoch: 9, Loss: 0.454712
# 14m 4s
# Epoch: 19, Loss: 0.662427
# 14m 7s
# Epoch: 29, Loss: 0.895587
# 0.8528735632183909
# 0.9264367816091954
# Model:  149
# 14m 10s
# Epoch: 9, Loss: 1.036728
# 14m 13s
# Epoch: 19, Loss: 1.072744
# 14m 17s
# Epoch: 29, Loss: 0.477606
# 0.8666666666666667
# 0.9310344827586208
# Model:  150
# 14m 20s
# Epoch: 9, Loss: 0.864124
# 14m 23s
# Epoch: 19, Loss: 0.377923
# 14m 27s
# Epoch: 29, Loss: 1.018176
# 0.8620689655172414
# 0.9218390804597701
# Model:  151
# 14m 30s
# Epoch: 9, Loss: 0.952998
# 14m 33s
# Epoch: 19, Loss: 0.178831
# 14m 37s
# Epoch: 29, Loss: 0.826620
# 0.8344827586206897
# 0.9126436781609196
# Model:  152
# 14m 40s
# Epoch: 9, Loss: 1.053258
# 14m 44s
# Epoch: 19, Loss: 1.907987
# 14m 47s
# Epoch: 29, Loss: 0.331266
# 0.8666666666666667
# 0.9126436781609196
# Model:  153
# 14m 51s
# Epoch: 9, Loss: 0.577302
# 14m 54s
# Epoch: 19, Loss: 0.355003
# 14m 57s
# Epoch: 29, Loss: 0.445320
# 0.8528735632183909
# 0.903448275862069
# Model:  154
# 15m 1s
# Epoch: 9, Loss: 0.364674
# 15m 4s
# Epoch: 19, Loss: 0.206816
# 15m 7s
# Epoch: 29, Loss: 0.433556
# 0.8482758620689655
# 0.9080459770114943
# Model:  155
# 15m 11s
# Epoch: 9, Loss: 0.797395
# 15m 14s
# Epoch: 19, Loss: 0.444753
# 15m 18s
# Epoch: 29, Loss: 0.352458
# 0.7977011494252874
# 0.9126436781609196
# Model:  156
# 15m 21s
# Epoch: 9, Loss: 0.722850
# 15m 24s
# Epoch: 19, Loss: 0.456676
# 15m 28s
# Epoch: 29, Loss: 0.383561
# 0.8574712643678161
# 0.9310344827586208
# Model:  157
# 15m 32s
# Epoch: 9, Loss: 0.596177
# 15m 35s
# Epoch: 19, Loss: 1.034180
# 15m 38s
# Epoch: 29, Loss: 0.770990
# 0.8436781609195403
# 0.9402298850574713
# Model:  158
# 15m 42s
# Epoch: 9, Loss: 0.423515
# 15m 45s
# Epoch: 19, Loss: 1.302291
# 15m 49s
# Epoch: 29, Loss: 0.106418
# 0.8482758620689655
# 0.9356321839080461
# Model:  159
# 15m 53s
# Epoch: 9, Loss: 1.428879
# 15m 56s
# Epoch: 19, Loss: 0.257207
# 16m 0s
# Epoch: 29, Loss: 0.383533
# 0.8436781609195403
# 0.9448275862068967
# Model:  160
# 16m 3s
# Epoch: 9, Loss: 0.518974
# 16m 7s
# Epoch: 19, Loss: 0.937874
# 16m 10s
# Epoch: 29, Loss: 0.719489
# 0.8528735632183909
# 0.9586206896551724
# Model:  161
# 16m 14s
# Epoch: 9, Loss: 0.510184
# 16m 17s
# Epoch: 19, Loss: 0.268235
# 16m 20s
# Epoch: 29, Loss: 0.869054
# 0.8528735632183909
# 0.9816091954022989
# Model:  162
# 16m 24s
# Epoch: 9, Loss: 0.289648
# 16m 28s
# Epoch: 19, Loss: 0.158281
# 16m 31s
# Epoch: 29, Loss: 0.111719
# 0.871264367816092
# 0.9770114942528735
# 16m 31s
# Run 28
# 163 163
# Model:  0
# 0m 11s
# Epoch: 9, Loss: 0.642063
# 0m 12s
# Epoch: 19, Loss: 0.700445
# 0m 13s
# Epoch: 29, Loss: 0.372532
# 0.44367816091954027
# 0.4988505747126437
# Model:  1
# 0m 14s
# Epoch: 9, Loss: 0.663876
# 0m 15s
# Epoch: 19, Loss: 0.777496
# 0m 16s
# Epoch: 29, Loss: 0.492995
# 0.4666666666666667
# 0.535632183908046
# Model:  2
# 0m 17s
# Epoch: 9, Loss: 0.612709
# 0m 18s
# Epoch: 19, Loss: 0.647042
# 0m 19s
# Epoch: 29, Loss: 1.093323
# 0.44367816091954027
# 0.4850574712643679
# Model:  3
# 0m 20s
# Epoch: 9, Loss: 0.568715
# 0m 21s
# Epoch: 19, Loss: 0.546496
# 0m 22s
# Epoch: 29, Loss: 0.507038
# 0.4850574712643679
# 0.5586206896551724
# Model:  4
# 0m 23s
# Epoch: 9, Loss: 0.632953
# 0m 24s
# Epoch: 19, Loss: 0.658796
# 0m 25s
# Epoch: 29, Loss: 0.331129
# 0.46206896551724136
# 0.44367816091954027
# Model:  5
# 0m 26s
# Epoch: 9, Loss: 0.740832
# 0m 27s
# Epoch: 19, Loss: 0.652996
# 0m 28s
# Epoch: 29, Loss: 0.918789
# 0.47126436781609193
# 0.5724137931034483
# Model:  6
# 0m 30s
# Epoch: 9, Loss: 0.753704
# 0m 30s
# Epoch: 19, Loss: 0.919393
# 0m 31s
# Epoch: 29, Loss: 0.677837
# 0.535632183908046
# 0.5678160919540229
# Model:  7
# 0m 33s
# Epoch: 9, Loss: 0.579766
# 0m 34s
# Epoch: 19, Loss: 0.641919
# 0m 34s
# Epoch: 29, Loss: 0.284575
# 0.47126436781609193
# 0.4988505747126437
# Model:  8
# 0m 36s
# Epoch: 9, Loss: 0.690486
# 0m 37s
# Epoch: 19, Loss: 0.782195
# 0m 37s
# Epoch: 29, Loss: 0.435269
# 0.45287356321839084
# 0.5310344827586208
# Model:  9
# 0m 39s
# Epoch: 9, Loss: 0.624483
# 0m 40s
# Epoch: 19, Loss: 0.561338
# 0m 41s
# Epoch: 29, Loss: 0.735075
# 0.5080459770114942
# 0.6045977011494253
# Model:  10
# 0m 42s
# Epoch: 9, Loss: 0.640244
# 0m 43s
# Epoch: 19, Loss: 0.823759
# 0m 44s
# Epoch: 29, Loss: 0.328584
# 0.39310344827586213
# 0.5724137931034483
# Model:  11
# 0m 45s
# Epoch: 9, Loss: 0.557967
# 0m 46s
# Epoch: 19, Loss: 0.727722
# 0m 47s
# Epoch: 29, Loss: 0.313863
# 0.5816091954022989
# 0.5494252873563219
# Model:  12
# 0m 48s
# Epoch: 9, Loss: 0.696118
# 0m 49s
# Epoch: 19, Loss: 0.402840
# 0m 50s
# Epoch: 29, Loss: 1.040325
# 0.5770114942528736
# 0.6367816091954024
# Model:  13
# 0m 51s
# Epoch: 9, Loss: 0.686383
# 0m 52s
# Epoch: 19, Loss: 0.963431
# 0m 53s
# Epoch: 29, Loss: 0.583208
# 0.5494252873563219
# 0.5540229885057472
# Model:  14
# 0m 54s
# Epoch: 9, Loss: 0.766728
# 0m 55s
# Epoch: 19, Loss: 0.501155
# 0m 56s
# Epoch: 29, Loss: 0.376589
# 0.5678160919540229
# 0.6045977011494253
# Model:  15
# 0m 57s
# Epoch: 9, Loss: 0.734205
# 0m 58s
# Epoch: 19, Loss: 0.350558
# 0m 59s
# Epoch: 29, Loss: 0.431115
# 0.6367816091954024
# 0.6827586206896552
# Model:  16
# 1m 0s
# Epoch: 9, Loss: 0.766138
# 1m 1s
# Epoch: 19, Loss: 0.761883
# 1m 2s
# Epoch: 29, Loss: 0.541461
# 0.5540229885057472
# 0.6367816091954024
# Model:  17
# 1m 3s
# Epoch: 9, Loss: 0.832566
# 1m 4s
# Epoch: 19, Loss: 0.700993
# 1m 5s
# Epoch: 29, Loss: 0.891589
# 0.2781609195402299
# 0.5678160919540229
# Model:  18
# 1m 7s
# Epoch: 9, Loss: 0.540632
# 1m 8s
# Epoch: 19, Loss: 0.754830
# 1m 9s
# Epoch: 29, Loss: 0.648872
# 0.5540229885057472
# 0.664367816091954
# Model:  19
# 1m 10s
# Epoch: 9, Loss: 0.633274
# 1m 11s
# Epoch: 19, Loss: 0.596750
# 1m 12s
# Epoch: 29, Loss: 0.692567
# 0.6275862068965518
# 0.7149425287356321
# Model:  20
# 1m 13s
# Epoch: 9, Loss: 0.555462
# 1m 14s
# Epoch: 19, Loss: 0.670860
# 1m 15s
# Epoch: 29, Loss: 0.771590
# 0.4482758620689655
# 0.6873563218390805
# Model:  21
# 1m 16s
# Epoch: 9, Loss: 0.548108
# 1m 17s
# Epoch: 19, Loss: 0.497215
# 1m 18s
# Epoch: 29, Loss: 0.651259
# 0.5678160919540229
# 0.6367816091954024
# Model:  22
# 1m 20s
# Epoch: 9, Loss: 0.614629
# 1m 20s
# Epoch: 19, Loss: 0.723795
# 1m 21s
# Epoch: 29, Loss: 0.351376
# 0.6919540229885057
# 0.7057471264367816
# Model:  23
# 1m 23s
# Epoch: 9, Loss: 0.830152
# 1m 24s
# Epoch: 19, Loss: 0.959204
# 1m 25s
# Epoch: 29, Loss: 0.572717
# 0.47126436781609193
# 0.6413793103448276
# Model:  24
# 1m 26s
# Epoch: 9, Loss: 0.664534
# 1m 27s
# Epoch: 19, Loss: 0.343735
# 1m 28s
# Epoch: 29, Loss: 0.192410
# 0.5816091954022989
# 0.664367816091954
# Model:  25
# 1m 29s
# Epoch: 9, Loss: 0.535405
# 1m 30s
# Epoch: 19, Loss: 0.413146
# 1m 31s
# Epoch: 29, Loss: 0.881993
# 0.6229885057471265
# 0.632183908045977
# Model:  26
# 1m 32s
# Epoch: 9, Loss: 0.770219
# 1m 33s
# Epoch: 19, Loss: 0.466303
# 1m 34s
# Epoch: 29, Loss: 0.471819
# 0.37471264367816093
# 0.5632183908045977
# Model:  27
# 1m 35s
# Epoch: 9, Loss: 0.502005
# 1m 36s
# Epoch: 19, Loss: 0.443007
# 1m 37s
# Epoch: 29, Loss: 0.512408
# 0.4942528735632184
# 0.6275862068965518
# Model:  28
# 1m 38s
# Epoch: 9, Loss: 0.529473
# 1m 39s
# Epoch: 19, Loss: 1.024047
# 1m 40s
# Epoch: 29, Loss: 1.248521
# 0.3471264367816092
# 0.6091954022988506
# Model:  29
# 1m 41s
# Epoch: 9, Loss: 0.910602
# 1m 42s
# Epoch: 19, Loss: 0.514087
# 1m 43s
# Epoch: 29, Loss: 0.928548
# 0.4574712643678161
# 0.5494252873563219
# Model:  30
# 1m 44s
# Epoch: 9, Loss: 0.834785
# 1m 45s
# Epoch: 19, Loss: 0.572529
# 1m 46s
# Epoch: 29, Loss: 0.685105
# 0.5632183908045977
# 0.6183908045977011
# Model:  31
# 1m 48s
# Epoch: 9, Loss: 0.879467
# 1m 49s
# Epoch: 19, Loss: 0.932953
# 1m 49s
# Epoch: 29, Loss: 0.394871
# 0.4482758620689655
# 0.4942528735632184
# Model:  32
# 1m 51s
# Epoch: 9, Loss: 0.494953
# 1m 52s
# Epoch: 19, Loss: 0.529601
# 1m 53s
# Epoch: 29, Loss: 0.282511
# 0.4988505747126437
# 0.5586206896551724
# Model:  33
# 1m 54s
# Epoch: 9, Loss: 0.477206
# 1m 55s
# Epoch: 19, Loss: 0.333252
# 1m 56s
# Epoch: 29, Loss: 1.445374
# 0.5218390804597701
# 0.5816091954022989
# Model:  34
# 1m 57s
# Epoch: 9, Loss: 0.650201
# 1m 58s
# Epoch: 19, Loss: 1.220198
# 1m 59s
# Epoch: 29, Loss: 0.330418
# 0.4942528735632184
# 0.5448275862068965
# Model:  35
# 2m 0s
# Epoch: 9, Loss: 0.493046
# 2m 1s
# Epoch: 19, Loss: 0.554045
# 2m 2s
# Epoch: 29, Loss: 0.480396
# 0.33333333333333337
# 0.5586206896551724
# Model:  36
# 2m 3s
# Epoch: 9, Loss: 0.901626
# 2m 4s
# Epoch: 19, Loss: 0.481312
# 2m 5s
# Epoch: 29, Loss: 0.678278
# 0.3563218390804598
# 0.5908045977011495
# Model:  37
# 2m 6s
# Epoch: 9, Loss: 0.513476
# 2m 7s
# Epoch: 19, Loss: 1.001044
# 2m 8s
# Epoch: 29, Loss: 0.400599
# 0.439080459770115
# 0.5908045977011495
# Model:  38
# 2m 9s
# Epoch: 9, Loss: 0.679987
# 2m 10s
# Epoch: 19, Loss: 0.736391
# 2m 11s
# Epoch: 29, Loss: 0.746343
# 0.3977011494252874
# 0.5540229885057472
# Model:  39
# 2m 12s
# Epoch: 9, Loss: 0.485883
# 2m 13s
# Epoch: 19, Loss: 0.927557
# 2m 14s
# Epoch: 29, Loss: 0.502167
# 0.45287356321839084
# 0.5310344827586208
# Model:  40
# 2m 16s
# Epoch: 9, Loss: 0.495075
# 2m 17s
# Epoch: 19, Loss: 0.485729
# 2m 18s
# Epoch: 29, Loss: 0.683801
# 0.5540229885057472
# 0.6367816091954024
# Model:  41
# 2m 19s
# Epoch: 9, Loss: 0.941936
# 2m 20s
# Epoch: 19, Loss: 0.960042
# 2m 21s
# Epoch: 29, Loss: 0.300421
# 0.5310344827586208
# 0.5494252873563219
# Model:  42
# 2m 22s
# Epoch: 9, Loss: 0.973531
# 2m 23s
# Epoch: 19, Loss: 1.006078
# 2m 24s
# Epoch: 29, Loss: 0.636341
# 0.44367816091954027
# 0.535632183908046
# Model:  43
# 2m 26s
# Epoch: 9, Loss: 0.814317
# 2m 27s
# Epoch: 19, Loss: 0.797503
# 2m 28s
# Epoch: 29, Loss: 0.559867
# 0.5448275862068965
# 0.5770114942528736
# Model:  44
# 2m 29s
# Epoch: 9, Loss: 0.708225
# 2m 30s
# Epoch: 19, Loss: 0.523472
# 2m 31s
# Epoch: 29, Loss: 0.370137
# 0.4482758620689655
# 0.4942528735632184
# Model:  45
# 2m 33s
# Epoch: 9, Loss: 0.483371
# 2m 34s
# Epoch: 19, Loss: 0.446416
# 2m 35s
# Epoch: 29, Loss: 0.444983
# 0.4850574712643679
# 0.5126436781609195
# Model:  46
# 2m 36s
# Epoch: 9, Loss: 0.460259
# 2m 37s
# Epoch: 19, Loss: 1.019250
# 2m 38s
# Epoch: 29, Loss: 0.714041
# 0.4114942528735632
# 0.5310344827586208
# Model:  47
# 2m 40s
# Epoch: 9, Loss: 0.875645
# 2m 41s
# Epoch: 19, Loss: 0.980701
# 2m 42s
# Epoch: 29, Loss: 0.480008
# 0.5310344827586208
# 0.5724137931034483
# Model:  48
# 2m 43s
# Epoch: 9, Loss: 0.491106
# 2m 45s
# Epoch: 19, Loss: 0.704822
# 2m 46s
# Epoch: 29, Loss: 0.337240
# 0.5862068965517242
# 0.5816091954022989
# Model:  49
# 2m 47s
# Epoch: 9, Loss: 0.927462
# 2m 48s
# Epoch: 19, Loss: 0.509386
# 2m 49s
# Epoch: 29, Loss: 0.665750
# 0.4574712643678161
# 0.5264367816091954
# Model:  50
# 2m 51s
# Epoch: 9, Loss: 0.917988
# 2m 52s
# Epoch: 19, Loss: 0.442664
# 2m 53s
# Epoch: 29, Loss: 0.505727
# 0.5080459770114942
# 0.5310344827586208
# Model:  51
# 2m 55s
# Epoch: 9, Loss: 0.673741
# 2m 56s
# Epoch: 19, Loss: 0.363974
# 2m 57s
# Epoch: 29, Loss: 0.523670
# 0.5126436781609195
# 0.4758620689655172
# Model:  52
# 2m 58s
# Epoch: 9, Loss: 0.502782
# 3m 0s
# Epoch: 19, Loss: 0.833644
# 3m 1s
# Epoch: 29, Loss: 0.564007
# 0.5264367816091954
# 0.5310344827586208
# Model:  53
# 3m 2s
# Epoch: 9, Loss: 0.448746
# 3m 4s
# Epoch: 19, Loss: 0.402951
# 3m 5s
# Epoch: 29, Loss: 1.250030
# 0.535632183908046
# 0.5862068965517242
# Model:  54
# 3m 6s
# Epoch: 9, Loss: 0.446601
# 3m 8s
# Epoch: 19, Loss: 0.611681
# 3m 9s
# Epoch: 29, Loss: 0.614287
# 0.5770114942528736
# 0.5724137931034483
# Model:  55
# 3m 11s
# Epoch: 9, Loss: 0.492504
# 3m 12s
# Epoch: 19, Loss: 0.346945
# 3m 13s
# Epoch: 29, Loss: 1.232666
# 0.5264367816091954
# 0.6
# Model:  56
# 3m 15s
# Epoch: 9, Loss: 0.907014
# 3m 16s
# Epoch: 19, Loss: 0.481400
# 3m 17s
# Epoch: 29, Loss: 0.491942
# 0.5816091954022989
# 0.6091954022988506
# Model:  57
# 3m 19s
# Epoch: 9, Loss: 0.943807
# 3m 20s
# Epoch: 19, Loss: 0.390081
# 3m 22s
# Epoch: 29, Loss: 0.439518
# 0.6183908045977011
# 0.6183908045977011
# Model:  58
# 3m 23s
# Epoch: 9, Loss: 1.026058
# 3m 24s
# Epoch: 19, Loss: 0.444110
# 3m 26s
# Epoch: 29, Loss: 0.700953
# 0.5770114942528736
# 0.6137931034482759
# Model:  59
# 3m 28s
# Epoch: 9, Loss: 0.474783
# 3m 29s
# Epoch: 19, Loss: 0.302240
# 3m 30s
# Epoch: 29, Loss: 0.497604
# 0.6551724137931034
# 0.664367816091954
# Model:  60
# 3m 32s
# Epoch: 9, Loss: 0.917058
# 3m 33s
# Epoch: 19, Loss: 0.604215
# 3m 35s
# Epoch: 29, Loss: 0.585140
# 0.6413793103448276
# 0.6505747126436782
# Model:  61
# 3m 36s
# Epoch: 9, Loss: 1.082581
# 3m 38s
# Epoch: 19, Loss: 0.952713
# 3m 39s
# Epoch: 29, Loss: 0.367543
# 0.664367816091954
# 0.6919540229885057
# Model:  62
# 3m 41s
# Epoch: 9, Loss: 0.737018
# 3m 42s
# Epoch: 19, Loss: 0.713046
# 3m 44s
# Epoch: 29, Loss: 0.256244
# 0.632183908045977
# 0.6551724137931034
# Model:  63
# 3m 45s
# Epoch: 9, Loss: 0.474231
# 3m 47s
# Epoch: 19, Loss: 0.707810
# 3m 48s
# Epoch: 29, Loss: 0.672309
# 0.6091954022988506
# 0.6459770114942529
# Model:  64
# 3m 50s
# Epoch: 9, Loss: 0.462934
# 3m 51s
# Epoch: 19, Loss: 0.480063
# 3m 53s
# Epoch: 29, Loss: 0.155594
# 0.6413793103448276
# 0.6367816091954024
# Model:  65
# 3m 55s
# Epoch: 9, Loss: 0.921601
# 3m 56s
# Epoch: 19, Loss: 0.443184
# 3m 58s
# Epoch: 29, Loss: 0.740660
# 0.5770114942528736
# 0.6413793103448276
# Model:  66
# 3m 59s
# Epoch: 9, Loss: 0.946797
# 4m 1s
# Epoch: 19, Loss: 0.382983
# 4m 2s
# Epoch: 29, Loss: 0.549558
# 0.6229885057471265
# 0.6597701149425287
# Model:  67
# 4m 4s
# Epoch: 9, Loss: 0.497905
# 4m 6s
# Epoch: 19, Loss: 0.839560
# 4m 8s
# Epoch: 29, Loss: 0.522679
# 0.6597701149425287
# 0.6597701149425287
# Model:  68
# 4m 9s
# Epoch: 9, Loss: 0.625738
# 4m 11s
# Epoch: 19, Loss: 0.717735
# 4m 13s
# Epoch: 29, Loss: 0.511025
# 0.6229885057471265
# 0.7057471264367816
# Model:  69
# 4m 15s
# Epoch: 9, Loss: 0.903487
# 4m 16s
# Epoch: 19, Loss: 0.384175
# 4m 18s
# Epoch: 29, Loss: 0.190893
# 0.6091954022988506
# 0.6689655172413793
# Model:  70
# 4m 20s
# Epoch: 9, Loss: 0.539882
# 4m 21s
# Epoch: 19, Loss: 0.435579
# 4m 23s
# Epoch: 29, Loss: 0.374590
# 0.6689655172413793
# 0.6965517241379311
# Model:  71
# 4m 25s
# Epoch: 9, Loss: 0.911254
# 4m 27s
# Epoch: 19, Loss: 0.640727
# 4m 28s
# Epoch: 29, Loss: 0.577313
# 0.6413793103448276
# 0.6551724137931034
# Model:  72
# 4m 30s
# Epoch: 9, Loss: 0.487277
# 4m 32s
# Epoch: 19, Loss: 0.741076
# 4m 34s
# Epoch: 29, Loss: 0.799774
# 0.6919540229885057
# 0.7333333333333334
# Model:  73
# 4m 36s
# Epoch: 9, Loss: 0.786195
# 4m 37s
# Epoch: 19, Loss: 1.168438
# 4m 39s
# Epoch: 29, Loss: 0.682255
# 0.6551724137931034
# 0.6551724137931034
# Model:  74
# 4m 41s
# Epoch: 9, Loss: 0.955134
# 4m 43s
# Epoch: 19, Loss: 0.363676
# 4m 45s
# Epoch: 29, Loss: 0.618000
# 0.6551724137931034
# 0.7517241379310345
# Model:  75
# 4m 47s
# Epoch: 9, Loss: 0.735954
# 4m 48s
# Epoch: 19, Loss: 0.368579
# 4m 50s
# Epoch: 29, Loss: 0.129547
# 0.6551724137931034
# 0.7287356321839081
# Model:  76
# 4m 52s
# Epoch: 9, Loss: 0.700825
# 4m 54s
# Epoch: 19, Loss: 0.681940
# 4m 56s
# Epoch: 29, Loss: 0.741515
# 0.67816091954023
# 0.7379310344827587
# Model:  77
# 4m 58s
# Epoch: 9, Loss: 0.493251
# 4m 59s
# Epoch: 19, Loss: 0.700138
# 5m 1s
# Epoch: 29, Loss: 0.506146
# 0.67816091954023
# 0.6873563218390805
# Model:  78
# 5m 3s
# Epoch: 9, Loss: 0.448114
# 5m 5s
# Epoch: 19, Loss: 0.708537
# 5m 7s
# Epoch: 29, Loss: 0.475301
# 0.6367816091954024
# 0.7287356321839081
# Model:  79
# 5m 9s
# Epoch: 9, Loss: 1.001250
# 5m 11s
# Epoch: 19, Loss: 0.419386
# 5m 13s
# Epoch: 29, Loss: 0.178595
# 0.67816091954023
# 0.6873563218390805
# Model:  80
# 5m 15s
# Epoch: 9, Loss: 0.482870
# 5m 17s
# Epoch: 19, Loss: 0.348071
# 5m 19s
# Epoch: 29, Loss: 1.162811
# 0.6827586206896552
# 0.6919540229885057
# Model:  81
# 5m 21s
# Epoch: 9, Loss: 0.645024
# 5m 23s
# Epoch: 19, Loss: 0.523310
# 5m 24s
# Epoch: 29, Loss: 1.486091
# 0.6689655172413793
# 0.632183908045977
# Model:  82
# 5m 27s
# Epoch: 9, Loss: 0.712548
# 5m 29s
# Epoch: 19, Loss: 0.592916
# 5m 30s
# Epoch: 29, Loss: 0.131130
# 0.7103448275862069
# 0.6965517241379311
# Model:  83
# 5m 33s
# Epoch: 9, Loss: 0.891823
# 5m 34s
# Epoch: 19, Loss: 0.667432
# 5m 36s
# Epoch: 29, Loss: 0.191168
# 0.67816091954023
# 0.7103448275862069
# Model:  84
# 5m 38s
# Epoch: 9, Loss: 1.017597
# 5m 40s
# Epoch: 19, Loss: 0.397782
# 5m 42s
# Epoch: 29, Loss: 0.513318
# 0.6965517241379311
# 0.6873563218390805
# Model:  85
# 5m 44s
# Epoch: 9, Loss: 0.869067
# 5m 46s
# Epoch: 19, Loss: 0.176603
# 5m 48s
# Epoch: 29, Loss: 0.939100
# 0.7057471264367816
# 0.7149425287356321
# Model:  86
# 5m 50s
# Epoch: 9, Loss: 0.930832
# 5m 52s
# Epoch: 19, Loss: 0.569270
# 5m 54s
# Epoch: 29, Loss: 0.847968
# 0.7379310344827587
# 0.7563218390804598
# Model:  87
# 5m 57s
# Epoch: 9, Loss: 0.546674
# 5m 59s
# Epoch: 19, Loss: 0.395935
# 6m 1s
# Epoch: 29, Loss: 0.512496
# 0.7057471264367816
# 0.7471264367816092
# Model:  88
# 6m 3s
# Epoch: 9, Loss: 0.810665
# 6m 5s
# Epoch: 19, Loss: 0.308284
# 6m 7s
# Epoch: 29, Loss: 0.584064
# 0.6965517241379311
# 0.7517241379310345
# Model:  89
# 6m 9s
# Epoch: 9, Loss: 0.409149
# 6m 11s
# Epoch: 19, Loss: 1.300216
# 6m 13s
# Epoch: 29, Loss: 0.230812
# 0.7701149425287357
# 0.7287356321839081
# Model:  90
# 6m 16s
# Epoch: 9, Loss: 0.944346
# 6m 18s
# Epoch: 19, Loss: 0.687224
# 6m 20s
# Epoch: 29, Loss: 0.848396
# 0.7241379310344828
# 0.7931034482758622
# Model:  91
# 6m 22s
# Epoch: 9, Loss: 0.531772
# 6m 25s
# Epoch: 19, Loss: 0.746798
# 6m 27s
# Epoch: 29, Loss: 0.577148
# 0.7195402298850575
# 0.7609195402298851
# Model:  92
# 6m 29s
# Epoch: 9, Loss: 0.629843
# 6m 31s
# Epoch: 19, Loss: 0.244602
# 6m 33s
# Epoch: 29, Loss: 0.638904
# 0.7471264367816092
# 0.7471264367816092
# Model:  93
# 6m 35s
# Epoch: 9, Loss: 0.718219
# 6m 37s
# Epoch: 19, Loss: 0.647631
# 6m 39s
# Epoch: 29, Loss: 0.665528
# 0.7195402298850575
# 0.7931034482758622
# Model:  94
# 6m 42s
# Epoch: 9, Loss: 0.465994
# 6m 44s
# Epoch: 19, Loss: 0.385179
# 6m 46s
# Epoch: 29, Loss: 0.755319
# 0.7563218390804598
# 0.7655172413793103
# Model:  95
# 6m 48s
# Epoch: 9, Loss: 0.752611
# 6m 50s
# Epoch: 19, Loss: 0.275491
# 6m 52s
# Epoch: 29, Loss: 1.042053
# 0.7241379310344828
# 0.7655172413793103
# Model:  96
# 6m 55s
# Epoch: 9, Loss: 0.467010
# 6m 57s
# Epoch: 19, Loss: 0.323756
# 6m 59s
# Epoch: 29, Loss: 0.587558
# ...
# 3m 8s
# Epoch: 9, Loss: 0.432320
# 3m 10s
# Epoch: 19, Loss: 0.816216
# 3m 11s
# Epoch: 29, Loss: 0.205610
# 0.5724137931034483
# 0.6275862068965518
# Model:  56
# 3m 12s
# Epoch: 9, Loss: 0.510745
# 3m 14s
# Epoch: 19, Loss: 0.426116
# 3m 15s
# Epoch: 29, Loss: 0.769721
# 0.6137931034482759
# 0.6459770114942529
# Model:  57
# 3m 17s
# Epoch: 9, Loss: 0.901004
# 3m 18s
# Epoch: 19, Loss: 0.558581
# 3m 19s
# Epoch: 29, Loss: 0.819750
# 0.5954022988505747
# 0.6551724137931034
# Model:  58
# 3m 21s
# Epoch: 9, Loss: 0.535665
# 3m 22s
# Epoch: 19, Loss: 0.946581
# 3m 23s
# Epoch: 29, Loss: 0.234626
# 0.5678160919540229
# 0.6367816091954024
# Model:  59
# 3m 25s
# Epoch: 9, Loss: 0.498332
# 3m 26s
# Epoch: 19, Loss: 0.381536
# 3m 28s
# Epoch: 29, Loss: 0.396166
# 0.5632183908045977
# 0.6229885057471265
# Model:  60
# 3m 29s
# Epoch: 9, Loss: 0.837316
# 3m 31s
# Epoch: 19, Loss: 0.331621
# 3m 32s
# Epoch: 29, Loss: 0.311070
# 0.632183908045977
# 0.6505747126436782
# Model:  61
# 3m 34s
# Epoch: 9, Loss: 0.977500
# 3m 35s
# Epoch: 19, Loss: 0.622132
# 3m 36s
# Epoch: 29, Loss: 0.572317
# 0.6505747126436782
# 0.6689655172413793
# Model:  62
# 3m 38s
# Epoch: 9, Loss: 0.491165
# 3m 39s
# Epoch: 19, Loss: 0.589844
# 3m 41s
# Epoch: 29, Loss: 0.352987
# 0.5448275862068965
# 0.6367816091954024
# Model:  63
# 3m 43s
# Epoch: 9, Loss: 0.703090
# 3m 44s
# Epoch: 19, Loss: 0.748398
# 3m 45s
# Epoch: 29, Loss: 0.758426
# 0.6137931034482759
# 0.6735632183908047
# Model:  64
# 3m 47s
# Epoch: 9, Loss: 0.884435
# 3m 49s
# Epoch: 19, Loss: 0.350127
# 3m 50s
# Epoch: 29, Loss: 1.558826
# 0.6459770114942529
# 0.6689655172413793
# Model:  65
# 3m 52s
# Epoch: 9, Loss: 0.554477
# 3m 53s
# Epoch: 19, Loss: 0.662536
# 3m 55s
# Epoch: 29, Loss: 0.213066
# 0.6183908045977011
# 0.6459770114942529
# Model:  66
# 3m 56s
# Epoch: 9, Loss: 0.473881
# 3m 58s
# Epoch: 19, Loss: 0.679745
# 3m 59s
# Epoch: 29, Loss: 0.615992
# 0.5954022988505747
# 0.6183908045977011
# Model:  67
# 4m 1s
# Epoch: 9, Loss: 0.667036
# 4m 2s
# Epoch: 19, Loss: 0.473978
# 4m 4s
# Epoch: 29, Loss: 0.514663
# 0.6551724137931034
# 0.6827586206896552
# Model:  68
# 4m 6s
# Epoch: 9, Loss: 0.453433
# 4m 7s
# Epoch: 19, Loss: 0.394390
# 4m 9s
# Epoch: 29, Loss: 0.514757
# 0.6229885057471265
# 0.664367816091954
# Model:  69
# 4m 11s
# Epoch: 9, Loss: 0.520837
# 4m 12s
# Epoch: 19, Loss: 0.858762
# 4m 14s
# Epoch: 29, Loss: 0.259854
# 0.6137931034482759
# 0.664367816091954
# Model:  70
# 4m 15s
# Epoch: 9, Loss: 0.492272
# 4m 17s
# Epoch: 19, Loss: 0.594524
# 4m 19s
# Epoch: 29, Loss: 0.430608
# 0.6827586206896552
# 0.6965517241379311
# Model:  71
# 4m 21s
# Epoch: 9, Loss: 0.732724
# 4m 22s
# Epoch: 19, Loss: 0.797282
# 4m 24s
# Epoch: 29, Loss: 0.677436
# 0.6597701149425287
# 0.6459770114942529
# Model:  72
# 4m 26s
# Epoch: 9, Loss: 0.509089
# 4m 27s
# Epoch: 19, Loss: 0.871438
# 4m 29s
# Epoch: 29, Loss: 0.691700
# 0.6275862068965518
# 0.7425287356321839
# Model:  73
# 4m 31s
# Epoch: 9, Loss: 0.944641
# 4m 32s
# Epoch: 19, Loss: 0.399581
# 4m 34s
# Epoch: 29, Loss: 1.284677
# 0.6229885057471265
# 0.6873563218390805
# Model:  74
# 4m 36s
# Epoch: 9, Loss: 0.891997
# 4m 38s
# Epoch: 19, Loss: 0.605954
# 4m 39s
# Epoch: 29, Loss: 0.224276
# 0.6045977011494253
# 0.7333333333333334
# Model:  75
# 4m 41s
# Epoch: 9, Loss: 0.759026
# 4m 43s
# Epoch: 19, Loss: 0.564613
# 4m 45s
# Epoch: 29, Loss: 0.533913
# 0.6551724137931034
# 0.7241379310344828
# Model:  76
# 4m 47s
# Epoch: 9, Loss: 0.542082
# 4m 48s
# Epoch: 19, Loss: 0.536524
# 4m 50s
# Epoch: 29, Loss: 0.654866
# 0.632183908045977
# 0.7103448275862069
# Model:  77
# 4m 52s
# Epoch: 9, Loss: 0.665711
# 4m 54s
# Epoch: 19, Loss: 0.283766
# 4m 56s
# Epoch: 29, Loss: 0.295378
# 0.67816091954023
# 0.7195402298850575
# Model:  78
# 4m 58s
# Epoch: 9, Loss: 0.540856
# 4m 59s
# Epoch: 19, Loss: 0.718829
# 5m 1s
# Epoch: 29, Loss: 0.316544
# 0.6413793103448276
# 0.7195402298850575
# Model:  79
# 5m 3s
# Epoch: 9, Loss: 0.484493
# 5m 5s
# Epoch: 19, Loss: 0.464759
# 5m 7s
# Epoch: 29, Loss: 0.222565
# 0.6919540229885057
# 0.6597701149425287
# Model:  80
# 5m 9s
# Epoch: 9, Loss: 0.554036
# 5m 10s
# Epoch: 19, Loss: 0.433994
# 5m 12s
# Epoch: 29, Loss: 0.410840
# 0.6505747126436782
# 0.6827586206896552
# Model:  81
# 5m 14s
# Epoch: 9, Loss: 0.470893
# 5m 16s
# Epoch: 19, Loss: 1.245095
# 5m 18s
# Epoch: 29, Loss: 0.969957
# 0.6551724137931034
# 0.6965517241379311
# Model:  82
# 5m 20s
# Epoch: 9, Loss: 0.685206
# 5m 22s
# Epoch: 19, Loss: 0.774547
# 5m 23s
# Epoch: 29, Loss: 0.297130
# 0.6689655172413793
# 0.6689655172413793
# Model:  83
# 5m 26s
# Epoch: 9, Loss: 0.974216
# 5m 27s
# Epoch: 19, Loss: 0.471134
# 5m 29s
# Epoch: 29, Loss: 0.369684
# 0.6367816091954024
# 0.6735632183908047
# Model:  84
# 5m 31s
# Epoch: 9, Loss: 0.468090
# 5m 33s
# Epoch: 19, Loss: 0.639235
# 5m 35s
# Epoch: 29, Loss: 0.348500
# 0.67816091954023
# 0.6827586206896552
# Model:  85
# 5m 37s
# Epoch: 9, Loss: 1.022316
# 5m 39s
# Epoch: 19, Loss: 0.485443
# 5m 42s
# Epoch: 29, Loss: 0.107814
# 0.7057471264367816
# 0.7241379310344828
# Model:  86
# 5m 44s
# Epoch: 9, Loss: 0.472128
# 5m 46s
# Epoch: 19, Loss: 0.818684
# 5m 48s
# Epoch: 29, Loss: 0.756082
# 0.7333333333333334
# 0.7563218390804598
# Model:  87
# 5m 50s
# Epoch: 9, Loss: 0.404360
# 5m 53s
# Epoch: 19, Loss: 0.423013
# 5m 55s
# Epoch: 29, Loss: 1.389500
# 0.7655172413793103
# 0.7655172413793103
# Model:  88
# 5m 57s
# Epoch: 9, Loss: 0.965843
# 5m 59s
# Epoch: 19, Loss: 0.954049
# 6m 1s
# Epoch: 29, Loss: 0.895797
# 0.7287356321839081
# 0.825287356321839
# Model:  89
# 6m 4s
# Epoch: 9, Loss: 0.477669
# 6m 6s
# Epoch: 19, Loss: 1.514046
# 6m 8s
# Epoch: 29, Loss: 0.666246
# 0.7149425287356321
# 0.7517241379310345
# Model:  90
# 6m 10s
# Epoch: 9, Loss: 0.650664
# 6m 13s
# Epoch: 19, Loss: 0.785950
# 6m 15s
# Epoch: 29, Loss: 1.078799
# 0.7057471264367816
# 0.7471264367816092
# Model:  91
# 6m 17s
# Epoch: 9, Loss: 0.677043
# 6m 19s
# Epoch: 19, Loss: 0.583961
# 6m 21s
# Epoch: 29, Loss: 0.915194
# 0.7287356321839081
# 0.7195402298850575
# Model:  92
# 6m 24s
# Epoch: 9, Loss: 0.709243
# 6m 26s
# Epoch: 19, Loss: 0.216028
# 6m 28s
# Epoch: 29, Loss: 0.163294
# 0.7333333333333334
# 0.8022988505747127
# Model:  93
# 6m 30s
# Epoch: 9, Loss: 0.534672
# 6m 33s
# Epoch: 19, Loss: 0.486667
# 6m 35s
# Epoch: 29, Loss: 0.713364
# 0.7287356321839081
# 0.7563218390804598
# Model:  94
# 6m 37s
# Epoch: 9, Loss: 0.651248
# 6m 39s
# Epoch: 19, Loss: 0.816762
# 6m 42s
# Epoch: 29, Loss: 0.854340
# 0.7103448275862069
# 0.7839080459770115
# Model:  95
# 6m 44s
# Epoch: 9, Loss: 0.674571
# 6m 46s
# Epoch: 19, Loss: 0.241271
# 6m 49s
# Epoch: 29, Loss: 0.590984
# 0.7287356321839081
# 0.7839080459770115
# Model:  96
# 6m 51s
# Epoch: 9, Loss: 0.483097
# 6m 54s
# Epoch: 19, Loss: 0.396748
# 6m 56s
# Epoch: 29, Loss: 0.622401
# 0.7241379310344828
# 0.7793103448275862
# Model:  97
# 6m 59s
# Epoch: 9, Loss: 0.505955
# 7m 1s
# Epoch: 19, Loss: 0.617706
# 7m 4s
# Epoch: 29, Loss: 0.659334
# 0.7241379310344828
# 0.7839080459770115
# Model:  98
# 7m 6s
# Epoch: 9, Loss: 0.951117
# 7m 9s
# Epoch: 19, Loss: 0.257356
# 7m 11s
# Epoch: 29, Loss: 0.215779
# 0.7195402298850575
# 0.7655172413793103
# Model:  99
# 7m 14s
# Epoch: 9, Loss: 0.920673
# 7m 16s
# Epoch: 19, Loss: 0.461030
# 7m 19s
# Epoch: 29, Loss: 0.610625
# 0.7701149425287357
# 0.7563218390804598
# Model:  100
# 7m 21s
# Epoch: 9, Loss: 0.636420
# 7m 24s
# Epoch: 19, Loss: 0.803382
# 7m 26s
# Epoch: 29, Loss: 0.693626
# 0.7701149425287357
# 0.8022988505747127
# Model:  101
# 7m 28s
# Epoch: 9, Loss: 0.562493
# 7m 31s
# Epoch: 19, Loss: 0.772143
# 7m 33s
# Epoch: 29, Loss: 0.831978
# 0.7701149425287357
# 0.8068965517241379
# Model:  102
# 7m 35s
# Epoch: 9, Loss: 0.483850
# 7m 38s
# Epoch: 19, Loss: 0.179358
# 7m 40s
# Epoch: 29, Loss: 0.210026
# 0.7839080459770115
# 0.8114942528735632
# Model:  103
# 7m 42s
# Epoch: 9, Loss: 0.797760
# 7m 45s
# Epoch: 19, Loss: 0.933439
# 7m 47s
# Epoch: 29, Loss: 0.248262
# 0.7885057471264368
# 0.8068965517241379
# Model:  104
# 7m 49s
# Epoch: 9, Loss: 0.691800
# 7m 52s
# Epoch: 19, Loss: 0.387852
# 7m 54s
# Epoch: 29, Loss: 0.684187
# 0.7471264367816092
# 0.7885057471264368
# Model:  105
# 7m 56s
# Epoch: 9, Loss: 0.461381
# 7m 59s
# Epoch: 19, Loss: 0.762013
# 8m 1s
# Epoch: 29, Loss: 0.899849
# 0.7793103448275862
# 0.8160919540229885
# Model:  106
# 8m 3s
# Epoch: 9, Loss: 0.826793
# 8m 6s
# Epoch: 19, Loss: 0.441523
# 8m 8s
# Epoch: 29, Loss: 0.628360
# 0.7701149425287357
# 0.8344827586206897
# Model:  107
# 8m 11s
# Epoch: 9, Loss: 0.483875
# 8m 13s
# Epoch: 19, Loss: 0.637287
# 8m 15s
# Epoch: 29, Loss: 0.220741
# 0.7517241379310345
# 0.7931034482758622
# Model:  108
# 8m 18s
# Epoch: 9, Loss: 0.538508
# 8m 20s
# Epoch: 19, Loss: 0.356585
# 8m 23s
# Epoch: 29, Loss: 0.597929
# 0.7839080459770115
# 0.825287356321839
# Model:  109
# 8m 25s
# Epoch: 9, Loss: 0.966764
# 8m 28s
# Epoch: 19, Loss: 1.008557
# 8m 30s
# Epoch: 29, Loss: 0.823790
# 0.7793103448275862
# 0.8206896551724139
# Model:  110
# 8m 33s
# Epoch: 9, Loss: 0.695191
# 8m 35s
# Epoch: 19, Loss: 0.218666
# 8m 37s
# Epoch: 29, Loss: 0.660453
# 0.7839080459770115
# 0.8114942528735632
# Model:  111
# 8m 40s
# Epoch: 9, Loss: 0.346000
# 8m 43s
# Epoch: 19, Loss: 0.207549
# 8m 45s
# Epoch: 29, Loss: 0.261706
# 0.7655172413793103
# 0.8022988505747127
# Model:  112
# 8m 48s
# Epoch: 9, Loss: 0.846930
# 8m 50s
# Epoch: 19, Loss: 0.365523
# 8m 53s
# Epoch: 29, Loss: 1.176029
# 0.7563218390804598
# 0.7977011494252874
# Model:  113
# 8m 55s
# Epoch: 9, Loss: 0.543402
# 8m 58s
# Epoch: 19, Loss: 0.363777
# 9m 1s
# Epoch: 29, Loss: 0.239012
# 0.7471264367816092
# 0.8206896551724139
# Model:  114
# 9m 4s
# Epoch: 9, Loss: 0.614355
# 9m 7s
# Epoch: 19, Loss: 0.510102
# 9m 9s
# Epoch: 29, Loss: 0.473636
# 0.7885057471264368
# 0.8344827586206897
# Model:  115
# 9m 12s
# Epoch: 9, Loss: 0.306024
# 9m 15s
# Epoch: 19, Loss: 0.196481
# 9m 18s
# Epoch: 29, Loss: 0.233346
# 0.7655172413793103
# 0.8436781609195403
# Model:  116
# 9m 21s
# Epoch: 9, Loss: 0.633784
# 9m 23s
# Epoch: 19, Loss: 0.891557
# 9m 26s
# Epoch: 29, Loss: 1.864448
# 0.7839080459770115
# 0.825287356321839
# Model:  117
# 9m 29s
# Epoch: 9, Loss: 0.641689
# 9m 32s
# Epoch: 19, Loss: 0.543333
# 9m 35s
# Epoch: 29, Loss: 1.331333
# 0.7747126436781608
# 0.8482758620689655
# Model:  118
# 9m 39s
# Epoch: 9, Loss: 0.613871
# 9m 41s
# Epoch: 19, Loss: 0.836011
# 9m 44s
# Epoch: 29, Loss: 0.124234
# 0.7747126436781608
# 0.8436781609195403
# Model:  119
# 9m 47s
# Epoch: 9, Loss: 0.621696
# 9m 50s
# Epoch: 19, Loss: 1.215289
# 9m 54s
# Epoch: 29, Loss: 0.687975
# 0.7793103448275862
# 0.8344827586206897
# Model:  120
# 9m 57s
# Epoch: 9, Loss: 0.990603
# 10m 1s
# Epoch: 19, Loss: 0.783345
# 10m 5s
# Epoch: 29, Loss: 0.607437
# 0.8022988505747127
# 0.8942528735632185
# Model:  121
# 10m 8s
# Epoch: 9, Loss: 0.370024
# 10m 11s
# Epoch: 19, Loss: 0.325771
# 10m 14s
# Epoch: 29, Loss: 0.376722
# 0.7793103448275862
# 0.8482758620689655
# Model:  122
# 10m 17s
# Epoch: 9, Loss: 0.589998
# 10m 20s
# Epoch: 19, Loss: 1.130308
# 10m 23s
# Epoch: 29, Loss: 0.122571
# 0.7839080459770115
# 0.8298850574712644
# Model:  123
# 10m 26s
# Epoch: 9, Loss: 0.615083
# 10m 29s
# Epoch: 19, Loss: 0.076036
# 10m 32s
# Epoch: 29, Loss: 0.766809
# 0.7885057471264368
# 0.8436781609195403
# Model:  124
# 10m 35s
# Epoch: 9, Loss: 0.763359
# 10m 38s
# Epoch: 19, Loss: 0.821813
# 10m 41s
# Epoch: 29, Loss: 0.526021
# 0.7885057471264368
# 0.871264367816092
# Model:  125
# 10m 45s
# Epoch: 9, Loss: 0.559138
# 10m 48s
# Epoch: 19, Loss: 0.597476
# 10m 51s
# Epoch: 29, Loss: 0.165141
# 0.8068965517241379
# 0.8482758620689655
# Model:  126
# 10m 54s
# Epoch: 9, Loss: 0.826709
# 10m 57s
# Epoch: 19, Loss: 1.745992
# 11m 0s
# Epoch: 29, Loss: 0.933580
# 0.7839080459770115
# 0.8528735632183909
# Model:  127
# 11m 3s
# Epoch: 9, Loss: 0.521602
# 11m 7s
# Epoch: 19, Loss: 1.216700
# 11m 10s
# Epoch: 29, Loss: 1.108982
# 0.7839080459770115
# 0.8574712643678161
# Model:  128
# 11m 13s
# Epoch: 9, Loss: 0.409080
# 11m 16s
# Epoch: 19, Loss: 0.544745
# 11m 19s
# Epoch: 29, Loss: 0.746978
# 0.8344827586206897
# 0.871264367816092
# Model:  129
# 11m 22s
# Epoch: 9, Loss: 0.214780
# 11m 25s
# Epoch: 19, Loss: 0.403195
# 11m 28s
# Epoch: 29, Loss: 0.734204
# 0.8482758620689655
# 0.8804597701149426
# Model:  130
# 11m 32s
# Epoch: 9, Loss: 0.567215
# 11m 35s
# Epoch: 19, Loss: 0.160336
# 11m 38s
# Epoch: 29, Loss: 0.599574
# 0.8160919540229885
# 0.8758620689655172
# Model:  131
# 11m 42s
# Epoch: 9, Loss: 0.620417
# 11m 45s
# Epoch: 19, Loss: 0.726791
# 11m 48s
# Epoch: 29, Loss: 0.316197
# 0.8206896551724139
# 0.871264367816092
# Model:  132
# 11m 51s
# Epoch: 9, Loss: 0.930296
# 11m 55s
# Epoch: 19, Loss: 0.325048
# 11m 58s
# Epoch: 29, Loss: 0.678476
# 0.8068965517241379
# 0.871264367816092
# Model:  133
# 12m 1s
# Epoch: 9, Loss: 0.362119
# 12m 4s
# Epoch: 19, Loss: 0.363376
# 12m 8s
# Epoch: 29, Loss: 1.000703
# 0.8206896551724139
# 0.8482758620689655
# Model:  134
# 12m 11s
# Epoch: 9, Loss: 0.522388
# 12m 14s
# Epoch: 19, Loss: 0.594983
# 12m 17s
# Epoch: 29, Loss: 0.595502
# 0.8344827586206897
# 0.8942528735632185
# Model:  135
# 12m 21s
# Epoch: 9, Loss: 0.587151
# 12m 24s
# Epoch: 19, Loss: 0.810103
# 12m 27s
# Epoch: 29, Loss: 0.712746
# 0.7931034482758622
# 0.8666666666666667
# Model:  136
# 12m 30s
# Epoch: 9, Loss: 0.453204
# 12m 34s
# Epoch: 19, Loss: 0.838860
# 12m 37s
# Epoch: 29, Loss: 0.557227
# 0.825287356321839
# 0.8804597701149426
# Model:  137
# 12m 41s
# Epoch: 9, Loss: 0.717101
# 12m 44s
# Epoch: 19, Loss: 1.168994
# 12m 47s
# Epoch: 29, Loss: 0.526691
# 0.8206896551724139
# 0.8620689655172414
# Model:  138
# 12m 51s
# Epoch: 9, Loss: 0.596011
# 12m 54s
# Epoch: 19, Loss: 0.369341
# 12m 58s
# Epoch: 29, Loss: 0.317552
# 0.8574712643678161
# 0.871264367816092
# Model:  139
# 13m 1s
# Epoch: 9, Loss: 0.599136
# 13m 5s
# Epoch: 19, Loss: 1.124996
# 13m 8s
# Epoch: 29, Loss: 0.368658
# 0.7839080459770115
# 0.8804597701149426
# Model:  140
# 13m 11s
# Epoch: 9, Loss: 0.526027
# 13m 15s
# Epoch: 19, Loss: 0.747878
# 13m 18s
# Epoch: 29, Loss: 1.358585
# 0.8114942528735632
# 0.8620689655172414
# Model:  141
# 13m 22s
# Epoch: 9, Loss: 0.797918
# 13m 25s
# Epoch: 19, Loss: 0.613295
# 13m 28s
# Epoch: 29, Loss: 0.441223
# 0.8114942528735632
# 0.8942528735632185
# Model:  142
# 13m 32s
# Epoch: 9, Loss: 0.301414
# 13m 35s
# Epoch: 19, Loss: 0.107430
# 13m 39s
# Epoch: 29, Loss: 0.616050
# 0.8574712643678161
# 0.9126436781609196
# Model:  143
# 13m 43s
# Epoch: 9, Loss: 0.348841
# 13m 47s
# Epoch: 19, Loss: 0.162236
# 13m 51s
# Epoch: 29, Loss: 0.160936
# 0.8114942528735632
# 0.871264367816092
# Model:  144
# 13m 54s
# Epoch: 9, Loss: 0.410711
# 13m 58s
# Epoch: 19, Loss: 1.721146
# 14m 1s
# Epoch: 29, Loss: 0.719766
# 0.8436781609195403
# 0.9126436781609196
# Model:  145
# 14m 5s
# Epoch: 9, Loss: 0.565721
# 14m 9s
# Epoch: 19, Loss: 0.555071
# 14m 12s
# Epoch: 29, Loss: 0.536071
# 0.8160919540229885
# 0.9126436781609196
# Model:  146
# 14m 16s
# Epoch: 9, Loss: 0.607779
# 14m 19s
# Epoch: 19, Loss: 0.358199
# 14m 23s
# Epoch: 29, Loss: 0.409560
# 0.8160919540229885
# 0.8804597701149426
# Model:  147
# 14m 27s
# Epoch: 9, Loss: 0.761745
# 14m 30s
# Epoch: 19, Loss: 0.245776
# 14m 34s
# Epoch: 29, Loss: 0.311270
# 0.7931034482758622
# 0.9264367816091954
# Model:  148
# 14m 38s
# Epoch: 9, Loss: 0.515509
# 14m 41s
# Epoch: 19, Loss: 1.556908
# 14m 45s
# Epoch: 29, Loss: 1.635799
# 0.8482758620689655
# 0.9310344827586208
# Model:  149
# 14m 49s
# Epoch: 9, Loss: 0.789842
# 14m 52s
# Epoch: 19, Loss: 1.451307
# 14m 56s
# Epoch: 29, Loss: 0.506478
# 0.8574712643678161
# 0.9310344827586208
# Model:  150
# 15m 0s
# Epoch: 9, Loss: 0.997454
# 15m 3s
# Epoch: 19, Loss: 0.224582
# 15m 7s
# Epoch: 29, Loss: 0.114308
# 0.8298850574712644
# 0.8942528735632185
# Model:  151
# 15m 11s
# Epoch: 9, Loss: 0.358700
# 15m 14s
# Epoch: 19, Loss: 0.189708
# 15m 18s
# Epoch: 29, Loss: 0.177643
# 0.8068965517241379
# 0.8942528735632185
# Model:  152
# 15m 22s
# Epoch: 9, Loss: 0.496618
# 15m 25s
# Epoch: 19, Loss: 0.443412
# 15m 29s
# Epoch: 29, Loss: 0.227464
# 0.8574712643678161
# 0.9126436781609196
# Model:  153
# 15m 32s
# Epoch: 9, Loss: 0.324987
# 15m 36s
# Epoch: 19, Loss: 1.129073
# 15m 40s
# Epoch: 29, Loss: 0.475608
# 0.8758620689655172
# 0.9402298850574713
# Model:  154
# 15m 44s
# Epoch: 9, Loss: 0.432554
# 15m 48s
# Epoch: 19, Loss: 0.576859
# 15m 51s
# Epoch: 29, Loss: 0.461044
# 0.8160919540229885
# 0.8988505747126437
# Model:  155
# 15m 55s
# Epoch: 9, Loss: 0.360468
# 15m 59s
# Epoch: 19, Loss: 0.585318
# 16m 2s
# Epoch: 29, Loss: 0.392143
# 0.825287356321839
# 0.9126436781609196
# Model:  156
# 16m 6s
# Epoch: 9, Loss: 0.779387
# 16m 10s
# Epoch: 19, Loss: 0.524195
# 16m 14s
# Epoch: 29, Loss: 0.570200
# 0.7977011494252874
# 0.9126436781609196
# Model:  157
# 16m 18s
# Epoch: 9, Loss: 0.925633
# 16m 21s
# Epoch: 19, Loss: 0.271227
# 16m 25s
# Epoch: 29, Loss: 1.165015
# 0.8068965517241379
# 0.9402298850574713
# Model:  158
# 16m 29s
# Epoch: 9, Loss: 0.578041
# 16m 32s
# Epoch: 19, Loss: 0.344664
# 16m 36s
# Epoch: 29, Loss: 0.335813
# 0.825287356321839
# 0.9356321839080461
# Model:  159
# 16m 40s
# Epoch: 9, Loss: 0.801862
# 16m 44s
# Epoch: 19, Loss: 0.863660
# 16m 48s
# Epoch: 29, Loss: 0.493078
# 0.8528735632183909
# 0.9448275862068967
# Model:  160
# 16m 52s
# Epoch: 9, Loss: 0.366662
# 16m 56s
# Epoch: 19, Loss: 0.930256
# 16m 59s
# Epoch: 29, Loss: 0.534972
# 0.8206896551724139
# 0.9632183908045978
# Model:  161
# 17m 4s
# Epoch: 9, Loss: 0.690909
# 17m 7s
# Epoch: 19, Loss: 0.997477
# 17m 11s
# Epoch: 29, Loss: 0.126868
# 0.8574712643678161
# 0.9816091954022989
# Model:  162
# 17m 16s
# Epoch: 9, Loss: 1.096766
# 17m 19s
# Epoch: 19, Loss: 0.646940
# 17m 23s
# Epoch: 29, Loss: 1.099454
# 0.871264367816092
# 0.9770114942528735
# 17m 23s
